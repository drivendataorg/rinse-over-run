# %%
# !pip install tsfresh
# !pip install catboost
# Out:
# Collecting tsfresh
#   Downloading https://files.pythonhosted.org/packages/2f/32/265c651f4fd70751f5ada348af0f9e322b058eddcda6a6f9bb305c8d270a/tsfresh-0.11.1-py2.py3-none-any.whl (1.2MB)
#     100% |████████████████████████████████| 1.2MB 9.1MB/s
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (2.18.4)
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (0.8.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (1.1.0)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (0.22.0)
# Requirement already satisfied: dask>=0.15.2 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (0.20.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (1.14.6)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (0.5.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (1.11.0)
# Requirement already satisfied: tqdm>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (4.28.1)
# Requirement already satisfied: distributed>=1.18.3 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (1.25.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (0.16.0)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from tsfresh) (0.20.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->tsfresh) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->tsfresh) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->tsfresh) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->tsfresh) (2.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->tsfresh) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->tsfresh) (2.5.3)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (5.4.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (3.13)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (4.5.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (0.1.3)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (7.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (0.6.1)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (2.1.0)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (0.9.0)
# Requirement already satisfied: tblib in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (1.3.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.6/dist-packages (from distributed>=1.18.3->tsfresh) (0.5.6)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.6/dist-packages (from zict>=0.1.3->distributed>=1.18.3->tsfresh) (1.0.0)
# Installing collected packages: tsfresh
# Successfully installed tsfresh-0.11.1
# Collecting catboost
#   Downloading https://files.pythonhosted.org/packages/98/03/777a0e1c12571a7f3320a4fa6d5f123dba2dd7c0bca34f4f698a6396eb48/catboost-0.12.2-cp36-none-manylinux1_x86_64.whl (55.5MB)
#     100% |████████████████████████████████| 55.5MB 793kB/s
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from catboost) (1.14.6)
# Collecting enum34 (from catboost)
#   Downloading https://files.pythonhosted.org/packages/af/42/cb9355df32c69b553e72a2e28daee25d1611d2c0d9c272aa1d34204205b2/enum34-1.1.6-py3-none-any.whl
# Requirement already satisfied: pandas>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from catboost) (0.22.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from catboost) (1.11.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.1->catboost) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.1->catboost) (2.5.3)
# Installing collected packages: enum34, catboost
# Successfully installed catboost-0.12.2 enum34-1.1.6

# %%
# The essentials
import pandas as pd
import numpy as np

# Plotting
# %matplotlib inline
import matplotlib.pyplot as plt

# Progress bars
from tqdm import tqdm

# Access our Google Drive
from google.colab import drive

# Gradient Boosting
from catboost import CatBoostRegressor

from collections import defaultdict

from tsfresh.feature_selection.relevance import calculate_relevance_table
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
drive.mount('/content/drive', force_remount=True)
# !ls "/content/drive/My Drive/Rinse Over Run"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# 20178.png
# 20451.png
# 20899.png
# 22112.png
# 22369.png
# 22414.png
# 22487.png
# 23011.png
# 23142.png
# 23599.png
# 23872.png
# 24804.png
# 24845.png
# 24872.png
# 25129.png
# 25908.png
# 25983.png
# 26270.png
# 27115.png
# 27243.png
# 27346.png
# 27366.png
# 27418.png
# 27508.png
# all_train_preds_per_phase.p
# baseline_features_with_preds_per_phase.csv
# baseline_model_per_nunique_phases.csv
# dtw_distances_3.p
# extended_phase_predictors.csv
# last_cleaned_test.csv
# last_cleaned_train.csv
# mds_embeddings_2d_3.csv
# mds_embeddings_2d_3.p
# more_features_with_preds_per_phase.csv
# pca_features_with_preds_per_phase.csv
# predictions_machine_405.csv
# processes_all_phases.p
# test_features_14.csv
# test_features_15.csv
# test_features_1.csv
# test_features_2.csv
# test_features_3.csv
# test_features_6.csv
# test_features_7.csv
# test_features_8.csv
# test_features_per_phase_14.csv
# test_features_per_phase_15.csv
# test_features_per_phase_1.csv
# test_features_per_phase_2.csv
# test_features_per_phase_3.csv
# test_features_per_phase_6.csv
# test_features_per_phase_7.csv
# test_features_per_phase_8.csv
# test_features_sel_15.csv
# test_preds_per_phase.p
# test_values.csv
# test_values_sample.csv
# train_features_14.csv
# train_features_15.csv
# train_features_1.csv
# train_features_2.csv
# train_features_3.csv
# train_features_6.csv
# train_features_7.csv
# train_features_8.csv
# train_features_adv_14.csv
# train_features_adv_15.csv
# train_features_adv_1.csv
# train_features_adv_2.csv
# train_features_adv_3.csv
# train_features_adv_6.csv
# train_features_adv_7.csv
# train_features_adv_8.csv
# train_features_per_phase_14.csv
# train_features_per_phase_15.csv
# train_features_per_phase_1.csv
# train_features_per_phase_2.csv
# train_features_per_phase_3.csv
# train_features_per_phase_6.csv
# train_features_per_phase_7.csv
# train_features_per_phase_8.csv
# train_features_sel_15.csv
# train_labels.csv
# train_preds_per_phase.p
# train_values.csv
# train_values_sample.csv
# tsfresh_all_per_phase_combination_adv.csv
# tsfresh_all_per_phase_combination.csv
# tsfresh_features_14.csv
# tsfresh_features_15.csv
# tsfresh_features_1.csv
# tsfresh_features_2.csv
# tsfresh_features_3.csv
# tsfresh_features_6.csv
# tsfresh_features_7.csv
# tsfresh_features_8.csv
# tsfresh_features_object_low_level_14.csv
# tsfresh_features_object_low_level_1.csv
# tsfresh_features_object_low_level_2.csv
# tsfresh_features_object_low_level_3.csv
# tsfresh_features_object_low_level_6.csv
# tsfresh_features_object_low_level_7.csv
# tsfresh_features_return_acid_14.csv
# tsfresh_features_return_acid_1.csv
# tsfresh_features_return_acid_2.csv
# tsfresh_features_return_acid_3.csv
# tsfresh_features_return_acid_6.csv
# tsfresh_features_return_acid_7.csv
# tsfresh_features_return_caustic_14.csv
# tsfresh_features_return_caustic_1.csv
# tsfresh_features_return_caustic_2.csv
# tsfresh_features_return_caustic_3.csv
# tsfresh_features_return_caustic_6.csv
# tsfresh_features_return_caustic_7.csv
# tsfresh_features_return_conductivity_14.csv
# tsfresh_features_return_conductivity_1.csv
# tsfresh_features_return_conductivity_2.csv
# tsfresh_features_return_conductivity_3.csv
# tsfresh_features_return_conductivity_6.csv
# tsfresh_features_return_conductivity_7.csv
# tsfresh_features_return_drain_14.csv
# tsfresh_features_return_drain_1.csv
# tsfresh_features_return_drain_2.csv
# tsfresh_features_return_drain_3.csv
# tsfresh_features_return_drain_6.csv
# tsfresh_features_return_drain_7.csv
# tsfresh_features_return_flow_14.csv
# tsfresh_features_return_flow_1.csv
# tsfresh_features_return_flow_2.csv
# tsfresh_features_return_flow_3.csv
# tsfresh_features_return_flow_6.csv
# tsfresh_features_return_flow_7.csv
# tsfresh_features_return_recovery_water_14.csv
# tsfresh_features_return_recovery_water_1.csv
# tsfresh_features_return_recovery_water_2.csv
# tsfresh_features_return_recovery_water_3.csv
# tsfresh_features_return_recovery_water_6.csv
# tsfresh_features_return_recovery_water_7.csv
# tsfresh_features_return_temperature_14.csv
# tsfresh_features_return_temperature_1.csv
# tsfresh_features_return_temperature_2.csv
# tsfresh_features_return_temperature_3.csv
# tsfresh_features_return_temperature_6.csv
# tsfresh_features_return_temperature_7.csv
# tsfresh_features_return_turbidity_14.csv
# tsfresh_features_return_turbidity_1.csv
# tsfresh_features_return_turbidity_2.csv
# tsfresh_features_return_turbidity_3.csv
# tsfresh_features_return_turbidity_6.csv
# tsfresh_features_return_turbidity_7.csv
# tsfresh_features_supply_acid_14.csv
# tsfresh_features_supply_acid_1.csv
# tsfresh_features_supply_acid_2.csv
# tsfresh_features_supply_acid_3.csv
# tsfresh_features_supply_acid_6.csv
# tsfresh_features_supply_acid_7.csv
# tsfresh_features_supply_caustic_14.csv
# tsfresh_features_supply_caustic_1.csv
# tsfresh_features_supply_caustic_2.csv
# tsfresh_features_supply_caustic_3.csv
# tsfresh_features_supply_caustic_6.csv
# tsfresh_features_supply_caustic_7.csv
# tsfresh_features_supply_clean_water_14.csv
# tsfresh_features_supply_clean_water_1.csv
# tsfresh_features_supply_clean_water_2.csv
# tsfresh_features_supply_clean_water_3.csv
# tsfresh_features_supply_clean_water_6.csv
# tsfresh_features_supply_clean_water_7.csv
# tsfresh_features_supply_flow_14.csv
# tsfresh_features_supply_flow_1.csv
# tsfresh_features_supply_flow_2.csv
# tsfresh_features_supply_flow_3.csv
# tsfresh_features_supply_flow_6.csv
# tsfresh_features_supply_flow_7.csv
# tsfresh_features_supply_pre_rinse_14.csv
# tsfresh_features_supply_pre_rinse_1.csv
# tsfresh_features_supply_pre_rinse_2.csv
# tsfresh_features_supply_pre_rinse_3.csv
# tsfresh_features_supply_pre_rinse_6.csv
# tsfresh_features_supply_pre_rinse_7.csv
# tsfresh_features_supply_pressure_14.csv
# tsfresh_features_supply_pressure_1.csv
# tsfresh_features_supply_pressure_2.csv
# tsfresh_features_supply_pressure_3.csv
# tsfresh_features_supply_pressure_6.csv
# tsfresh_features_supply_pressure_7.csv
# tsfresh_features_supply_pump_14.csv
# tsfresh_features_supply_pump_1.csv
# tsfresh_features_supply_pump_2.csv
# tsfresh_features_supply_pump_3.csv
# tsfresh_features_supply_pump_6.csv
# tsfresh_features_supply_pump_7.csv
# tsfresh_features_tank_concentration_acid_14.csv
# tsfresh_features_tank_concentration_acid_1.csv
# tsfresh_features_tank_concentration_acid_2.csv
# tsfresh_features_tank_concentration_acid_3.csv
# tsfresh_features_tank_concentration_acid_6.csv
# tsfresh_features_tank_concentration_acid_7.csv
# tsfresh_features_tank_concentration_caustic_14.csv
# tsfresh_features_tank_concentration_caustic_1.csv
# tsfresh_features_tank_concentration_caustic_2.csv
# tsfresh_features_tank_concentration_caustic_3.csv
# tsfresh_features_tank_concentration_caustic_6.csv
# tsfresh_features_tank_concentration_caustic_7.csv
# tsfresh_features_tank_level_acid_14.csv
# tsfresh_features_tank_level_acid_1.csv
# tsfresh_features_tank_level_acid_2.csv
# tsfresh_features_tank_level_acid_3.csv
# tsfresh_features_tank_level_acid_6.csv
# tsfresh_features_tank_level_acid_7.csv
# tsfresh_features_tank_level_caustic_14.csv
# tsfresh_features_tank_level_caustic_1.csv
# tsfresh_features_tank_level_caustic_2.csv
# tsfresh_features_tank_level_caustic_3.csv
# tsfresh_features_tank_level_caustic_6.csv
# tsfresh_features_tank_level_caustic_7.csv
# tsfresh_features_tank_level_clean_water_14.csv
# tsfresh_features_tank_level_clean_water_1.csv
# tsfresh_features_tank_level_clean_water_2.csv
# tsfresh_features_tank_level_clean_water_3.csv
# tsfresh_features_tank_level_clean_water_6.csv
# tsfresh_features_tank_level_clean_water_7.csv
# tsfresh_features_tank_level_pre_rinse_14.csv
# tsfresh_features_tank_level_pre_rinse_1.csv
# tsfresh_features_tank_level_pre_rinse_2.csv
# tsfresh_features_tank_level_pre_rinse_3.csv
# tsfresh_features_tank_level_pre_rinse_6.csv
# tsfresh_features_tank_level_pre_rinse_7.csv
# tsfresh_features_tank_temperature_acid_14.csv
# tsfresh_features_tank_temperature_acid_1.csv
# tsfresh_features_tank_temperature_acid_2.csv
# tsfresh_features_tank_temperature_acid_3.csv
# tsfresh_features_tank_temperature_acid_6.csv
# tsfresh_features_tank_temperature_acid_7.csv
# tsfresh_features_tank_temperature_caustic_14.csv
# tsfresh_features_tank_temperature_caustic_1.csv
# tsfresh_features_tank_temperature_caustic_2.csv
# tsfresh_features_tank_temperature_caustic_3.csv
# tsfresh_features_tank_temperature_caustic_6.csv
# tsfresh_features_tank_temperature_caustic_7.csv
# tsfresh_features_tank_temperature_pre_rinse_14.csv
# tsfresh_features_tank_temperature_pre_rinse_1.csv
# tsfresh_features_tank_temperature_pre_rinse_2.csv
# tsfresh_features_tank_temperature_pre_rinse_3.csv
# tsfresh_features_tank_temperature_pre_rinse_6.csv
# tsfresh_features_tank_temperature_pre_rinse_7.csv
# tsfresh_mix_per_phase_combination_adv.csv
# tsfresh_none_per_phase_combination_adv.csv
# val_features_adv_14.csv
# val_features_adv_15.csv
# val_features_adv_1.csv
# val_features_adv_2.csv
# val_features_adv_3.csv
# val_features_adv_6.csv
# val_features_adv_7.csv
# val_features_adv_8.csv
# val_features_sel_15.csv
# val_preds_per_phase.p

# %%
train_df = pd.read_csv('/content/drive/My Drive/Rinse Over Run/train_values.csv', index_col=0, parse_dates=['timestamp'])
test_df = pd.read_csv('/content/drive/My Drive/Rinse Over Run/test_values.csv', index_col=0, parse_dates=['timestamp'])
label_df = pd.read_csv('/content/drive/My Drive/Rinse Over Run/train_labels.csv', index_col='process_id')
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
process_comb = 3
train_features_index = pd.read_csv('/content/drive/My Drive/Rinse Over Run/train_features_adv_{}.csv'.format(process_comb), index_col=['process_id']).index
val_features_index = pd.read_csv('/content/drive/My Drive/Rinse Over Run/val_features_adv_{}.csv'.format(process_comb), index_col=['process_id']).index
test_features_index = pd.read_csv('/content/drive/My Drive/Rinse Over Run/test_features_{}.csv'.format(process_comb), index_col=['process_id']).index

# %%
ts_real = [
    'supply_flow',
    'supply_pressure',
    'return_temperature',
    'return_conductivity',
    'return_turbidity',
    'return_flow',
    'tank_level_pre_rinse',
    'tank_level_caustic',
    'tank_level_acid',
    'tank_level_clean_water',
    'tank_temperature_pre_rinse',
    'tank_temperature_caustic',
    'tank_temperature_acid',
    'tank_concentration_caustic',
    'tank_concentration_acid',
    'target_value'
]

# variables we'll use to create our time series features
ts_cols = [
    'supply_flow',
    'supply_pressure',
    'return_temperature',
    'return_conductivity',
    'return_turbidity',
    'return_flow',
    'tank_level_pre_rinse',
    'tank_level_caustic',
    'tank_level_acid',
    'tank_level_clean_water',
    'tank_temperature_pre_rinse',
    'tank_temperature_caustic',
    'tank_temperature_acid',
    'tank_concentration_caustic',
    'tank_concentration_acid',
    'target_value'
]

# variables for binary time series features
bin_cols = [
    'supply_pump',
    'supply_pre_rinse',
    'supply_caustic',
    'return_caustic',
    'supply_acid',
    'return_acid',
    'supply_clean_water',
    'return_recovery_water',
    'return_drain',
    'object_low_level'
]

process_comb_to_phases = {
    15: ['pre_rinse', 'caustic', 'intermediate_rinse', 'acid'],
    3:  ['pre_rinse', 'caustic'],
    7:  ['pre_rinse', 'caustic', 'intermediate_rinse'],
    1:  ['pre_rinse'],
    8:  ['acid'],
    2:  ['caustic'],
    6:  ['caustic', 'intermediate_rinse'],
    14: ['caustic', 'intermediate_rinse', 'acid'],
}

# phases, ordered from earliest to latest
phases = ['pre_rinse', 'caustic', 'intermediate_rinse', 'acid']

def encode_categorical(df):
    # Currently just copy-pasted from http://drivendata.co/blog/rinse-over-run-benchmark/
    
    # select process_id and pipeline
    meta = df[['process_id', 'pipeline']].drop_duplicates().set_index('process_id') 
    
    # convert categorical pipeline data to dummy variables
    meta = pd.get_dummies(meta)
    
    # pipeline L12 not in test data (so useless feature)
    if 'pipeline_L12' in meta:
        meta = meta.drop('pipeline_L12', axis=1)
    
    # calculate number of phases for each process_object
    meta['num_phases'] = df.groupby('process_id')['phase'].apply(lambda x: x.nunique())
    
    return meta

def percentile_25(x):
  return np.percentile(x, 0.25)

def percentile_75(x):
  return np.percentile(x, 0.75)
  
def encode_real_timeseries(df):   
    ts_df = df[['process_id'] + ts_cols].set_index('process_id')
    
    # create features: count, min, max, mean, standard deviation
    ts_features = ts_df.groupby('process_id').agg(['min', 'max', 'mean', 'std', 
                                                   'count', 'median', 'sum', 
                                                   'mad'])
    
    # Now we will get the mean + variance value of the last K measurements for each phase
    # TODO: This can be moved to extracting features per phase
    all_vals_per_phase = []
    K = 5
    col_names = ['process_id'] 
    for phase in phases:
        for col in ts_cols:
            col_names.extend(['mean_{}_{}_{}'.format(col, K, phase), 
                              'std_{}_{}_{}'.format(col, K, phase)])
    for process in tqdm(ts_features.index, total=len(ts_features)):
        vals_per_phase = [process]
        process_filtered_df = df[df['process_id'] == process]
        for phase in phases:
            filtered_df = process_filtered_df[process_filtered_df['phase'] == phase].tail(K)
            for col in ts_cols:
                vals_per_phase.extend([filtered_df[col].mean(), filtered_df[col].std()])
                
        all_vals_per_phase.append(vals_per_phase)
    values_df = pd.DataFrame(all_vals_per_phase, columns=col_names)
    values_df = values_df.set_index('process_id')
    
    ts_features = ts_features.merge(values_df, left_index=True, right_index=True)
    
    col_map = {}
    for col in ts_features.columns:
        col_map[col] = 'real_{}'.format(col)
    ts_features = ts_features.rename(columns=col_map)
    
    return ts_features

def encode_binary_timeseries(df):
    ts_df = df[['process_id'] + bin_cols].set_index('process_id')
            
    # create features: count, min, max, mean, standard deviation
    ts_features = ts_df.groupby('process_id').agg(['mean', 'std', 'count', 'sum', 'mad'])
    
    # TODO: Count fraction of True in each phase
    feature_vectors = []
    col_names = ['process_id'] 
    for phase in phases:
        for col in bin_cols:
            col_names.append('fraction_{}_{}'.format(col, phase))
            
    # Get fraction of True values for each binary timeseries
    # TODO: This can be moved to extracting features per phase
    for process in tqdm(set(df['process_id']), total=len(set(df['process_id']))):
        vector = [process]
        process_filtered_df = df[df['process_id'] == process]
        for phase in phases:
            filtered_df = process_filtered_df[process_filtered_df['phase'] == phase]
            for col in bin_cols:
                if len(filtered_df):
                    vector.append(sum(filtered_df[col]) / len(filtered_df))
                else:
                    vector.append(np.NaN)
                
        feature_vectors.append(vector)
                
    feature_df = pd.DataFrame(feature_vectors, columns=col_names)
    feature_df = feature_df.set_index('process_id')
    
    feature_df = feature_df.merge(ts_features, left_index=True, right_index=True)
    col_map = {}
    for col in feature_df.columns:
        col_map[col] = 'bin_{}'.format(col)
    feature_df = feature_df.rename(columns=col_map)
    
    return feature_df
  

def get_descript(data, functions, cols):
    ts_df = data.set_index('process_id').sort_values(by='timestamp')
    return ts_df.groupby('process_id')[cols].agg(functions)  
  
  
def get_descript_prev_process(data):
    machines = set(data['object_id'])
    all_features = []
    for machine in tqdm(machines):
        machine_data = data[data['object_id'] == machine]
        machine_data = machine_data.sort_values(by='timestamp')
        machine_processes = machine_data['process_id'].unique()
        for process_ix, process in enumerate(machine_processes):
            if process_ix > 0:
                prev_process = machine_data[machine_data['process_id'] == machine_processes[process_ix - 1]]
                this_process = machine_data[machine_data['process_id'] == machine_processes[process_ix]]
                features = get_descript(prev_process, ['mean', 'std', 'min', 'max', 'count'], ts_real)
                _columns = list(features.columns)
                assert len(features) == 1
                features = features.iloc[0, :].values
                time_delta = (this_process['timestamp'].values[0] - prev_process['timestamp'].values[-1]) / np.timedelta64(1, 'h')
                assert time_delta > 0
                all_features.append([machine, process, time_delta] + list(features))
            else:
                all_features.append([machine, process, np.NaN] + ([np.NaN] * 60))
                
    all_features = pd.DataFrame(all_features, columns=['object_id', 'process_id', 'time_delta'] + _columns)
    all_features = all_features.set_index('process_id', drop=True)
    col_map = {}
    for col in all_features.columns:
        col_map[col] = 'prev_{}'.format(col)
    all_features = all_features.rename(columns=col_map)
    return all_features
  
def get_descript_per_phase(data, phases):
    all_features = pd.DataFrame(index=list(set(data['process_id'])))
    for phase in phases:
        phase_data = data[data['phase'] == phase].sort_values(by='timestamp')[['process_id'] + ts_real + bin_cols]
        col_map = {}
        for col in phase_data.columns:
          if col != 'process_id':
            col_map[col] = '{}_{}'.format(phase, col)
        phase_data = phase_data.rename(columns=col_map)
        features = phase_data.groupby('process_id').agg(['mean', 'std', 'count'])
        all_features = all_features.merge(features, left_index=True, right_index=True, how='left')
        
    col_map = {}
    for col in all_features.columns:
        col_map[col] = 'phase_{}'.format(col)
    all_features = all_features.rename(columns=col_map)

    return all_features

def create_feature_matrix(df):
    df['return_flow_relu'] = df['return_flow'].apply(lambda x: max(0, x))
    df['target_value'] = df['return_flow_relu'] * df['return_turbidity']
    
    #phase_features = get_descript_per_phase(df, ['pre_rinse', 'caustic'])
    prev_features = get_descript_prev_process(df)
    metadata = encode_categorical(df)
    time_series = encode_real_timeseries(df)
    binary_features = encode_binary_timeseries(df)
    
    # join metadata and time series features into a single dataframe
    feature_matrix = metadata
    feature_matrix = feature_matrix.merge(time_series, left_index=True, right_index=True)
    feature_matrix = feature_matrix.merge(binary_features, left_index=True, right_index=True)
    feature_matrix = feature_matrix.merge(prev_features, left_index=True, right_index=True)
    #feature_matrix = feature_matrix.merge(phase_features, left_index=True, right_index=True)
    
    return feature_matrix

# %%
all_train_index = list(train_features_index) + list(val_features_index)
train_df_filtered = train_df[(train_df['phase'].isin(process_comb_to_phases[process_comb])) &
                             (train_df['process_id'].isin(all_train_index))]
test_df_filtered = test_df[(test_df['phase'].isin(process_comb_to_phases[process_comb])) &
                           (test_df['process_id'].isin(test_features_index))]

features = create_feature_matrix(pd.concat([train_df_filtered, test_df_filtered]))

X_train = features.loc[train_features_index]
X_val = features.loc[val_features_index]
X_test = features.loc[test_features_index]


np.random.seed(1337)
X_train = pd.concat([X_train, X_val])

val_idx = np.random.choice(list(X_train.index), replace=False, size=int(0.1*len(X_train)))
train_idx = list(set(X_train.index) - set(val_idx))

X_val = X_train.loc[val_idx]
X_train = X_train.loc[train_idx]
# Out:
# 100%|██████████| 90/90 [03:22<00:00,  2.25s/it]
# 100%|██████████| 5925/5925 [02:04<00:00, 47.48it/s]
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py:558: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)
# 100%|██████████| 5925/5925 [00:55<00:00, 106.25it/s]
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py:558: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)

# %%
y_train = np.log(label_df.loc[X_train.index])
y_val = np.log(label_df.loc[X_val.index])


y_train = pd.concat([y_train, y_val], axis=0)
y_val = y_train.loc[val_idx]
y_train = y_train.loc[train_idx]

# %%
# Let's get the highly correlated features first
def get_corr_features(X):
  row_idx, col_idx = np.where(X.corr() == 1)
  self_corr = set([(i, i) for i in range(X_train.shape[1])])
  return set(list(zip(row_idx, col_idx))) - self_corr 

X_train_uncorr = X_train.copy()
correlated_features = get_corr_features(X_train_uncorr)
while correlated_features:
  print('{} correlated feature pairs left...'.format(len(correlated_features)))
  corr_row, corr_col = correlated_features.pop()
  print('{} is correlated with {}... Removing {}.'.format(X_train_uncorr.columns[corr_row], X_train_uncorr.columns[corr_col], X_train_uncorr.columns[corr_row]))
  col_mask = [True]*X_train_uncorr.shape[1]
  col_mask[corr_row] = False
  X_train_uncorr = X_train_uncorr.loc[:, col_mask]
  correlated_features = get_corr_features(X_train_uncorr)
  
print(X_train.shape, X_train_uncorr.shape)
# Out:
# 890 correlated feature pairs left...
# bin_('object_low_level', 'count') is correlated with real_('tank_level_caustic', 'count')... Removing bin_('object_low_level', 'count').
# 840 correlated feature pairs left...
# prev_('tank_temperature_pre_rinse', 'count') is correlated with prev_('tank_level_acid', 'count')... Removing prev_('tank_temperature_pre_rinse', 'count').
# 810 correlated feature pairs left...
# real_('tank_temperature_caustic', 'count') is correlated with real_('supply_flow', 'count')... Removing real_('tank_temperature_caustic', 'count').
# 762 correlated feature pairs left...
# real_('tank_level_caustic', 'count') is correlated with bin_('return_caustic', 'count')... Removing real_('tank_level_caustic', 'count').
# 716 correlated feature pairs left...
# real_('return_turbidity', 'count') is correlated with bin_('return_acid', 'count')... Removing real_('return_turbidity', 'count').
# 672 correlated feature pairs left...
# bin_('supply_pre_rinse', 'count') is correlated with bin_('return_acid', 'count')... Removing bin_('supply_pre_rinse', 'count').
# 630 correlated feature pairs left...
# prev_('tank_level_acid', 'count') is correlated with prev_('return_temperature', 'count')... Removing prev_('tank_level_acid', 'count').
# 602 correlated feature pairs left...
# bin_('return_drain', 'count') is correlated with bin_('supply_acid', 'count')... Removing bin_('return_drain', 'count').
# 562 correlated feature pairs left...
# bin_('return_recovery_water', 'count') is correlated with real_('return_temperature', 'count')... Removing bin_('return_recovery_water', 'count').
# 524 correlated feature pairs left...
# prev_('return_turbidity', 'count') is correlated with prev_('tank_concentration_acid', 'count')... Removing prev_('return_turbidity', 'count').
# 498 correlated feature pairs left...
# prev_('tank_level_clean_water', 'count') is correlated with prev_('return_flow', 'count')... Removing prev_('tank_level_clean_water', 'count').
# 474 correlated feature pairs left...
# bin_('return_acid', 'count') is correlated with real_('tank_level_clean_water', 'count')... Removing bin_('return_acid', 'count').
# 438 correlated feature pairs left...
# prev_('return_conductivity', 'count') is correlated with prev_('return_temperature', 'count')... Removing prev_('return_conductivity', 'count').
# 416 correlated feature pairs left...
# prev_('supply_flow', 'count') is correlated with prev_('return_temperature', 'count')... Removing prev_('supply_flow', 'count').
# 396 correlated feature pairs left...
# prev_('target_value', 'count') is correlated with prev_('tank_level_caustic', 'count')... Removing prev_('target_value', 'count').
# 378 correlated feature pairs left...
# bin_('supply_clean_water', 'count') is correlated with real_('tank_level_acid', 'count')... Removing bin_('supply_clean_water', 'count').
# 344 correlated feature pairs left...
# prev_('tank_concentration_caustic', 'count') is correlated with prev_('tank_temperature_caustic', 'count')... Removing prev_('tank_concentration_caustic', 'count').
# 328 correlated feature pairs left...
# real_('supply_pressure', 'count') is correlated with real_('target_value', 'count')... Removing real_('supply_pressure', 'count').
# 296 correlated feature pairs left...
# real_('tank_level_pre_rinse', 'count') is correlated with bin_('supply_pump', 'count')... Removing real_('tank_level_pre_rinse', 'count').
# 266 correlated feature pairs left...
# bin_('supply_acid', 'count') is correlated with real_('target_value', 'count')... Removing bin_('supply_acid', 'count').
# 238 correlated feature pairs left...
# prev_('tank_level_pre_rinse', 'count') is correlated with prev_('return_flow', 'count')... Removing prev_('tank_level_pre_rinse', 'count').
# 224 correlated feature pairs left...
# real_('tank_temperature_acid', 'count') is correlated with real_('return_temperature', 'count')... Removing real_('tank_temperature_acid', 'count').
# 198 correlated feature pairs left...
# prev_('supply_pressure', 'count') is correlated with prev_('tank_temperature_acid', 'count')... Removing prev_('supply_pressure', 'count').
# 186 correlated feature pairs left...
# real_('tank_concentration_acid', 'count') is correlated with real_('return_temperature', 'count')... Removing real_('tank_concentration_acid', 'count').
# 162 correlated feature pairs left...
# prev_('return_flow', 'count') is correlated with prev_('tank_temperature_caustic', 'count')... Removing prev_('return_flow', 'count').
# 152 correlated feature pairs left...
# real_('supply_flow', 'count') is correlated with bin_('supply_caustic', 'count')... Removing real_('supply_flow', 'count').
# 130 correlated feature pairs left...
# real_('return_conductivity', 'count') is correlated with real_('tank_level_clean_water', 'count')... Removing real_('return_conductivity', 'count').
# 110 correlated feature pairs left...
# real_('target_value', 'count') is correlated with bin_('return_caustic', 'count')... Removing real_('target_value', 'count').
# 92 correlated feature pairs left...
# prev_('tank_temperature_caustic', 'count') is correlated with prev_('tank_temperature_acid', 'count')... Removing prev_('tank_temperature_caustic', 'count').
# 84 correlated feature pairs left...
# real_('return_temperature', 'count') is correlated with real_('tank_level_clean_water', 'count')... Removing real_('return_temperature', 'count').
# 68 correlated feature pairs left...
# bin_('supply_pump', 'count') is correlated with real_('tank_level_acid', 'count')... Removing bin_('supply_pump', 'count').
# 54 correlated feature pairs left...
# real_('tank_temperature_pre_rinse', 'count') is correlated with real_('tank_level_acid', 'count')... Removing real_('tank_temperature_pre_rinse', 'count').
# 42 correlated feature pairs left...
# bin_('return_caustic', 'count') is correlated with real_('tank_level_clean_water', 'count')... Removing bin_('return_caustic', 'count').
# 32 correlated feature pairs left...
# prev_('tank_concentration_acid', 'count') is correlated with prev_('tank_temperature_acid', 'count')... Removing prev_('tank_concentration_acid', 'count').
# 26 correlated feature pairs left...
# real_('return_flow', 'count') is correlated with bin_('supply_caustic', 'count')... Removing real_('return_flow', 'count').
# 18 correlated feature pairs left...
# real_('tank_level_clean_water', 'count') is correlated with real_('tank_concentration_caustic', 'count')... Removing real_('tank_level_clean_water', 'count').
# 12 correlated feature pairs left...
# real_('tank_concentration_caustic', 'count') is correlated with real_('tank_level_acid', 'count')... Removing real_('tank_concentration_caustic', 'count').
# 8 correlated feature pairs left...
# real_('tank_level_acid', 'count') is correlated with bin_('supply_caustic', 'count')... Removing real_('tank_level_acid', 'count').
# 6 correlated feature pairs left...
# prev_('return_temperature', 'count') is correlated with prev_('tank_level_caustic', 'count')... Removing prev_('return_temperature', 'count').
# 2 correlated feature pairs left...
# prev_('tank_level_caustic', 'count') is correlated with prev_('tank_temperature_acid', 'count')... Removing prev_('tank_level_caustic', 'count').
# (4269, 439) (4269, 399)

# %%
# Now let's remove columns with too many NA's and only 1 single value
#na_cols = X_train_uncorr.columns[X_train_uncorr.isnull().sum() / len(X_train_uncorr) > 0.5]
single_cols = X_train_uncorr.columns[X_train_uncorr.nunique() == 1]

uncorr_cols = X_train_uncorr.columns
uncorr_cols = list(set(uncorr_cols) - set(single_cols)) #.union(set(na_cols))

#print(uncorr_cols)

X_train_no_corr = X_train[uncorr_cols]
X_val_no_corr = X_val[uncorr_cols]
print(X_train.shape, X_train_no_corr.shape)
#X_train.to_csv('/content/drive/My Drive/Rinse Over Run/train_features_sel_{}.csv'.format(process_comb))
#X_val.to_csv('/content/drive/My Drive/Rinse Over Run/val_features_sel_{}.csv'.format(process_comb))
# Out:
# (4269, 439) (4269, 383)

# %%
rel_table = calculate_relevance_table(X_train.dropna(axis=1), y_train['final_rinse_total_turbidity_liter'], ml_task='regression')

# %%
X_train_na_cols = X_train.columns[X_train.isnull().sum() > 1]
X_train_no_na = X_train[X_train_na_cols].dropna(axis=0)
rel_table_na = calculate_relevance_table(X_train_no_na.astype(float), y_train.loc[X_train_no_na.index]['final_rinse_total_turbidity_liter'], ml_task='regression')

# %%
X_train_selected_cols = list(set(rel_table_na[rel_table_na['p_value'] < 0.05]['feature']).union(set(rel_table[rel_table['p_value'] < 0.05]['feature'])))
len(X_train_selected_cols), len(X_train.columns)
# Out:
# (293, 378)

# %%
print(X_train_selected_cols)

X_train_sub = X_train[X_train_selected_cols]
X_val_sub = X_val[X_train_selected_cols]
X_test_sub = X_test[X_train_selected_cols]
#X_train.to_csv('/content/drive/My Drive/Rinse Over Run/train_features_sel_{}.csv'.format(process_comb))
#X_val.to_csv('/content/drive/My Drive/Rinse Over Run/val_features_sel_{}.csv'.format(process_comb))
#X_test.to_csv('/content/drive/My Drive/Rinse Over Run/test_features_sel_{}.csv'.format(process_comb))
# Out:
# ["prev_('tank_level_caustic', 'min')", "real_('tank_concentration_caustic', 'sum')", "real_('return_flow', 'sum')", "phase_('caustic_return_flow', 'std')", "real_('tank_level_clean_water', 'mad')", 'real_mean_supply_pressure_5_pre_rinse', "prev_('supply_flow', 'max')", 'real_std_tank_level_pre_rinse_5_pre_rinse', "prev_('return_conductivity', 'min')", "real_('tank_concentration_acid', 'sum')", "real_('return_turbidity', 'mad')", "real_('tank_concentration_acid', 'mad')", "prev_('tank_concentration_caustic', 'mean')", "prev_('tank_level_caustic', 'mean')", "real_('target_value', 'sum')", "prev_('tank_temperature_acid', 'min')", "real_('tank_concentration_acid', 'std')", "prev_('supply_flow', 'mean')", 'real_std_tank_concentration_caustic_5_pre_rinse', 'pipeline_L11', "real_('tank_concentration_caustic', 'std')", "real_('target_value', 'mad')", "bin_('supply_caustic', 'std')", "real_('tank_level_clean_water', 'median')", "real_('supply_pressure', 'std')", "bin_('object_low_level', 'mad')", "bin_('supply_pre_rinse', 'sum')", "phase_('caustic_target_value', 'std')", "phase_('caustic_supply_caustic', 'std')", "phase_('caustic_supply_flow', 'mean')", "phase_('pre_rinse_return_temperature', 'mean')", "prev_('tank_temperature_caustic', 'std')", 'real_mean_tank_concentration_caustic_5_pre_rinse', "phase_('pre_rinse_supply_pump', 'mean')", 'real_mean_tank_concentration_caustic_5_caustic', "real_('tank_level_caustic', 'min')", "bin_('object_low_level', 'sum')", "phase_('pre_rinse_tank_level_acid', 'std')", "prev_('tank_temperature_acid', 'std')", "prev_('return_conductivity', 'mean')", "phase_('pre_rinse_tank_concentration_acid', 'std')", "prev_('target_value', 'max')", "prev_('tank_level_acid', 'std')", 'real_std_return_flow_5_pre_rinse', "phase_('caustic_tank_level_pre_rinse', 'mean')", "phase_('caustic_supply_pump', 'std')", "real_('tank_level_acid', 'std')", 'real_std_supply_pressure_5_pre_rinse', 'pipeline_L8', "prev_('return_conductivity', 'max')", "bin_('supply_pump', 'mad')", 'pipeline_L4', 'real_mean_return_flow_5_caustic', "prev_('supply_pressure', 'min')", "real_('return_conductivity', 'max')", 'real_std_tank_level_acid_5_pre_rinse', "prev_('supply_flow', 'std')", "real_('target_value', 'std')", 'real_std_tank_concentration_acid_5_caustic', "prev_('return_flow', 'std')", 'real_mean_return_temperature_5_caustic', "real_('return_flow', 'min')", 'real_std_tank_level_acid_5_caustic', "real_('return_temperature', 'median')", "bin_('supply_clean_water', 'sum')", "prev_('target_value', 'min')", "bin_('supply_pre_rinse', 'mean')", "phase_('caustic_return_conductivity', 'std')", "phase_('caustic_supply_caustic', 'mean')", "real_('return_flow', 'median')", "prev_('supply_pressure', 'std')", 'real_mean_supply_flow_5_caustic', "real_('return_temperature', 'mad')", "real_('tank_temperature_caustic', 'mean')", "prev_('tank_temperature_acid', 'max')", "real_('tank_level_pre_rinse', 'median')", "phase_('pre_rinse_return_turbidity', 'mean')", "real_('supply_flow', 'max')", "real_('tank_concentration_acid', 'max')", "real_('tank_temperature_acid', 'min')", 'real_std_return_flow_5_caustic', 'bin_fraction_supply_pre_rinse_pre_rinse', "bin_('supply_pump', 'std')", "phase_('pre_rinse_object_low_level', 'std')", "real_('tank_concentration_caustic', 'mean')", "prev_('tank_concentration_acid', 'min')", "real_('return_conductivity', 'sum')", "phase_('pre_rinse_tank_level_pre_rinse', 'mean')", "real_('target_value', 'min')", "prev_('tank_level_pre_rinse', 'std')", "real_('supply_flow', 'median')", "phase_('caustic_supply_pump', 'mean')", "bin_('supply_clean_water', 'std')", "prev_('return_flow', 'min')", 'pipeline_L3', "real_('target_value', 'mean')", "prev_('supply_pressure', 'mean')", "bin_('return_caustic', 'std')", "real_('tank_level_caustic', 'sum')", "bin_('return_drain', 'mad')", 'real_std_target_value_5_pre_rinse', "phase_('pre_rinse_tank_level_clean_water', 'mean')", "prev_('tank_temperature_caustic', 'min')", 'real_std_supply_pressure_5_causti ...

# %%
def custom_mape(approxes, targets):
    return np.mean(np.abs(np.subtract(approxes, targets)) / np.maximum(np.abs(targets), 290000))

class MAPEMetric(object):
    def get_final_error(self, error, weight):
        return error

    def is_max_optimal(self):
        return False

    def evaluate(self, approxes, targets, weight):
        return custom_mape(np.exp(approxes), np.exp(targets)), len(targets)

# %%
cat = CatBoostRegressor(iterations=100000, od_type='Iter', od_wait=250, learning_rate=0.33,
                        loss_function='MAPE', eval_metric='MAPE', border_count=254, task_type='GPU')#, l2_leaf_reg=10) #MAPEMetric()
cat.fit(X_train_no_corr, y_train, eval_set=(X_val_no_corr, y_val), verbose=50)

# baseline: 0.3098982664741879
# removing useless features: 0.31096976977748236
# more features: 0.3098482619660084
# Out:
# 0:	learn: 0.9981617	test: 0.9981692	best: 0.9981692 (0)	total: 73.4ms	remaining: 2h 2m 18s
# 50:	learn: 0.9055828	test: 0.9059201	best: 0.9059201 (50)	total: 2.4s	remaining: 1h 18m 34s
# 100:	learn: 0.8127572	test: 0.8136417	best: 0.8136417 (100)	total: 4.04s	remaining: 1h 6m 34s
# 150:	learn: 0.7199331	test: 0.7214031	best: 0.7214031 (150)	total: 5.61s	remaining: 1h 1m 47s
# 200:	learn: 0.6271076	test: 0.6290847	best: 0.6290847 (200)	total: 7.3s	remaining: 1h 23s
# 250:	learn: 0.5342897	test: 0.5368148	best: 0.5368148 (250)	total: 8.95s	remaining: 59m 18s
# 300:	learn: 0.4415060	test: 0.4445416	best: 0.4445416 (300)	total: 10.6s	remaining: 58m 40s
# 350:	learn: 0.3506329	test: 0.3535772	best: 0.3535772 (350)	total: 12.5s	remaining: 59m 19s
# 400:	learn: 0.2664131	test: 0.2677799	best: 0.2677799 (400)	total: 15.4s	remaining: 1h 3m 51s
# 450:	learn: 0.1927465	test: 0.1932633	best: 0.1932633 (450)	total: 18.4s	remaining: 1h 7m 47s
# 500:	learn: 0.1251733	test: 0.1246239	best: 0.1246239 (500)	total: 21.5s	remaining: 1h 11m 5s
# 550:	learn: 0.0728217	test: 0.0710532	best: 0.0710532 (550)	total: 24.5s	remaining: 1h 13m 45s
# 600:	learn: 0.0492338	test: 0.0487340	best: 0.0487340 (600)	total: 27.7s	remaining: 1h 16m 22s
# 650:	learn: 0.0377659	test: 0.0398107	best: 0.0398107 (650)	total: 30.9s	remaining: 1h 18m 36s
# 700:	learn: 0.0309374	test: 0.0346046	best: 0.0346046 (700)	total: 34s	remaining: 1h 20m 14s
# 750:	learn: 0.0295803	test: 0.0339333	best: 0.0339305 (749)	total: 37.1s	remaining: 1h 21m 36s
# 800:	learn: 0.0286208	test: 0.0333739	best: 0.0333739 (800)	total: 40s	remaining: 1h 22m 40s
# 850:	learn: 0.0278910	test: 0.0331517	best: 0.0331517 (850)	total: 43s	remaining: 1h 23m 32s
# 900:	learn: 0.0271757	test: 0.0330586	best: 0.0330435 (893)	total: 46s	remaining: 1h 24m 24s
# 950:	learn: 0.0265053	test: 0.0328491	best: 0.0328468 (948)	total: 49.1s	remaining: 1h 25m 11s
# 1000:	learn: 0.0259612	test: 0.0328128	best: 0.0327928 (994)	total: 52.1s	remaining: 1h 25m 55s
# 1050:	learn: 0.0254665	test: 0.0327723	best: 0.0327694 (1020)	total: 55.2s	remaining: 1h 26m 37s
# 1100:	learn: 0.0249219	test: 0.0326806	best: 0.0326626 (1094)	total: 58.3s	remaining: 1h 27m 20s
# 1150:	learn: 0.0243777	test: 0.0325984	best: 0.0325801 (1129)	total: 1m 1s	remaining: 1h 27m 56s
# 1200:	learn: 0.0239392	test: 0.0325771	best: 0.0325717 (1196)	total: 1m 4s	remaining: 1h 28m 23s
# 1250:	learn: 0.0234329	test: 0.0325800	best: 0.0325631 (1215)	total: 1m 7s	remaining: 1h 29m 2s
# 1300:	learn: 0.0230007	test: 0.0324891	best: 0.0324838 (1294)	total: 1m 10s	remaining: 1h 29m 31s
# 1350:	learn: 0.0225960	test: 0.0325340	best: 0.0324712 (1305)	total: 1m 13s	remaining: 1h 29m 57s
# 1400:	learn: 0.0221821	test: 0.0325458	best: 0.0324712 (1305)	total: 1m 17s	remaining: 1h 30m 25s
# 1450:	learn: 0.0217303	test: 0.0325911	best: 0.0324712 (1305)	total: 1m 20s	remaining: 1h 30m 55s
# 1500:	learn: 0.0213239	test: 0.0326352	best: 0.0324712 (1305)	total: 1m 23s	remaining: 1h 31m 18s
# 1550:	learn: 0.0209322	test: 0.0326248	best: 0.0324712 (1305)	total: 1m 26s	remaining: 1h 31m 40s
# bestTest = 0.0324712202
# bestIteration = 1305
# Shrink model to first 1306 iterations.

# %%
print(custom_mape(np.exp(cat.predict(X_val)), np.exp(y_val.values.flatten())))
# Out:
# 0.3113927192320934

# %%
single_cols
# Out:
# Index(['num_phases', 'bin_fraction_return_caustic_pre_rinse',
#        'bin_fraction_supply_acid_pre_rinse',
#        'bin_fraction_return_acid_pre_rinse',
#        'bin_fraction_supply_clean_water_pre_rinse',
#        'bin_fraction_return_recovery_water_pre_rinse',
#        'bin_fraction_supply_acid_caustic',
#        'bin_fraction_return_recovery_water_caustic',
#        'bin_('supply_acid', 'mean')', 'bin_('supply_acid', 'std')',
#        'bin_('supply_acid', 'sum')', 'bin_('supply_acid', 'mad')',
#        'bin_('return_recovery_water', 'mean')',
#        'bin_('return_recovery_water', 'std')',
#        'bin_('return_recovery_water', 'sum')',
#        'bin_('return_recovery_water', 'mad')',
#        'phase_('pre_rinse_return_caustic', 'mean')',
#        'phase_('pre_rinse_return_caustic', 'std')',
#        'phase_('pre_rinse_supply_acid', 'mean')',
#        'phase_('pre_rinse_supply_acid', 'std')',
#        'phase_('pre_rinse_return_acid', 'mean')',
#        'phase_('pre_rinse_return_acid', 'std')',
#        'phase_('pre_rinse_supply_clean_water', 'mean')',
#        'phase_('pre_rinse_supply_clean_water', 'std')',
#        'phase_('pre_rinse_return_recovery_water', 'mean')',
#        'phase_('pre_rinse_return_recovery_water', 'std')',
#        'phase_('caustic_supply_acid', 'mean')',
#        'phase_('caustic_supply_acid', 'std')',
#        'phase_('caustic_return_recovery_water', 'mean')',
#        'phase_('caustic_return_recovery_water', 'std')'],
#       dtype='object')

# %%
# cat = CatBoostRegressor(iterations=100000, od_type='Iter', od_wait=250, learning_rate=0.33,
#                         loss_function='MAPE', eval_metric='MAPE')#
# cat.fit(X_train, y_train, eval_set=(X_val, y_val), verbose=50)
# Out:
# 0:	learn: 0.9981518	test: 0.9981495	best: 0.9981495 (0)	total: 29.9ms	remaining: 49m 54s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-2940213ef8d7> in <module>()
#       1 cat = CatBoostRegressor(iterations=100000, od_type='Iter', od_wait=250, learning_rate=0.33,
#       2                         loss_function='MAPE', eval_metric='MAPE')#
# ----> 3 cat.fit(X_train, y_train, eval_set=(X_val, y_val), verbose=50)
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in fit(self, X, y, cat_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval)
#    2547                          use_best_model, eval_set, verbose, logging_level, plot, column_description,
#    2548                          verbose_eval, metric_period, silent, early_stopping_rounds,
# -> 2549                          save_snapshot, snapshot_file, snapshot_interval)
#    2550
#    2551     def predict(self, data, ntree_start=0, ntree_end=0, thread_count=-1, verbose=None):
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in _fit(self, X, y, cat_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval)
#    1124
#    1125         with log_fixup(), plot_wrapper(plot, self.get_params()):
# -> 1126             self._train(train_pool, eval_sets, params, allow_clear_pool)
#    1127
#    1128         if (not self._object._has_leaf_weights_in_model()) and allow_clear_pool:
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool)
#     826
#     827     def _train(self, train_pool, test_pool, params, allow_clear_pool):
# --> 828         self._object._train(train_pool, test_pool, params, allow_clear_pool)
#     829         self._set_trained_model_attributes()
#     830
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
rel_table_na
# Out:
#                                                                                  feature  \
# feature
# prev_('supply_flow', 'mean')                                prev_('supply_flow', 'mean')
# prev_('return_flow', 'mean')                                prev_('return_flow', 'mean')
# prev_('supply_flow', 'max')                                  prev_('supply_flow', 'max')
# prev_('supply_flow', 'std')                                  prev_('supply_flow', 'std')
# prev_('return_flow', 'std')                                  prev_('return_flow', 'std')
# prev_('return_flow', 'max')                                  prev_('return_flow', 'max')
# prev_('target_value', 'mean')                              prev_('target_value', 'mean')
# prev_('supply_pressure', 'min')                          prev_('supply_pressure', 'min')
# prev_('return_flow', 'min')                                  prev_('return_flow', 'min')
# prev_('target_value', 'max')                                prev_('target_value', 'max')
# prev_('target_value', 'std')                                prev_('target_value', 'std')
# prev_('return_conductivity', 'max')                  prev_('return_conductivity', 'max')
# prev_('tank_temperature_caustic', 'count')    prev_('tank_temperature_caustic', 'count')
# prev_('return_conductivity', 'mean')                prev_('return_conductivity', 'mean')
# prev_('supply_pressure', 'mean')                        prev_('supply_pressure', 'mean')
# prev_('target_value', 'min')                                prev_('target_value', 'min')
# prev_('supply_pressure', 'std')                          prev_('supply_pressure', 'std')
# prev_('tank_level_pre_rinse', 'min')                prev_('tank_level_pre_rinse', 'min')
# prev_('tank_level_pre_rinse', 'mean')              prev_('tank_level_pre_rinse', 'mean')
# prev_('supply_pressure', 'max')                          prev_('supply_pressure', 'max')
# prev_('tank_level_pre_rinse', 'std')                prev_('tank_level_pre_rinse', 'std')
# prev_('tank_level_acid', 'std')                          prev_('tank_level_acid', 'std')
# prev_('tank_level_caustic', 'std')                    prev_('tank_level_caustic', 'std')
# prev_('tank_concentration_acid', 'max')          prev_('tank_concentration_acid', 'max')
# prev_('tank_temperature_acid', 'min')              prev_('tank_temperature_acid', 'min')
# prev_('return_temperature', 'max')                    prev_('return_temperature', 'max')
# prev_('tank_temperature_pre_rinse', 'std')    prev_('tank_temperature_pre_rinse', 'std')
# prev_('return_temperature', 'min')                    prev_('return_temperature', 'min')
# prev_('tank_concentration_acid', 'min')          prev_('tank_concentration_acid', 'min')
# prev_('tank_level_acid', 'min')                          prev_('tank_level_acid', 'min')
# ...                                                                                  ...
# prev_('tank_concentration_caustic', 'min')    prev_('tank_concentration_caustic', 'min')
# prev_('tank_temperature_caustic', 'std')        prev_('tank_temperature_caustic', 'std')
# prev_('return_turbidity', 'std')                        prev_('return_turbidity', 'std')
# prev_('tank_concentration_caustic', 'mean')  prev_('tank_concentration_caustic', 'mean')
# prev_('tank_concentration_caustic', 'max')    prev_('tank_concentration_caustic', 'max')
# prev_('tank_temperature_acid', 'max')              prev_('tank_temperature_acid', 'max')
# prev_('return_turbidity', 'min')                        prev_('return_turbidity', 'min')
# prev_('tank_level_caustic', 'max')                    prev_('tank_level_caustic', 'max')
# prev_('tank_level_clean_water', 'min')            prev_('tank_level_clean_water', 'min')
# prev_('supply_flow', 'min')                                  prev_('supply_flow', 'min')
# prev_('tank_temperature_acid', 'mean')            prev_('tank_temperature_acid', 'mean')
# prev_('tank_level_acid', 'mean')                        prev_('tank_level_acid', 'mean')
# prev_('tank_level_caustic', 'mean')                  prev_('tank_level_caustic', 'mean')
# prev_('tank_temperature_caustic', 'mean')      prev_('tank_temperature_caustic', 'mean')
# prev_('tank_temperature_caustic', 'max')        prev_('tank_temperature_caustic', 'max')
# prev_('tank_level_pre_rinse', 'max')                prev_('tank_level_pre_rinse', 'max')
# prev_('return_turbidity', 'mean')                      prev_('return_turbidity', 'mean')
# prev_('tank_temperature_pre_rinse', 'max')    prev_('tank_temperature_pre_rinse', 'max')
# prev_('tank_concentration_caustic', 'std')    prev_('tank_concentration_caustic', 'std')
# prev_('tank_level_clean_water', 'max')            prev_('tank_level_clean_water', 'max')
# prev_('tank_level_acid', 'max')                          prev_('tank_level_acid', 'max')
# prev_('return_temperature', 'std')                    prev_('return_temperature', 'std')
# prev_('return_conductivity', 'min')                  prev_('return_conductivity', 'min')
# prev_('tank_temperature_pre_rinse', 'mean')  prev_('tank_temperature_pre_rinse', 'mean')
# prev_('return_conductivity', 'std')                  prev_('return_conductivity', 'std')
# prev_('tank_level_clean_water', 'mean')          prev_('tank_level_clean_water', 'mean')
# prev_('tank_concentration_acid', 'mean')        prev_('tank_concentration_acid', 'mean')
# prev_('tank_temperature_pre_rinse', 'min')    prev_('tank_temperature_pre_rinse', 'min')
# prev_time_delta                                                          prev_time_delta
# prev_('return_turbidity', 'max')                        prev_('return_turbidity', 'max')
#
#                                              type        p_value  relevant
# feature
# prev_('supply_flow', 'mean')                 real  1.734781e-294      True
# prev_('return_flow', 'mean')                 real  5.860941e-282      True
# prev_('supply_flow', 'max')                  real  1.313609e-274      True
# prev_('supply_flow', 'std')                  real  8.289771e-224      True
# prev_('return_flow', 'std')                  real  1.155660e-137      True
# prev_('return_flow', 'max')                  real  4.138401e-101      True
# prev_('target_value', 'mean')                real   3.557386e-84      True
# prev_('supply_pressure', 'min')              real   1.161656e-59      True
# prev_('return_flow', 'min')                  real   6.827346e-55      True
# prev_('target_value', 'max')                 real   9.064211e-51      True
# prev_('target_value', 'std')                 real   1.379179e-49      True
# prev_('return_conductivity', 'max')          real   3.766419e-46      True
# prev_('tank_temperature_caustic', 'count')   real   1.058451e-45      True
# prev_('return_conductivity', 'mean')         real   2.907239e-44      True
# prev_('supply_pressure', 'mean')             real   5.867075e-31      True
# prev_('target_value', 'min')                 real   1.867129e-30      True
# prev_('supply_pressure', 'std')              real   3.053918e-28      True
# prev_('tank_level_pre_rinse', 'min')         real   1.053113e-22      True
# prev_('tank_level_pre_rinse', 'mean')        real   4.169192e-22      True
# prev_('supply_pressure', 'max')              real   1.369025e-21      True
# prev_('tank_level_pre_rinse', 'std')         real   5.522262e-20      True
# prev_('tank_level_acid', 'std')              real   3.419391e-19      True
# prev_('tank_level_caustic', 'std')           real   1.594864e-17      True
# prev_('tank_concentration_acid', 'max')      real   9.739820e-15      True
# prev_('tank_temperature_acid', 'min')        real   7.758600e-13      True
# prev_('return_temperature', 'max')           real   8.451360e-13      True
# prev_('tank_temperature_pre_rinse', 'std')   real   7.313311e-12      True
# prev_('return_temperature', 'min')           real   1.075539e-11      True
# prev_('tank_concentration_acid', 'min')      real   1.548359e-11      True
# prev_('tank_level_acid', 'min')              real   7.972513e-11      True
# ...                                           ...            ...       ...
# prev_('tank_concentration_caustic', 'min')   real   6.061248e-07      True
# prev_('tank_temperature_caustic', 'std')     real   3.735747e-06      True
# prev_('return_turbidity', 'std')             real   4.298703e-06      True
# prev_('tank_concentration_caustic', 'mean')  real   7.285090e-05      True
# prev_('tank_concentration_caustic', 'max')   real   1.844112e-04      True
# prev_('tank_temperature_acid', 'max')        real   8.004111e-04      True
# prev_('return_turbidity', 'min')             real   8.442713e-04      True
# prev_('tank_level_caustic', 'max')           real   2.570623e-03      True
# prev_('tank_level_clean_water', 'min')       real   2.817194e-03      True
# prev_('supply_flow', 'min')                  real   3.059572e-03      True
# prev_('tank_temperature_acid', 'mean')       real   5.355882e-03      True
# prev_('tank_level_acid', 'mean')             real   5.477117e-03      True
# prev_('tank_level_caustic', 'mean')          real   7.275958e-03      True
# prev_('tank_temperature_caustic', 'mean')    real   1.042410e-02     False
# prev_('tank_temperature_caustic', 'max')     real   1.332354e-02     False
# prev_('tank_level_pre_rinse', 'max')         real   1.735026e-02     False
# prev_('return_turbidity', 'mean')            real   1.872133e-02     False
# prev_('tank_temperature_pre_rinse', 'max')   real   3.042626e-02     False
# prev_('tank_concentration_caustic', 'std')   real   3.751261e-02     False
# prev_('tank_level_clean_water', 'max')       real   6.792492e-02     False
# prev_('tank_level_acid', 'max')              real   1.837424e-01     False
# prev_('return_temperature', 'std')           real   2.661305e-01     False
# prev_('return_conductivity', 'min')          real   3.669314e-01     False
# prev_('tank_temperature_pre_rinse', 'mean')  real   3.713885e-01     False
# prev_('return_conductivity', 'std')          real   4.192465e-01     False
# prev_('tank_level_clean_water', 'mean')      real   5.049092e-01     False
# prev_('tank_concentration_acid', 'mean')     real   5.367735e-01     False
# prev_('tank_temperature_pre_rinse', 'min')   real   5.399471e-01     False
# prev_time_delta                              real   5.648360e-01     False
# prev_('return_turbidity', 'max')             real   8.998079e-01     False
#
# [66 rows x 4 columns]
