# %%
# pip installs go here
# !pip install mord
# Out:
# Collecting mord
#   Downloading https://files.pythonhosted.org/packages/67/9d/c791c841501d9ff4ecb76b57f208dec6cf9f925109c59c995ddec80f9b32/mord-0.6.tar.gz
# Building wheels for collected packages: mord
#   Building wheel for mord (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/98/14/b2/244c2cec93a0c6edb29b488bd6b2710ded7e9d457033b86366
# Successfully built mord
# Installing collected packages: mord
# Successfully installed mord-0.6

# %%
# The essentials
import pandas as pd
import numpy as np

from collections import defaultdict

# Plotting
# %matplotlib inline
import matplotlib.pyplot as plt

# Progress bars
from tqdm import tqdm

# Access our Google Drive
from google.colab import drive

from sklearn.model_selection import KFold, GridSearchCV
from sklearn.linear_model import Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor, RandomTreesEmbedding
from sklearn.base import clone


from collections import defaultdict, Counter
from scipy.stats import norm

from sklearn.preprocessing import PowerTransformer, StandardScaler
import glob

# %%
drive.mount('/content/drive', force_remount=True)
# !ls "/content/drive/My Drive/Rinse Over Run"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# 20178.png
# 20451.png
# 20899.png
# 22112.png
# 22369.png
# 22414.png
# 22487.png
# 23011.png
# 23142.png
# 23599.png
# 23872.png
# 24804.png
# 24845.png
# 24872.png
# 25129.png
# 25908.png
# 25983.png
# 26270.png
# 27115.png
# 27243.png
# 27346.png
# 27366.png
# 27418.png
# 27508.png
# all_train_preds_per_phase.p
# baseline_features_with_preds_per_phase.csv
# baseline_model_per_nunique_phases.csv
# better_prev_object_id_per_10.csv
# dtw_distances_3.p
# extended_phase_predictors.csv
# final_phase_labels_15_14.csv
# final_phase_labels_15_15.csv
# final_phase_labels_15_1.csv
# final_phase_labels_15_2.csv
# final_phase_labels_15_3.csv
# final_phase_labels_15_6.csv
# final_phase_labels_15_7.csv
# final_phase_labels_3_1.csv
# final_phase_labels_3_2.csv
# final_phase_labels_3_3.csv
# final_phase_labels_9_8.csv
# hcsta_features_3_3.csv
# last_cleaned_test.csv
# last_cleaned_train.csv
# mds_embeddings_2d_3.csv
# mds_embeddings_2d_3.p
# model_per_recipe_simple.csv
# more_features_with_preds_per_phase.csv
# pca_features_with_preds_per_phase.csv
# predictions_15_15.csv
# predictions_15_1.csv
# predictions_152_15_15
# predictions_152_3_1
# predictions_152_3_2
# predictions_152_3_3
# predictions_152_9_8
# predictions_15_3.csv
# predictions_15_7.csv
# predictions_162_15_1
# predictions_162_15_15
# predictions_162_15_3
# predictions_162_15_7
# predictions_162_3_1
# predictions_162_3_2
# predictions_162_3_3
# predictions_162_9_8
# predictions_192_15_1
# predictions_192_15_15
# predictions_192_15_3
# predictions_192_15_7
# predictions_3_3.csv
# predictions_9_8.csv
# predictions_machine_405.csv
# predictions_nn_train_1111.csv
# preds_feature_selection.csv
# processes_all_phases.p
# process_machine_outlier_predicted.csv
# recipe_8_augmented.csv
# recipe_metadata.csv
# recipe_model_all_tsfresh_bitmaps.csv
# recipe_model_prev_process_tsfresh.csv
# stacking_v1.csv
# stacking_v2_not_all_models.csv
# submission_1602.csv
# supertest.csv
# test_features_14.csv
# test_features_15_14.csv
# test_features_15_15.csv
# test_features_15_1.csv
# test_features_15_2.csv
# test_features_15_3.csv
# test_features_15_6.csv
# test_features_15_7.csv
# test_features_15.csv
# test_features_1.csv
# test_features_2.csv
# test_features_3_1.csv
# test_features_3_2.csv
# test_features_3_3.csv
# test_features_3.csv
# test_features_6.csv
# test_features_7.csv
# test_features_8.csv
# test_features_9_8.csv
# test_features_per_phase_14.csv
# test_features_per_phase_15.csv
# test_features_per_phase_1.csv
# test_features_per_phase_2.csv
# test_features_per_phase_3.csv
# test_features_per_phase_6.csv
# test_features_per_phase_7.csv
# test_features_per_phase_8.csv
# test_features_sel_15.csv
# test_predictions_knn_3_1.csv
# test_predictions_knn_pca_3_1.csv
# test_predictions_lr_3_1.csv
# test_predictions_stack_ada_250_15_1.csv
# test_predictions_stack_ada_250_15_3.csv
# test_predictions_stack_ada_50_15_15.csv
# test_predictions_stack_ada_50_15_1.csv
# test_predictions_stack_ada_50_15_3.csv
# test_predictions_stack_ada_50_15_7.csv
# test_predictions_stack_ada_50_3_1.csv
# test_predictions_stack_ada_50_3_2.csv
# test_predictions_stack_ada_50_3_3.csv
# test_predictions_stack_ada_50_9_8.csv
# test_predictions_stack_bay_lr_15_15.csv
# test_predictions_stack_bay_lr_15_1.csv
# test_predictions_stack_bay_lr_15_3.csv
# test_predictions_stack_bay_lr_15_7.csv
# test_predictions_stack_bay_lr_3_1.csv
# test_predictions_stack_bay_lr_3_2.csv
# test_predictions_stack_bay_lr_3_3.csv
# test_predictions_stack_bay_lr_9_8.csv
# test_predictions_stack_cat_clf_15_15.csv
# test_predictions_stack_cat_clf_15_1.csv
# test_predictions_stack_cat_clf_15_3.csv
# test_predictions_stack_cat_clf_15_7.csv
# test_predictions_stack_cat_flow_clf_15_15.csv
# test_predictions_stack_cat_flow_clf_15_1.csv
# test_predictions_stack_cat_flow_clf_15_3.csv
# test_predictions_stack_cat_flow_clf_15_7.csv
# test_predictions_stack_cat_flow_clf_3_1.csv
# test_predictions_stack_cat_flow_clf_3_2.csv
# test_predictions_stack_cat_flow_clf_3_3.csv
# test_predictions_stack_cat_flow_clf_9_8.csv
# test_predictions_stack_cat_turbidity_clf_15_15.csv
# test_predictions_stack_cat_turbidity_clf_15_1.csv
# test_predictions_stack_cat_turbidity_clf_15_3.csv
# test_predictions_stack_cat_turbidity_clf_15_7.csv
# test_predictions_stack_cat_turbidity_clf_3_1.csv
# test_predictions_stack_cat_turbidity_clf_3_2.csv
# test_predictions_stack_cat_turbidity_clf_3_3.csv
# test_predictions_stack_cat_turbidity_clf_9_8.csv
# test_predictions_stack_et_100_15_14.csv
# test_predictions_stack_et_100_15_15.csv
# test_predictions_stack_et_100_15_1.csv
# test_predictions_stack_et_100_15_3.csv
# test_predictions_stack_et_100_15_7.csv
# test_predictions_stack_et_100_3_1.csv
# test_predictions_stack_et_100_3_2.csv
# test_predictions_stack_et_100_3_3.csv
# test_predictions_stack_et_100_9_8.csv
# test_predictions_stack_et_100_clf_15_15.csv
# test_predictions_stack_et_100_clf_15_1.csv
# test_predictions_stack_et_100_clf_15_3.csv
# test_predictions_stack_et_100_clf_15_7.csv
# test_predictions_stack_et_100_clf_3_1.csv
# test_predictions_stack_et_100_clf_3_2.csv
# test_predictions_stack_et_100_clf_3_3.csv
# test_predictions_stack_et_100_clf_9_8.csv
# test_predictions_stack_et_100_depth_3_15_15.csv
# test_predictions_stack_et_100_depth_3_15_1.csv
# test_predictions_stack_et_100_depth_3_15_3.csv
# test_predictions_stack_et_100_depth_3_15_7.csv
# test_predictions_stack_et_100_depth_3_3_1.csv
# test_predictions_stack_et_100_depth_3_3_2.csv
# test_predictions_stack_et_100_depth_3_3_3.csv
# test_predictions_stack_et_100_depth_3_9_8.csv
# test_predictions_stack_et_10_hash_15_15.csv
# test_predictions_stack_et_10_hash_15_1.csv
# test_predictions_stack_et_10_hash_15_3.csv
# test_predictions_stack_et_10_hash_15_7.csv
# test_predictions_stack_et_10_hash_3_1.csv
# test_predictions_stack_et_10_hash_3_2.csv
# test_predictions_stack_et_10_hash_3_3.csv
# test_predictions_stack_et_10_hash_9_8.csv
# test_predictions_stack_et_250_15_14.csv
# test_predictions_stack_et_250_15_15.csv
# test_predictions_stack_et_250_15_1.csv
# test_predictions_stack_et_250_15_3.csv
# test_predictions_stack_et_250_15_7.csv
# test_predictions_stack_et_250_3_1.csv
# test_predictions_stack_et_250_3_2.csv
# test_predictions_stack_et_250_3_3.csv
# test_predictions_stack_et_250_9_8.csv
# test_predictions_stack_et_250_clf_15_15.csv
# test_predictions_stack_et_250_clf_15_1.csv
# test_predictions_stack_et_250_clf_15_3.csv
# test_predictions_stack_et_250_clf_15_7.csv
# test_predictions_stack_et_250_clf_3_1.csv
# test_predictions_stack_et_250_clf_3_2.csv
# test_predictions_stack_et_250_clf_3_3.csv
# test_predictions_stack_et_250_clf_9_8.csv
# test_predictions_stack_et_25_15_14.csv
# test_predictions_stack_et_25_15_15.csv
# test_predictions_stack_et_25_15_1.csv
# test_predictions_stack_et_25_15_3.csv
# test_predictions_stack_et_25_15_7.csv
# test_predictions_stack_et_25_3_1.csv
# test_predictions_stack_et_25_3_2.csv
# test_predictions_stack_et_25_3_3.csv
# test_predictions_stack_et_25_9_8.csv
# test_predictions_stack_et_25_mae_15_15.csv
# test_predictions_stack_et_25_mae_15_3.csv
# test_predictions_stack_et_25_mae_3_1.csv
# test_predictions_stack_et_25_mae_3_3.csv
# test_predictions_stack_et_25_mae_9_8.csv
# test_predictions_stack_et_50_15_15.csv
# test_predictions_stack_et_50_15_1.csv
# test_predictions_stack_et_50_15_3.csv
# test_predictions_stack_et_50_15_7.csv
# test_predictions_stack_et_50_3_1.csv
# test_predictions_stack_et_50_3_2.csv
# test_predictions_stack_et_50_3_3.csv
# test_predictions_stack_et_50_9_8.csv
# test_predictions_stack_et_50_clf_15_15.csv
# test_predictions_stack_et_50_clf_15_1.csv
# test_predictions_stack_et_50_clf_15_3.csv
# test_predictions_stack_et_50_clf_15_7.csv
# test_predictions_stack_et_50_clf_3_1.csv
# test_predictions_stack_et_50_clf_3_2.csv
# test_predictions_stack_et_50_clf_3_3.csv
# test_predictions_stack_et_50_clf_9_8.csv
# test_predictions_stack_et_50_hash_15_15.csv
# test_predictions_stack_et_50_hash_15_1.csv
# test_predictions_stack_et_50_hash_15_3.csv
# test_predictions_stack_et_50_hash_15_7.csv
# test_predictions_stack_et_50_hash_3_1.csv
# test_predictions_stack_et_50_hash_3_2.csv
# test_predictions_stack_et_50_hash_3_3.csv
# test_predictions_stack_et_50_hash_9_8.csv
# test_predictions_stack_flow_et_25_return_flow_sum_15_1.csv
# test_predictions_stack_flow_et_25_return_flow_sum_15_2.csv
# test_predictions_stack_flow_et_25_return_flow_sum_3_1.csv
# test_predictions_stack_flow_et_25_return_flow_sum_3_2.csv
# test_predictions_stack_flow_et_25_return_flow_sum_3_3.csv
# test_predictions_stack_flow_et_25_return_flow_sum_9_8.csv
# test_predictions_stack_flow_rf_25_return_flow_sum_15_1.csv
# test_predictions_stack_flow_rf_25_return_flow_sum_15_2.csv
# test_predictions_stack_flow_rf_25_return_flow_sum_15_3.csv
# test_predictions_stack_flow_rf_25_return_flow_sum_3_1.csv
# test_predictions_stack_flow_rf_25_return_flow_sum_3_2.csv
# test_predictions_stack_flow_rf_25_return_flow_sum_3_3.csv
# test_predictions_stack_flow_rf_25_return_flow_sum_9_8.csv
# test_predictions_stack_knn_100_15_14.csv
# test_predictions_stack_knn_100_15_15.csv
# test_predictions_stack_knn_100_15_1.csv
# test_predictions_stack_knn_100_15_3.csv
# test_predictions_stack_knn_100_15_6.csv
# test_predictions_stack_knn_100_15_7.csv
# test_predictions_stack_knn_100_3_1.csv
# test_predictions_stack_knn_100_3_2.csv
# test_predictions_stack_knn_100_3_3.csv
# test_predictions_stack_knn_100_9_8.csv
# test_predictions_stack_knn_10_15_14.csv
# test_predictions_stack_knn_10_15_15.csv
# test_predictions_stack_knn_10_15_1.csv
# test_predictions_stack_knn_10_15_3.csv
# test_predictions_stack_knn_10_15_6.csv
# test_predictions_stack_knn_10_15_7.csv
# test_predictions_stack_knn_10_3_1.csv
# test_predictions_stack_knn_10_3_2.csv
# test_predictions_stack_knn_10_3_3.csv
# test_predictions_stack_knn_10_9_8.csv
# test_predictions_stack_knn_15_15.csv
# test_predictions_stack_knn_15_1.csv
# test_predictions_stack_knn_15_3.csv
# test_predictions_stack_knn_250_15_14.csv
# test_predictions_stack_knn_250_15_15.csv
# test_predictions_stack_knn_250_15_1.csv
# test_predictions_stack_knn_250_15_3.csv
# test_predictions_stack_knn_250_15_6.csv
# test_predictions_stack_knn_250_15_7.csv
# test_predictions_stack_knn_250_3_1.csv
# test_predictions_stack_knn_250_3_2.csv
# test_predictions_stack_knn_250_3_3.csv
# test_predictions_stack_knn_250_9_8.csv
# test_predictions_stack_knn_25_15_1.csv
# test_predictions_stack_knn_25_rbf_15_15.csv
# test_predictions_stack_knn_25_rbf_15_1.csv
# test_predictions_stack_knn_25_rbf_15_3.csv
# test_predictions_stack_knn_25_rbf_15_7.csv
# test_predictions_stack_knn_25_rbf_3_1.csv
# test_predictions_stack_knn_25_rbf_3_2.csv
# test_predictions_stack_knn_25_rbf_3_3.csv
# test_predictions_stack_knn_25_rbf_9_8.csv
# test_predictions_stack_knn_3_1.csv
# test_predictions_stack_knn_3_2.csv
# test_predictions_stack_knn_3_3.csv
# test_predictions_stack_knn_50_15_14.csv
# test_predictions_stack_knn_50_15_15.csv
# test_predictions_stack_knn_50_15_1.csv
# test_predictions_stack_knn_50_15_3.csv
# test_predictions_stack_knn_50_15_6.csv
# test_predictions_stack_knn_50_15_7.csv
# test_predictions_stack_knn_50_3_1.csv
# test_predictions_stack_knn_50_3_2.csv
# test_predictions_stack_knn_50_3_3.csv
# test_predictions_stack_knn_50_9_8.csv
# test_predictions_stack_knn_9_8.csv
# test_predictions_stack_knn_pca_15_14.csv
# test_predictions_stack_knn_pca_15_15.csv
# test_predictions_stack_knn_pca_15_1.csv
# test_predictions_stack_knn_pca_15_3.csv
# test_predictions_stack_knn_pca_15_6.csv
# test_predictions_stack_knn_pca_15_7.csv
# test_predictions_stack_knn_pca_3_1.csv
# test_predictions_stack_knn_pca_3_2.csv
# test_predictions_stack_knn_pca_3_3.csv
# test_predictions_stack_knn_pca_9_8.csv
# test_predictions_stack_lgbm_15_15.csv
# test_predictions_stack_lgbm_15_1.csv
# test_predictions_stack_lgbm_15_3.csv
# test_predictions_stack_lgbm_15_7.csv
# test_predictions_stack_lgbm_3_1.csv
# test_predictions_stack_lgbm_3_2.csv
# test_predictions_stack_lgbm_3_3.csv
# test_predictions_stack_lgbm_9_8.csv
# test_predictions_stack_linear_svr_15_15.csv
# test_predictions_stack_linear_svr_15_1.csv
# test_predictions_stack_linear_svr_15_3.csv
# test_predictions_stack_linear_svr_15_7.csv
# test_predictions_stack_linear_svr_3_1.csv
# test_predictions_stack_linear_svr_3_2.csv
# test_predictions_stack_linear_svr_3_3.csv
# test_predictions_stack_linear_svr_9_8.csv
# test_predictions_stack_logreg_l1_15_15.csv
# test_predictions_stack_logreg_l1_15_3.csv
# test_predictions_stack_logreg_l2_15_15.csv
# test_predictions_stack_lr_15_14.csv
# test_predictions_stack_lr_15_15.csv
# test_predictions_stack_lr_15_1.csv
# test_predictions_stack_lr_15_3.csv
# test_predictions_stack_lr_15_6.csv
# test_predictions_stack_lr_15_7.csv
# test_predictions_stack_lr_3_1.csv
# test_predictions_stack_lr_3_2.csv
# test_predictions_stack_lr_3_3.csv
# test_predictions_stack_lr_9_8.csv
# test_predictions_stack_mlp_15_14.csv
# test_predictions_stack_mlp_15_15.csv
# test_predictions_stack_mlp_15_1.csv
# test_predictions_stack_mlp_15_3.csv
# test_predictions_stack_mlp_15_6.csv
# test_predictions_stack_mlp_15_7.csv
# test_predictions_stack_mlp_3_1.csv
# test_predictions_stack_mlp_3_2.csv
# test_predictions_stack_mlp_3_3.csv
# test_predictions_stack_mlp_9_8.csv
# test_predictions_stack_pca_et_15_15.csv
# test_predictions_stack_pca_et_15_1.csv
# test_predictions_stack_pca_et_15_3.csv
# test_predictions_stack_pca_et_15_7.csv
# test_predictions_stack_pca_et_3_1.csv
# test_predictions_stack_pca_et_3_2.csv
# test_predictions_stack_pca_et_3_3.csv
# test_predictions_stack_pca_et_9_8.csv
# test_predictions_stack_rf_100_15_14.csv
# test_predictions_stack_rf_100_15_15.csv
# test_predictions_stack_rf_100_15_1.csv
# test_predictions_stack_rf_100_15_3.csv
# test_predictions_stack_rf_100_15_7.csv
# test_predictions_stack_rf_100_3_1.csv
# test_predictions_stack_rf_100_3_2.csv
# test_predictions_stack_rf_100_3_3.csv
# test_predictions_stack_rf_100_9_8.csv
# test_predictions_stack_rf_100_clf_15_15.csv
# test_predictions_stack_rf_100_clf_15_1.csv
# test_predictions_stack_rf_100_clf_15_3.csv
# test_predictions_stack_rf_100_clf_15_7.csv
# test_predictions_stack_rf_100_clf_3_1.csv
# test_predictions_stack_rf_100_clf_3_2.csv
# test_predictions_stack_rf_100_clf_3_3.csv
# test_predictions_stack_rf_100_clf_9_8.csv
# test_predictions_stack_rf_250_15_14.csv
# test_predictions_stack_rf_250_15_15.csv
# test_predictions_stack_rf_250_15_1.csv
# test_predictions_stack_rf_250_15_3.csv
# test_predictions_stack_rf_250_15_7.csv
# test_predictions_stack_rf_250_3_1.csv
# test_predictions_stack_rf_250_3_2.csv
# test_predictions_stack_rf_250_3_3.csv
# test_predictions_stack_rf_250_9_8.csv
# test_predictions_stack_rf_25_15_14.csv
# test_predictions_stack_rf_25_15_15.csv
# test_predictions_stack_rf_25_15_1.csv
# test_predictions_stack_rf_25_15_3.csv
# test_predictions_stack_rf_25_15_6.csv
# test_predictions_stack_rf_25_15_7.csv
# test_predictions_stack_rf_25_3_1.csv
# test_predictions_stack_rf_25_3_2.csv
# test_predictions_stack_rf_25_3_3.csv
# test_predictions_stack_rf_25_9_8.csv
# test_predictions_stack_rf_50_clf_15_15.csv
# test_predictions_stack_rf_50_clf_15_1.csv
# test_predictions_stack_rf_50_clf_15_3.csv
# test_predictions_stack_rf_50_clf_15_7.csv
# test_predictions_stack_rf_50_clf_3_1.csv
# test_predictions_stack_rf_50_clf_3_2.csv
# test_predictions_stack_rf_50_clf_3_3.csv
# test_predictions_stack_rf_50_clf_9_8.csv
# test_predictions_stack_rot_et_100_15_15.csv
# test_predictions_stack_rot_et_50_15_15.csv
# test_predictions_stack_rot_rf_25_15_15.csv
# test_predictions_stack_rt_embedding_15_15.csv
# test_predictions_stack_rt_embedding_15_1.csv
# test_predictions_stack_rt_embedding_15_3.csv
# test_predictions_stack_rt_embedding_15_7.csv
# test_predictions_stack_rt_embedding_3_1.csv
# test_predictions_stack_rt_embedding_3_2.csv
# test_predictions_stack_rt_embedding_3_3.csv
# test_predictions_stack_rt_embedding_9_8.csv
# test_predictions_stack_svm_clf_15_15.csv
# test_predictions_stack_svm_clf_15_1.csv
# test_predictions_stack_svm_clf_15_3.csv
# test_predictions_stack_svm_clf_15_7.csv
# test_predictions_stack_svm_clf_3_1.csv
# test_predictions_stack_svm_clf_3_2.csv
# test_predictions_stack_svm_clf_3_3.csv
# test_predictions_stack_svm_clf_9_8.csv
# test_predictions_stack_svr_15_15.csv
# test_predictions_stack_svr_15_1.csv
# test_predictions_stack_svr_15_3.csv
# test_predictions_stack_svr_15_7.csv
# test_predictions_stack_svr_3_1.csv
# test_predictions_stack_svr_3_2.csv
# test_predictions_stack_svr_3_3.csv
# test_predictions_stack_svr_9_8.csv
# test_predictions_stack_svr_C_100_15_15.csv
# test_predictions_stack_svr_C_100_15_1.csv
# test_predictions_stack_svr_C_100_15_3.csv
# test_predictions_stack_svr_C_100_15_7.csv
# test_predictions_stack_svr_C_100_3_1.csv
# test_predictions_stack_svr_C_100_3_2.csv
# test_predictions_stack_svr_C_100_3_3.csv
# test_predictions_stack_svr_C_100_9_8.csv
# test_predictions_stack_turbidity_cat_15_15.csv
# test_predictions_stack_turbidity_lgbm_15_15.csv
# test_predictions_stack_turbidity_lgbm_15_1.csv
# test_predictions_stack_turbidity_lgbm_15_3.csv
# test_predictions_stack_turbidity_lgbm_15_7.csv
# test_predictions_stack_turbidity_lgbm_3_1.csv
# test_predictions_stack_turbidity_lgbm_3_3.csv
# test_predictions_stack_turbidity_lgbm_9_8.csv
# test_predictions_stack_turbidity_xgb_15_15.csv
# test_predictions_stack_turbidity_xgb_15_1.csv
# test_predictions_stack_xgb_15_14.csv
# test_predictions_stack_xgb_15_15.csv
# test_predictions_stack_xgb_15_1.csv
# test_predictions_stack_xgb_15_2.csv
# test_predictions_stack_xgb_15_3.csv
# test_predictions_stack_xgb_15_6.csv
# test_predictions_stack_xgb_15_7.csv
# test_predictions_stack_xgb_3_1.csv
# test_predictions_stack_xgb_3_2.csv
# test_predictions_stack_xgb_3_3.csv
# test_predictions_stack_xgb_9_8.csv
# test_preds_per_phase.p
# test_values.csv
# test_values_sample.csv
# train_features_14.csv
# train_features_15_14.csv
# train_features_15_15.csv
# train_features_15_1.csv
# train_features_15_2.csv
# train_features_15_3.csv
# train_features_15_6.csv
# train_features_15_7.csv
# train_features_15.csv
# train_features_1.csv
# train_features_2.csv
# train_features_3_1.csv
# train_features_3_2.csv
# train_features_3_3.csv
# train_features_3.csv
# train_features_6.csv
# train_features_7.csv
# train_features_8.csv
# train_features_9_8.csv
# train_features_adv_14.csv
# train_features_adv_15.csv
# train_features_adv_1.csv
# train_features_adv_2.csv
# train_features_adv_3.csv
# train_features_adv_6.csv
# train_features_adv_7.csv
# train_features_adv_8.csv
# train_features_per_phase_14.csv
# train_features_per_phase_15.csv
# train_features_per_phase_1.csv
# train_features_per_phase_2.csv
# train_features_per_phase_3.csv
# train_features_per_phase_6.csv
# train_features_per_phase_7.csv
# train_features_per_phase_8.csv
# train_features_sel_15.csv
# train_labels.csv
# train_predictions_knn_3_1.csv
# train_predictions_knn_pca_3_1.csv
# train_predictions_lr_3_1.csv
# train_predictions_stack_ada_250_15_1.csv
# train_predictions_stack_ada_250_15_3.csv
# train_predictions_stack_ada_50_15_15.csv
# train_predictions_stack_ada_50_15_1.csv
# train_predictions_stack_ada_50_15_3.csv
# train_predictions_stack_ada_50_15_7.csv
# train_predictions_stack_ada_50_3_1.csv
# train_predictions_stack_ada_50_3_2.csv
# train_predictions_stack_ada_50_3_3.csv
# train_predictions_stack_ada_50_9_8.csv
# train_predictions_stack_bay_lr_15_15.csv
# train_predictions_stack_bay_lr_15_1.csv
# train_predictions_stack_bay_lr_15_3.csv
# train_predictions_stack_bay_lr_15_7.csv
# train_predictions_stack_bay_lr_3_1.csv
# train_predictions_stack_bay_lr_3_2.csv
# train_predictions_stack_bay_lr_3_3.csv
# train_predictions_stack_bay_lr_9_8.csv
# train_predictions_stack_cat_clf_15_15.csv
# train_predictions_stack_cat_clf_15_1.csv
# train_predictions_stack_cat_clf_15_3.csv
# train_predictions_stack_cat_clf_15_7.csv
# train_predictions_stack_cat_flow_clf_15_15.csv
# train_predictions_stack_cat_flow_clf_15_1.csv
# train_predictions_stack_cat_flow_clf_15_3.csv
# train_predictions_stack_cat_flow_clf_15_7.csv
# train_predictions_stack_cat_flow_clf_3_1.csv
# train_predictions_stack_cat_flow_clf_3_2.csv
# train_predictions_stack_cat_flow_clf_3_3.csv
# train_predictions_stack_cat_flow_clf_9_8.csv
# train_predictions_stack_cat_turbidity_clf_15_15.csv
# train_predictions_stack_cat_turbidity_clf_15_1.csv
# train_predictions_stack_cat_turbidity_clf_15_3.csv
# train_predictions_stack_cat_turbidity_clf_15_7.csv
# train_predictions_stack_cat_turbidity_clf_3_1.csv
# train_predictions_stack_cat_turbidity_clf_3_2.csv
# train_predictions_stack_cat_turbidity_clf_3_3.csv
# train_predictions_stack_cat_turbidity_clf_9_8.csv
# train_predictions_stack_et_100_15_14.csv
# train_predictions_stack_et_100_15_15.csv
# train_predictions_stack_et_100_15_1.csv
# train_predictions_stack_et_100_15_3.csv
# train_predictions_stack_et_100_15_7.csv
# train_predictions_stack_et_100_3_1.csv
# train_predictions_stack_et_100_3_2.csv
# train_predictions_stack_et_100_3_3.csv
# train_predictions_stack_et_100_9_8.csv
# train_predictions_stack_et_100_clf_15_15.csv
# train_predictions_stack_et_100_clf_15_1.csv
# train_predictions_stack_et_100_clf_15_3.csv
# train_predictions_stack_et_100_clf_15_7.csv
# train_predictions_stack_et_100_clf_3_1.csv
# train_predictions_stack_et_100_clf_3_2.csv
# train_predictions_stack_et_100_clf_3_3.csv
# train_predictions_stack_et_100_clf_9_8.csv
# train_predictions_stack_et_100_depth_3_15_15.csv
# train_predictions_stack_et_100_depth_3_15_1.csv
# train_predictions_stack_et_100_depth_3_15_3.csv
# train_predictions_stack_et_100_depth_3_15_7.csv
# train_predictions_stack_et_100_depth_3_3_1.csv
# train_predictions_stack_et_100_depth_3_3_2.csv
# train_predictions_stack_et_100_depth_3_3_3.csv
# train_predictions_stack_et_100_depth_3_9_8.csv
# train_predictions_stack_et_10_hash_15_15.csv
# train_predictions_stack_et_10_hash_15_1.csv
# train_predictions_stack_et_10_hash_15_3.csv
# train_predictions_stack_et_10_hash_15_7.csv
# train_predictions_stack_et_10_hash_3_1.csv
# train_predictions_stack_et_10_hash_3_2.csv
# train_predictions_stack_et_10_hash_3_3.csv
# train_predictions_stack_et_10_hash_9_8.csv
# train_predictions_stack_et_250_15_14.csv
# train_predictions_stack_et_250_15_15.csv
# train_predictions_stack_et_250_15_1.csv
# train_predictions_stack_et_250_15_3.csv
# train_predictions_stack_et_250_15_7.csv
# train_predictions_stack_et_250_3_1.csv
# train_predictions_stack_et_250_3_2.csv
# train_predictions_stack_et_250_3_3.csv
# train_predictions_stack_et_250_9_8.csv
# train_predictions_stack_et_250_clf_15_15.csv
# train_predictions_stack_et_250_clf_15_1.csv
# train_predictions_stack_et_250_clf_15_3.csv
# train_predictions_stack_et_250_clf_15_7.csv
# train_predictions_stack_et_250_clf_3_1.csv
# train_predictions_stack_et_250_clf_3_2.csv
# train_predictions_stack_et_250_clf_3_3.csv
# train_predictions_stack_et_250_clf_9_8.csv
# train_predictions_stack_et_25_15_14.csv
# train_predictions_stack_et_25_15_15.csv
# train_predictions_stack_et_25_15_1.csv
# train_predictions_stack_et_25_15_3.csv
# train_predictions_stack_et_25_15_7.csv
# train_predictions_stack_et_25_3_1.csv
# train_predictions_stack_et_25_3_2.csv
# train_predictions_stack_et_25_3_3.csv
# train_predictions_stack_et_25_9_8.csv
# train_predictions_stack_et_25_mae_15_15.csv
# train_predictions_stack_et_25_mae_15_3.csv
# train_predictions_stack_et_25_mae_3_1.csv
# train_predictions_stack_et_25_mae_3_3.csv
# train_predictions_stack_et_25_mae_9_8.csv
# train_predictions_stack_et_50_15_15.csv
# train_predictions_stack_et_50_15_1.csv
# train_predictions_stack_et_50_15_3.csv
# train_predictions_stack_et_50_15_7.csv
# train_predictions_stack_et_50_3_1.csv
# train_predictions_stack_et_50_3_2.csv
# train_predictions_stack_et_50_3_3.csv
# train_predictions_stack_et_50_9_8.csv
# train_predictions_stack_et_50_clf_15_15.csv
# train_predictions_stack_et_50_clf_15_1.csv
# train_predictions_stack_et_50_clf_15_3.csv
# train_predictions_stack_et_50_clf_15_7.csv
# train_predictions_stack_et_50_clf_3_1.csv
# train_predictions_stack_et_50_clf_3_2.csv
# train_predictions_stack_et_50_clf_3_3.csv
# train_predictions_stack_et_50_clf_9_8.csv
# train_predictions_stack_et_50_hash_15_15.csv
# train_predictions_stack_et_50_hash_15_1.csv
# train_predictions_stack_et_50_hash_15_3.csv
# train_predictions_stack_et_50_hash_15_7.csv
# train_predictions_stack_et_50_hash_3_1.csv
# train_predictions_stack_et_50_hash_3_2.csv
# train_predictions_stack_et_50_hash_3_3.csv
# train_predictions_stack_et_50_hash_9_8.csv
# train_predictions_stack_flow_et_25_return_flow_sum_15_1.csv
# train_predictions_stack_flow_et_25_return_flow_sum_15_2.csv
# train_predictions_stack_flow_et_25_return_flow_sum_3_1.csv
# train_predictions_stack_flow_et_25_return_flow_sum_3_2.csv
# train_predictions_stack_flow_et_25_return_flow_sum_3_3.csv
# train_predictions_stack_flow_et_25_return_flow_sum_9_8.csv
# train_predictions_stack_flow_lgbm_15_15.csv
# train_predictions_stack_flow_lgbm_15_1.csv
# train_predictions_stack_flow_lgbm_15_2.csv
# train_predictions_stack_flow_lgbm_15_3.csv
# train_predictions_stack_flow_lgbm_15_7.csv
# train_predictions_stack_flow_lgbm_3_1.csv
# train_predictions_stack_flow_lgbm_3_2.csv
# train_predictions_stack_flow_lgbm_3_3.csv
# train_predictions_stack_flow_lgbm_9_8.csv
# train_predictions_stack_flow_rf_25_return_flow_sum_15_1.csv
# train_predictions_stack_flow_rf_25_return_flow_sum_15_2.csv
# train_predictions_stack_flow_rf_25_return_flow_sum_15_3.csv
# train_predictions_stack_flow_rf_25_return_flow_sum_3_1.csv
# train_predictions_stack_flow_rf_25_return_flow_sum_3_2.csv
# train_predictions_stack_flow_rf_25_return_flow_sum_3_3.csv
# train_predictions_stack_flow_rf_25_return_flow_sum_9_8.csv
# train_predictions_stack_flow_xgb_15_14.csv
# train_predictions_stack_flow_xgb_15_15.csv
# train_predictions_stack_flow_xgb_15_1.csv
# train_predictions_stack_flow_xgb_15_2.csv
# train_predictions_stack_flow_xgb_15_3.csv
# train_predictions_stack_flow_xgb_15_6.csv
# train_predictions_stack_flow_xgb_15_7.csv
# train_predictions_stack_flow_xgb_3_1.csv
# train_predictions_stack_flow_xgb_3_2.csv
# train_predictions_stack_flow_xgb_3_3.csv
# train_predictions_stack_flow_xgb_9_8.csv
# train_predictions_stack_knn_100_15_14.csv
# train_predictions_stack_knn_100_15_15.csv
# train_predictions_stack_knn_100_15_1.csv
# train_predictions_stack_knn_100_15_3.csv
# train_predictions_stack_knn_100_15_6.csv
# train_predictions_stack_knn_100_15_7.csv
# train_predictions_stack_knn_100_3_1.csv
# train_predictions_stack_knn_100_3_2.csv
# train_predictions_stack_knn_100_3_3.csv
# train_predictions_stack_knn_100_9_8.csv
# train_predictions_stack_knn_10_15_14.csv
# train_predictions_stack_knn_10_15_15.csv
# train_predictions_stack_knn_10_15_1.csv
# train_predictions_stack_knn_10_15_3.csv
# train_predictions_stack_knn_10_15_6.csv
# train_predictions_stack_knn_10_15_7.csv
# train_predictions_stack_knn_10_3_1.csv
# train_predictions_stack_knn_10_3_2.csv
# train_predictions_stack_knn_10_3_3.csv
# train_predictions_stack_knn_10_9_8.csv
# train_predictions_stack_knn_15_15.csv
# train_predictions_stack_knn_15_1.csv
# train_predictions_stack_knn_15_3.csv
# train_predictions_stack_knn_250_15_14.csv
# train_predictions_stack_knn_250_15_15.csv
# train_predictions_stack_knn_250_15_1.csv
# train_predictions_stack_knn_250_15_3.csv
# train_predictions_stack_knn_250_15_6.csv
# train_predictions_stack_knn_250_15_7.csv
# train_predictions_stack_knn_250_3_1.csv
# train_predictions_stack_knn_250_3_2.csv
# train_predictions_stack_knn_250_3_3.csv
# train_predictions_stack_knn_250_9_8.csv
# train_predictions_stack_knn_25_15_1.csv
# train_predictions_stack_knn_25_rbf_15_15.csv
# train_predictions_stack_knn_25_rbf_15_1.csv
# train_predictions_stack_knn_25_rbf_15_3.csv
# train_predictions_stack_knn_25_rbf_15_7.csv
# train_predictions_stack_knn_25_rbf_3_1.csv
# train_predictions_stack_knn_25_rbf_3_2.csv
# train_predictions_stack_knn_25_rbf_3_3.csv
# train_predictions_stack_knn_25_rbf_9_8.csv
# train_predictions_stack_knn_3_1.csv
# train_predictions_stack_knn_3_2.csv
# train_predictions_stack_knn_3_3.csv
# train_predictions_stack_knn_50_15_14.csv
# train_predictions_stack_knn_50_15_15.csv
# train_predictions_stack_knn_50_15_1.csv
# train_predictions_stack_knn_50_15_3.csv
# train_predictions_stack_knn_50_15_6.csv
# train_predictions_stack_knn_50_15_7.csv
# train_predictions_stack_knn_50_3_1.csv
# train_predictions_stack_knn_50_3_2.csv
# train_predictions_stack_knn_50_3_3.csv
# train_predictions_stack_knn_50_9_8.csv
# train_predictions_stack_knn_9_8.csv
# train_predictions_stack_knn_pca_15_14.csv
# train_predictions_stack_knn_pca_15_15.csv
# train_predictions_stack_knn_pca_15_1.csv
# train_predictions_stack_knn_pca_15_3.csv
# train_predictions_stack_knn_pca_15_6.csv
# train_predictions_stack_knn_pca_15_7.csv
# train_predictions_stack_knn_pca_3_1.csv
# train_predictions_stack_knn_pca_3_2.csv
# train_predictions_stack_knn_pca_3_3.csv
# train_predictions_stack_knn_pca_9_8.csv
# train_predictions_stack_lgbm_15_15.csv
# train_predictions_stack_lgbm_15_1.csv
# train_predictions_stack_lgbm_15_3.csv
# train_predictions_stack_lgbm_15_7.csv
# train_predictions_stack_lgbm_3_1.csv
# train_predictions_stack_lgbm_3_2.csv
# train_predictions_stack_lgbm_3_3.csv
# train_predictions_stack_lgbm_9_8.csv
# train_predictions_stack_linear_svr_15_15.csv
# train_predictions_stack_linear_svr_15_1.csv
# train_predictions_stack_linear_svr_15_3.csv
# train_predictions_stack_linear_svr_15_7.csv
# train_predictions_stack_linear_svr_3_1.csv
# train_predictions_stack_linear_svr_3_2.csv
# train_predictions_stack_linear_svr_3_3.csv
# train_predictions_stack_linear_svr_9_8.csv
# train_predictions_stack_logreg_l1_15_15.csv
# train_predictions_stack_logreg_l1_15_3.csv
# train_predictions_stack_logreg_l2_15_15.csv
# train_predictions_stack_lr_15_14.csv
# train_predictions_stack_lr_15_15.csv
# train_predictions_stack_lr_15_1.csv
# train_predictions_stack_lr_15_3.csv
# train_predictions_stack_lr_15_6.csv
# train_predictions_stack_lr_15_7.csv
# train_predictions_stack_lr_3_1.csv
# train_predictions_stack_lr_3_2.csv
# train_predictions_stack_lr_3_3.csv
# train_predictions_stack_lr_9_8.csv
# train_predictions_stack_mlp_15_14.csv
# train_predictions_stack_mlp_15_15.csv
# train_predictions_stack_mlp_15_1.csv
# train_predictions_stack_mlp_15_3.csv
# train_predictions_stack_mlp_15_6.csv
# train_predictions_stack_mlp_15_7.csv
# train_predictions_stack_mlp_3_1.csv
# train_predictions_stack_mlp_3_2.csv
# train_predictions_stack_mlp_3_3.csv
# train_predictions_stack_mlp_9_8.csv
# train_predictions_stack_pca_et_15_15.csv
# train_predictions_stack_pca_et_15_1.csv
# train_predictions_stack_pca_et_15_3.csv
# train_predictions_stack_pca_et_15_7.csv
# train_predictions_stack_pca_et_3_1.csv
# train_predictions_stack_pca_et_3_2.csv
# train_predictions_stack_pca_et_3_3.csv
# train_predictions_stack_pca_et_9_8.csv
# train_predictions_stack_rf_100_15_14.csv
# train_predictions_stack_rf_100_15_15.csv
# train_predictions_stack_rf_100_15_1.csv
# train_predictions_stack_rf_100_15_3.csv
# train_predictions_stack_rf_100_15_7.csv
# train_predictions_stack_rf_100_3_1.csv
# train_predictions_stack_rf_100_3_2.csv
# train_predictions_stack_rf_100_3_3.csv
# train_predictions_stack_rf_100_9_8.csv
# train_predictions_stack_rf_100_clf_15_15.csv
# train_predictions_stack_rf_100_clf_15_1.csv
# train_predictions_stack_rf_100_clf_15_3.csv
# train_predictions_stack_rf_100_clf_15_7.csv
# train_predictions_stack_rf_100_clf_3_1.csv
# train_predictions_stack_rf_100_clf_3_2.csv
# train_predictions_stack_rf_100_clf_3_3.csv
# train_predictions_stack_rf_100_clf_9_8.csv
# train_predictions_stack_rf_250_15_14.csv
# train_predictions_stack_rf_250_15_15.csv
# train_predictions_stack_rf_250_15_1.csv
# train_predictions_stack_rf_250_15_3.csv
# train_predictions_stack_rf_250_15_7.csv
# train_predictions_stack_rf_250_3_1.csv
# train_predictions_stack_rf_250_3_2.csv
# train_predictions_stack_rf_250_3_3.csv
# train_predictions_stack_rf_250_9_8.csv
# train_predictions_stack_rf_25_15_14.csv
# train_predictions_stack_rf_25_15_15.csv
# train_predictions_stack_rf_25_15_1.csv
# train_predictions_stack_rf_25_15_3.csv
# train_predictions_stack_rf_25_15_6.csv
# train_predictions_stack_rf_25_15_7.csv
# train_predictions_stack_rf_25_3_1.csv
# train_predictions_stack_rf_25_3_2.csv
# train_predictions_stack_rf_25_3_3.csv
# train_predictions_stack_rf_25_9_8.csv
# train_predictions_stack_rf_50_clf_15_15.csv
# train_predictions_stack_rf_50_clf_15_1.csv
# train_predictions_stack_rf_50_clf_15_3.csv
# train_predictions_stack_rf_50_clf_15_7.csv
# train_predictions_stack_rf_50_clf_3_1.csv
# train_predictions_stack_rf_50_clf_3_2.csv
# train_predictions_stack_rf_50_clf_3_3.csv
# train_predictions_stack_rf_50_clf_9_8.csv
# train_predictions_stack_rot_et_100_15_15.csv
# train_predictions_stack_rot_et_50_15_15.csv
# train_predictions_stack_rot_rf_25_15_15.csv
# train_predictions_stack_rt_embedding_15_15.csv
# train_predictions_stack_rt_embedding_15_1.csv
# train_predictions_stack_rt_embedding_15_3.csv
# train_predictions_stack_rt_embedding_15_7.csv
# train_predictions_stack_rt_embedding_3_1.csv
# train_predictions_stack_rt_embedding_3_2.csv
# train_predictions_stack_rt_embedding_3_3.csv
# train_predictions_stack_rt_embedding_9_8.csv
# train_predictions_stack_svm_clf_15_15.csv
# train_predictions_stack_svm_clf_15_1.csv
# train_predictions_stack_svm_clf_15_3.csv
# train_predictions_stack_svm_clf_15_7.csv
# train_predictions_stack_svm_clf_3_1.csv
# train_predictions_stack_svm_clf_3_2.csv
# train_predictions_stack_svm_clf_3_3.csv
# train_predictions_stack_svm_clf_9_8.csv
# train_predictions_stack_svr_15_15.csv
# train_predictions_stack_svr_15_1.csv
# train_predictions_stack_svr_15_3.csv
# train_predictions_stack_svr_15_7.csv
# train_predictions_stack_svr_3_1.csv
# train_predictions_stack_svr_3_2.csv
# train_predictions_stack_svr_3_3.csv
# train_predictions_stack_svr_9_8.csv
# train_predictions_stack_svr_C_100_15_15.csv
# train_predictions_stack_svr_C_100_15_1.csv
# train_predictions_stack_svr_C_100_15_3.csv
# train_predictions_stack_svr_C_100_15_7.csv
# train_predictions_stack_svr_C_100_3_1.csv
# train_predictions_stack_svr_C_100_3_2.csv
# train_predictions_stack_svr_C_100_3_3.csv
# train_predictions_stack_svr_C_100_9_8.csv
# train_predictions_stack_turbidity_cat_15_15.csv
# train_predictions_stack_turbidity_lgbm_15_15.csv
# train_predictions_stack_turbidity_lgbm_15_1.csv
# train_predictions_stack_turbidity_lgbm_15_3.csv
# train_predictions_stack_turbidity_lgbm_15_7.csv
# train_predictions_stack_turbidity_lgbm_3_1.csv
# train_predictions_stack_turbidity_lgbm_3_3.csv
# train_predictions_stack_turbidity_lgbm_9_8.csv
# train_predictions_stack_turbidity_xgb_15_14.csv
# train_predictions_stack_turbidity_xgb_15_15.csv
# train_predictions_stack_turbidity_xgb_15_1.csv
# train_predictions_stack_turbidity_xgb_15_2.csv
# train_predictions_stack_turbidity_xgb_15_3.csv
# train_predictions_stack_turbidity_xgb_15_6.csv
# train_predictions_stack_turbidity_xgb_15_7.csv
# train_predictions_stack_turbidity_xgb_3_1.csv
# train_predictions_stack_turbidity_xgb_3_2.csv
# train_predictions_stack_turbidity_xgb_3_3.csv
# train_predictions_stack_turbidity_xgb_9_8.csv
# train_predictions_stack_xgb_15_14.csv
# train_predictions_stack_xgb_15_15.csv
# train_predictions_stack_xgb_15_1.csv
# train_predictions_stack_xgb_15_2.csv
# train_predictions_stack_xgb_15_3.csv
# train_predictions_stack_xgb_15_6.csv
# train_predictions_stack_xgb_15_7.csv
# train_predictions_stack_xgb_3_1.csv
# train_predictions_stack_xgb_3_2.csv
# train_predictions_stack_xgb_3_3.csv
# train_predictions_stack_xgb_9_8.csv
# train_preds_per_phase.p
# train_values.csv
# train_values_sample.csv
# tsfresh_all_per_phase_combination_adv.csv
# tsfresh_all_per_phase_combination.csv
# tsfresh_features_14.csv
# tsfresh_features_15.csv
# tsfresh_features_1.csv
# tsfresh_features_2.csv
# tsfresh_features_3.csv
# tsfresh_features_6.csv
# tsfresh_features_7.csv
# tsfresh_features_8.csv
# tsfresh_features.csv
# tsfresh_features_object_low_level_14.csv
# tsfresh_features_object_low_level_1.csv
# tsfresh_features_object_low_level_2.csv
# tsfresh_features_object_low_level_3.csv
# tsfresh_features_object_low_level_6.csv
# tsfresh_features_object_low_level_7.csv
# tsfresh_features_return_acid_14.csv
# tsfresh_features_return_acid_1.csv
# tsfresh_features_return_acid_2.csv
# tsfresh_features_return_acid_3.csv
# tsfresh_features_return_acid_6.csv
# tsfresh_features_return_acid_7.csv
# tsfresh_features_return_caustic_14.csv
# tsfresh_features_return_caustic_1.csv
# tsfresh_features_return_caustic_2.csv
# tsfresh_features_return_caustic_3.csv
# tsfresh_features_return_caustic_6.csv
# tsfresh_features_return_caustic_7.csv
# tsfresh_features_return_conductivity_14.csv
# tsfresh_features_return_conductivity_1.csv
# tsfresh_features_return_conductivity_2.csv
# tsfresh_features_return_conductivity_3.csv
# tsfresh_features_return_conductivity_6.csv
# tsfresh_features_return_conductivity_7.csv
# tsfresh_features_return_drain_14.csv
# tsfresh_features_return_drain_1.csv
# tsfresh_features_return_drain_2.csv
# tsfresh_features_return_drain_3.csv
# tsfresh_features_return_drain_6.csv
# tsfresh_features_return_drain_7.csv
# tsfresh_features_return_flow_14.csv
# tsfresh_features_return_flow_1.csv
# tsfresh_features_return_flow_2.csv
# tsfresh_features_return_flow_3.csv
# tsfresh_features_return_flow_6.csv
# tsfresh_features_return_flow_7.csv
# tsfresh_features_return_recovery_water_14.csv
# tsfresh_features_return_recovery_water_1.csv
# tsfresh_features_return_recovery_water_2.csv
# tsfresh_features_return_recovery_water_3.csv
# tsfresh_features_return_recovery_water_6.csv
# tsfresh_features_return_recovery_water_7.csv
# tsfresh_features_return_temperature_14.csv
# tsfresh_features_return_temperature_1.csv
# tsfresh_features_return_temperature_2.csv
# tsfresh_features_return_temperature_3.csv
# tsfresh_features_return_temperature_6.csv
# tsfresh_features_return_temperature_7.csv
# tsfresh_features_return_turbidity_14.csv
# tsfresh_features_return_turbidity_1.csv
# tsfresh_features_return_turbidity_2.csv
# tsfresh_features_return_turbidity_3.csv
# tsfresh_features_return_turbidity_6.csv
# tsfresh_features_return_turbidity_7.csv
# tsfresh_features_supply_acid_14.csv
# tsfresh_features_supply_acid_1.csv
# tsfresh_features_supply_acid_2.csv
# tsfresh_features_supply_acid_3.csv
# tsfresh_features_supply_acid_6.csv
# tsfresh_features_supply_acid_7.csv
# tsfresh_features_supply_caustic_14.csv
# tsfresh_features_supply_caustic_1.csv
# tsfresh_features_supply_caustic_2.csv
# tsfresh_features_supply_caustic_3.csv
# tsfresh_features_supply_caustic_6.csv
# tsfresh_features_supply_caustic_7.csv
# tsfresh_features_supply_clean_water_14.csv
# tsfresh_features_supply_clean_water_1.csv
# tsfresh_features_supply_clean_water_2.csv
# tsfresh_features_supply_clean_water_3.csv
# tsfresh_features_supply_clean_water_6.csv
# tsfresh_features_supply_clean_water_7.csv
# tsfresh_features_supply_flow_14.csv
# tsfresh_features_supply_flow_1.csv
# tsfresh_features_supply_flow_2.csv
# tsfresh_features_supply_flow_3.csv
# tsfresh_features_supply_flow_6.csv
# tsfresh_features_supply_flow_7.csv
# tsfresh_features_supply_pre_rinse_14.csv
# tsfresh_features_supply_pre_rinse_1.csv
# tsfresh_features_supply_pre_rinse_2.csv
# tsfresh_features_supply_pre_rinse_3.csv
# tsfresh_features_supply_pre_rinse_6.csv
# tsfresh_features_supply_pre_rinse_7.csv
# tsfresh_features_supply_pressure_14.csv
# tsfresh_features_supply_pressure_1.csv
# tsfresh_features_supply_pressure_2.csv
# tsfresh_features_supply_pressure_3.csv
# tsfresh_features_supply_pressure_6.csv
# tsfresh_features_supply_pressure_7.csv
# tsfresh_features_supply_pump_14.csv
# tsfresh_features_supply_pump_1.csv
# tsfresh_features_supply_pump_2.csv
# tsfresh_features_supply_pump_3.csv
# tsfresh_features_supply_pump_6.csv
# tsfresh_features_supply_pump_7.csv
# tsfresh_features_tank_concentration_acid_14.csv
# tsfresh_features_tank_concentration_acid_1.csv
# tsfresh_features_tank_concentration_acid_2.csv
# tsfresh_features_tank_concentration_acid_3.csv
# tsfresh_features_tank_concentration_acid_6.csv
# tsfresh_features_tank_concentration_acid_7.csv
# tsfresh_features_tank_concentration_caustic_14.csv
# tsfresh_features_tank_concentration_caustic_1.csv
# tsfresh_features_tank_concentration_caustic_2.csv
# tsfresh_features_tank_concentration_caustic_3.csv
# tsfresh_features_tank_concentration_caustic_6.csv
# tsfresh_features_tank_concentration_caustic_7.csv
# tsfresh_features_tank_level_acid_14.csv
# tsfresh_features_tank_level_acid_1.csv
# tsfresh_features_tank_level_acid_2.csv
# tsfresh_features_tank_level_acid_3.csv
# tsfresh_features_tank_level_acid_6.csv
# tsfresh_features_tank_level_acid_7.csv
# tsfresh_features_tank_level_caustic_14.csv
# tsfresh_features_tank_level_caustic_1.csv
# tsfresh_features_tank_level_caustic_2.csv
# tsfresh_features_tank_level_caustic_3.csv
# tsfresh_features_tank_level_caustic_6.csv
# tsfresh_features_tank_level_caustic_7.csv
# tsfresh_features_tank_level_clean_water_14.csv
# tsfresh_features_tank_level_clean_water_1.csv
# tsfresh_features_tank_level_clean_water_2.csv
# tsfresh_features_tank_level_clean_water_3.csv
# tsfresh_features_tank_level_clean_water_6.csv
# tsfresh_features_tank_level_clean_water_7.csv
# tsfresh_features_tank_level_pre_rinse_14.csv
# tsfresh_features_tank_level_pre_rinse_1.csv
# tsfresh_features_tank_level_pre_rinse_2.csv
# tsfresh_features_tank_level_pre_rinse_3.csv
# tsfresh_features_tank_level_pre_rinse_6.csv
# tsfresh_features_tank_level_pre_rinse_7.csv
# tsfresh_features_tank_temperature_acid_14.csv
# tsfresh_features_tank_temperature_acid_1.csv
# tsfresh_features_tank_temperature_acid_2.csv
# tsfresh_features_tank_temperature_acid_3.csv
# tsfresh_features_tank_temperature_acid_6.csv
# tsfresh_features_tank_temperature_acid_7.csv
# tsfresh_features_tank_temperature_caustic_14.csv
# tsfresh_features_tank_temperature_caustic_1.csv
# tsfresh_features_tank_temperature_caustic_2.csv
# tsfresh_features_tank_temperature_caustic_3.csv
# tsfresh_features_tank_temperature_caustic_6.csv
# tsfresh_features_tank_temperature_caustic_7.csv
# tsfresh_features_tank_temperature_pre_rinse_14.csv
# tsfresh_features_tank_temperature_pre_rinse_1.csv
# tsfresh_features_tank_temperature_pre_rinse_2.csv
# tsfresh_features_tank_temperature_pre_rinse_3.csv
# tsfresh_features_tank_temperature_pre_rinse_6.csv
# tsfresh_features_tank_temperature_pre_rinse_7.csv
# tsfresh_mix_per_phase_combination_adv.csv
# tsfresh_none_per_phase_combination_adv.csv
# val_features_adv_14.csv
# val_features_adv_15.csv
# val_features_adv_1.csv
# val_features_adv_2.csv
# val_features_adv_3.csv
# val_features_adv_6.csv
# val_features_adv_7.csv
# val_features_adv_8.csv
# val_features_sel_15.csv
# val_preds_per_phase.p

# %%
def custom_mape(approxes, targets):
    return np.mean(np.abs(np.subtract(approxes, targets)) / np.maximum(np.abs(targets), 290000))

def fit_stack(clf, name, X_train, y_train, X_test, train_index, test_index, 
              n_splits=5):  
  train_predictions = np.zeros((len(X_train),))
  test_predictions = np.zeros((len(X_test), n_splits))
  kf = KFold(n_splits=n_splits, shuffle=True)
  for fold_ix, (train_idx, test_idx) in enumerate(kf.split(X_train, y_train)):
    X_cv_train = X_train[train_idx, :]
    X_cv_test = X_train[test_idx, :]
    y_cv_train = y_train[train_idx]
    y_cv_test = y_train[test_idx]
    
    clf_clone = clone(clf)
    clf_clone.fit(X_cv_train, y_cv_train)
    
    print('[{}] Fold #{} MAPE={}'.format(name, fold_ix + 1, custom_mape(np.exp(y_cv_test), np.exp(clf_clone.predict(X_cv_test)))))
    
    train_predictions[test_idx] = np.minimum(np.max(y_cv_train), np.maximum(0, clf_clone.predict(X_cv_test)))
    test_predictions[:, fold_ix] = np.minimum(np.max(y_cv_train), np.maximum(0, clf_clone.predict(X_test)))
    
  train_predictions_df = pd.DataFrame(train_predictions, index=train_index, columns=['{}_pred'.format(name)])
  
  # Taking min instead of mean, since undershooting is better than overshooting for MAPE
  # TODO: This changed to mean for now
  test_predictions_df = pd.DataFrame(np.mean(test_predictions, axis=1), index=test_index, columns=['{}_pred'.format(name)])
    
  return train_predictions_df, test_predictions_df

def get_corr_features(X):
  row_idx, col_idx = np.where(X.corr() == 1)
  self_corr = set([(i, i) for i in range(X.shape[1])])
  return set(list(zip(row_idx, col_idx))) - self_corr 

def get_uncorr_features(data):
  X_train_corr = data.copy()
  correlated_features = get_corr_features(X_train_corr)
  
  corr_cols = set()
  for row_idx, col_idx in correlated_features:
    corr_cols.add(row_idx)
    corr_cols.add(col_idx)
  
  uncorr_cols = list(set(X_train_corr.columns) - set(X_train_corr.columns[list(corr_cols)]))
   
  col_mask = [False]*X_train_corr.shape[1]
  for col in corr_cols:
    col_mask[col] = True
  X_train_corr = X_train_corr.loc[:, col_mask]
  
  correlated_features = get_corr_features(X_train_corr)
  
  while correlated_features:
    print('{} correlated feature pairs left...'.format(len(correlated_features)))
    corr_row, corr_col = correlated_features.pop()
    col_mask = [True]*X_train_corr.shape[1]
    col_mask[corr_row] = False
    X_train_corr = X_train_corr.loc[:, col_mask]
    correlated_features = get_corr_features(X_train_corr)
  return list(set(list(X_train_corr.columns) + uncorr_cols))

def remove_features(data, target, p_val=0.25):
  single_cols = list(data.columns[data.nunique() == 1])
  
  uncorr_cols = get_uncorr_features(data)
  corr_cols = list(set(data.columns) - set(uncorr_cols))
  
  return list(set(single_cols + corr_cols))

# %%
from sklearn.feature_extraction import FeatureHasher
from sklearn.svm import SVR, LinearSVR, SVC
from sklearn.linear_model import BayesianRidge, LogisticRegression
from sklearn.kernel_approximation import RBFSampler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

from mord import OrdinalRidge, LAD

combinations_per_recipe = {
    3: [3, 1, 2],  # 1, 2, 
    9: [8],
    15: [15]#, 3, 7, 1, 2, 6, 14]
}

prediction_df = None
import warnings; warnings.filterwarnings('ignore')
for recipe in [15]:
  for process_combination in combinations_per_recipe[recipe]:
    train_features = pd.read_csv('/content/drive/My Drive/Rinse Over Run/train_features_{}_{}.csv'.format(recipe, process_combination), index_col=0)
    test_features = pd.read_csv('/content/drive/My Drive/Rinse Over Run/test_features_{}_{}.csv'.format(recipe, process_combination), index_col=0)
    
    X_train = train_features.drop('target', axis=1)
    y_train = np.log(train_features['target'])
    
    X_test = test_features
    
    #to_drop = remove_features(X_train, y_train)
    to_drop = ["real_('flow_diff', '<lambda>')", 'target_value__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.5', "real_('tank_level_caustic', 'count')", "flow_('target_value', 'mean')", 'target_value__symmetry_looking__r_0.9', 'supply_flow__symmetry_looking__r_0.45', 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'flow_diff__symmetry_looking__r_0.6000000000000001', 'supply_flow__symmetry_looking__r_0.7000000000000001', "real_('tank_concentration_acid', 'count')", 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.45', "last_real_('tank_temperature_pre_rinse', 'count_zeros')", 'target_value__maximum', "last_flow_('return_flow', 'sum')", 'supply_flow__large_standard_deviation__r_0.75', "real_('return_conductivity', 'count')", "last_real_('tank_temperature_pre_rinse', '<lambda>')", "real_('tank_temperature_pre_rinse', 'count_zeros')", 'return_turbidity__symmetry_looking__r_0.4', 'target_value__symmetry_looking__r_0.9500000000000001', "last_real_('return_flow', 'max')", "real_('tank_level_pre_rinse', 'count_zeros')", 'target_value__autocorrelation__lag_1', 'target_value__large_standard_deviation__r_0.5', 'return_turbidity__large_standard_deviation__r_0.6000000000000001', 'supply_flow__symmetry_looking__r_0.65', "last_flow_('supply_flow', 'sum')", 'return_turbidity__large_standard_deviation__r_0.55', 'return_flow__symmetry_looking__r_0.45', 'return_turbidity__symmetry_looking__r_0.8', "last_bin_('tank_lsh_pre_rinse', 'std')", 'flow_diff__number_crossing_m__m_0', "real_('target_value', 'count')", "last_real_('tank_level_caustic', '<lambda>')", "last_real_('supply_flow', 'count')", 'supply_flow__large_standard_deviation__r_0.5', 'flow_diff__large_standard_deviation__r_0.55', 'return_flow__symmetry_looking__r_0.65', "last_real_('return_turbidity', '<lambda>')", 'target_value__large_standard_deviation__r_0.6000000000000001', "bin_('return_caustic', '<lambda>')", "real_('tank_temperature_acid', '<lambda>')", "last_real_('tank_level_acid', 'count')", 'flow_diff__large_standard_deviation__r_0.8500000000000001', 'flow_diff__large_standard_deviation__r_0.8', "last_real_('tank_temperature_acid', 'count')", 'flow_diff__symmetry_looking__r_0.30000000000000004', "real_('tank_level_acid', '<lambda>')", 'return_flow__symmetry_looking__r_0.9', "real_('tank_temperature_caustic', 'count')", "last_real_('tank_temperature_caustic', 'count')", "bin_('supply_pre_rinse', '<lambda>')", 'flow_diff__maximum', 'return_turbidity__symmetry_looking__r_0.9500000000000001', 'return_turbidity__number_crossing_m__m_-1', 'target_value__large_standard_deviation__r_0.9', "real_('tank_concentration_caustic', 'count')", "last_real_('supply_flow', 'max')", "bin_('tank_lsh_clean_water', '<lambda>')", 'flow_diff__large_standard_deviation__r_0.9', 'return_flow__symmetry_looking__r_0.0', 'return_flow__symmetry_looking__r_0.35000000000000003', 'target_value__large_standard_deviation__r_0.8', 'return_flow__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.6000000000000001', 'return_turbidity__symmetry_looking__r_0.65', 'target_value__large_standard_deviation__r_0.8500000000000001', "real_('return_conductivity', '<lambda>')", "real_('return_flow', '<lambda>')", 'flow_diff__symmetry_looking__r_0.7000000000000001', "real_('target_value', '<lambda>')", "last_real_('target_value', 'count')", "flow_('target_value', 'sum')", 'return_flow__large_standard_deviation__r_0.55', 'return_turbidity__large_standard_deviation__r_0.65', 'target_value__symmetry_looking__r_0.6000000000000001', "last_bin_('supply_caustic', 'mean')", 'return_flow__large_standard_deviation__r_0.65', "last_real_('flow_diff', 'count')", "real_('return_turbidity', 'count')", "bin_('tank_lsh_acid', 'mean')", "bin_('supply_pump', '<lambda>')", 'return_flow__symmetry_looking__r_0.8', "last_real_('supply_flow', '<lambda>')", 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__partial_autocorrelation__lag_0', 'target_value__partial_autocorrelation__lag_0', "last_real_('return_turbidity', 'count')", 'supply_flow__large_standard_deviation__r_0.8', "real_('tank_concentration_caustic', 'count_zeros')", "real_('supply_flow', 'count')", 'return_turbidity__symmetry_looking__r_0.5', 'target_value__large_standard_deviation__r_0.45', 'return_turbidity__large_standard_deviation__r_0.8', "bin_('tank_lsh_pre_rinse', 'count_zeros')", "last_real_('tank_level_pre_rinse', 'count')", "last_bin_('tank_lsh_caustic', '<lambda>')", "bin_('tank_lsh_pre_rinse', '<lambda>')", 'return_flow__symmetry_looking__r_0.9500000000000001', "last_bin_('tank_lsh_acid', 'std')", 'target_value__symmetry_looking__r_0.35000000000000003', "last_bin_('return_caustic', '<lambda>')", "last_real_('tank_temperature_caustic', '<lambda>')", 'return_turbidity__large_standard_deviation__r_0.7000000000000001', "bin_('tank_lsh_acid', 'std')", 'flow_diff__large_standard_deviation__r_0.65', 'supply_flow__symmetry_looking__r_0.0', "bin_('return_drain', '<lambda>')", 'flow_diff__symmetry_looking__r_0.8500000000000001', 'flow_diff__large_standard_deviation__r_0.6000000000000001', "last_bin_('return_drain', '<lambda>')", "real_('tank_level_clean_water', 'count_zeros')", 'return_flow__maximum', "last_real_('tank_temperature_acid', 'count_zeros')", "last_bin_('supply_caustic', 'count_zeros')", 'supply_flow__large_standard_deviation__r_0.6000000000000001', "last_real_('return_temperature', 'count')", 'supply_flow__symmetry_looking__r_0.55', 'return_turbidity__symmetry_looking__r_0.8500000000000001', "last_real_('tank_level_pre_rinse', '<lambda>')", 'return_turbidity__symmetry_looking__r_0.75', 'flow_diff__symmetry_looking__r_0.75', 'target_value__symmetry_looking__r_0.0', "real_('return_flow', 'count')", "last_bin_('tank_lsh_clean_water', '<lambda>')", 'supply_flow__large_standard_deviation__r_0.7000000000000001', "real_('tank_level_acid', 'count')", 'return_flow__large_standard_deviation__r_0.9500000000000001', "last_real_('tank_concentration_caustic', 'count_zeros')", "last_flow_('return_flow', 'mean')", "bin_('return_recovery_water', '<lambda>')", "real_('tank_level_clean_water', 'count')", 'supply_flow__large_standard_deviation__r_0.65', "last_bin_('tank_lsh_acid', '<lambda>')", "real_('return_flow', 'sum')", 'return_flow__symmetry_looking__r_0.75', "bin_('tank_lsh_clean_water', 'std')", "real_('tank_concentration_acid', '<lambda>')", "bin_('tank_lsh_acid', '<lambda>')", "last_bin_('tank_lsh_pre_rinse', '<lambda>')", 'return_flow__symmetry_looking__r_0.7000000000000001', 'return_turbidity__symmetry_looking__r_0.7000000000000001', "bin_('supply_caustic', '<lambda>')", 'return_flow__partial_autocorrelation__lag_0', "real_('tank_level_clean_water', '<lambda>')", 'target_value__large_standard_deviation__r_0.75', "last_bin_('tank_lsh_acid', 'count_zeros')", "real_('target_value', 'max')", 'return_flow__symmetry_looking__r_0.6000000000000001', 'target_value__symmetry_looking__r_0.4', "real_('flow_diff', 'count')", "real_('supply_flow', 'mean')", 'return_flow__large_standard_deviation__r_0.5', 'supply_flow__symmetry_looking__r_0.9', 'return_flow__symmetry_looking__r_0.5', 'flow_diff__large_standard_deviation__r_0.4', 'return_turbidity__symmetry_looking__r_0.55', 'target_value__minimum', "flow_('return_flow', 'max')", 'supply_flow__symmetry_looking__r_0.8', "real_('flow_diff', 'min')", "last_real_('tank_level_clean_water', 'count')", "last_real_('tank_concentration_caustic', '<lambda>')", 'return_flow__large_standard_deviation__r_0.6000000000000001', "real_('return_turbidity', 'min')", 'target_value__large_standard_deviation__r_0.55', "real_('tank_level_pre_rinse', 'count')", "last_real_('tank_level_clean_water', 'count_zeros')", 'flow_diff__partial_autocorrelation__lag_0', 'supply_flow__symmetry_looking__r_0.8500000000000001', "last_flow_('target_value', 'max')", "last_bin_('tank_lsh_clean_water', 'mean')", 'supply_flow__large_standard_deviation__r_0.9500000000000001', 'supply_flow__large_standard_deviation__r_0.55', 'supply_flow__symmetry_looking__r_0.5', "last_bin_('supply_pre_rinse', 'std')", 'flow_diff__symmetry_looking__r_0.9', 'return_turbidity__large_standard_deviation__r_0.45', "bin_('supply_clean_water', '<lambda>')", 'flow_diff__symmetry_looking__r_0.9500000000000001', "last_bin_('tank_lsh_acid', 'mean')", 'return_flow__large_standard_deviation__r_0.8', 'return_flow__symmetry_looking__r_0.55', 'supply_flow__large_standard_deviation__r_0.8500000000000001', "last_bin_('object_low_level', '<lambda>')", "bin_('tank_lsh_clean_water', 'mean')", "last_real_('tank_concentration_caustic', 'count')", "last_bin_('supply_pre_rinse', 'count_zeros')", 'target_value__symmetry_looking__r_0.7000000000000001', 'supply_flow__number_crossing_m__m_-1', "real_('return_flow', 'min')", 'return_flow__large_standard_deviation__r_0.8500000000000001', "last_real_('tank_concentration_acid', 'count')", "real_('supply_flow', 'max')", 'supply_flow__symmetry_looking__r_0.75', "last_real_('return_conductivity', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.5', 'flow_diff__symmetry_looking__r_0.65', "last_real_('tank_level_caustic', 'count')", "last_bin_('supply_caustic', 'std')", 'flow_diff__symmetry_looking__r_0.8', "last_bin_('supply_caustic', '<lambda>')", "last_real_('tank_level_caustic', 'count_zeros')", "last_bin_('supply_acid', '<lambda>')", "bin_('tank_lsh_pre_rinse', 'std')", 'target_value__large_standard_deviation__r_0.65', 'flow_diff__large_standard_deviation__r_0.5', 'supply_flow__symmetry_looking__r_0.9500000000000001', "last_real_('return_conductivity', 'count')", 'flow_diff__symmetry_looking__r_0.2', "last_real_('tank_level_acid', 'count_zeros')", "last_bin_('return_acid', '<lambda>')", "flow_('return_flow', 'mean')", "real_('supply_pressure', 'count')", 'return_flow__number_crossing_m__m_-1', 'supply_flow__large_standard_deviation__r_0.9', "real_('return_turbidity', 'max')", "real_('tank_level_acid', 'count_zeros')", 'return_turbidity__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.45', "last_bin_('return_recovery_water', '<lambda>')", "real_('tank_temperature_pre_rinse', 'count')", "last_real_('tank_temperature_pre_rinse', 'count')", "last_real_('target_value', 'sum')", 'target_value__symmetry_looking__r_0.5', "last_real_('return_temperature', '<lambda>')", 'target_value__symmetry_looking__r_0.8500000000000001', 'target_value__symmetry_looking__r_0.30000000000000004', 'supply_flow__partial_autocorrelation__lag_0', "flow_('supply_flow', 'max')", "last_bin_('supply_pre_rinse', '<lambda>')", "last_flow_('supply_flow', 'mean')", "last_bin_('supply_pre_rinse', 'mean')", 'target_value__large_standard_deviation__r_0.9500000000000001', 'target_value__symmetry_looking__r_0.75', "real_('tank_temperature_acid', 'count')", "bin_('tank_lsh_pre_rinse', 'mean')", "real_('tank_level_caustic', 'count_zeros')", 'flow_diff__large_standard_deviation__r_0.35000000000000003', 'flow_diff__range_count__max_1__min_-1', "last_real_('tank_concentration_acid', 'count_zeros')", "bin_('tank_lsh_clean_water', 'count_zeros')", "real_('supply_pressure', '<lambda>')", 'return_flow__symmetry_looking__r_0.4', 'supply_flow__symmetry_looking__r_0.6000000000000001', 'target_value__symmetry_looking__r_0.8', "last_real_('return_flow', 'count')", "last_bin_('tank_lsh_pre_rinse', 'count_zeros')", 'flow_diff__large_standard_deviation__r_0.45', 'target_value__large_standard_deviation__r_0.7000000000000001', 'target_value__symmetry_looking__r_0.55', 'supply_flow__minimum', 'return_turbidity__large_standard_deviation__r_0.9500000000000001', "real_('supply_flow', 'sum')", "last_bin_('tank_lsh_pre_rinse', 'mean')", 'return_turbidity__large_standard_deviation__r_0.8500000000000001', 'flow_diff__symmetry_looking__r_0.55', 'target_value__symmetry_looking__r_0.65', 'flow_diff__symmetry_looking__r_0.35000000000000003', 'return_flow__large_standard_deviation__r_0.7000000000000001', "bin_('tank_lsh_acid', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.0', 'flow_diff__large_standard_deviation__r_0.75', "last_flow_('target_value', 'mean')", "real_('tank_temperature_acid', 'count_zeros')", 'return_turbidity__large_standard_deviation__r_0.75', 'return_flow__large_standard_deviation__r_0.45', 'return_turbidity__symmetry_looking__r_0.0', "last_real_('tank_level_pre_rinse', 'count_zeros')", "last_bin_('tank_lsh_clean_water', 'std')", "last_bin_('tank_lsh_clean_water', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.25', 'return_flow__symmetry_looking__r_0.8500000000000001', 'return_flow__large_standard_deviation__r_0.75', "last_real_('tank_temperature_caustic', 'count_zeros')", 'return_turbidity__symmetry_looking__r_0.9', 'return_turbidity__symmetry_looking__r_0.35000000000000003']
    print(len(to_drop), to_drop)

    X_train = X_train.drop(to_drop, axis=1)
    X_test = X_test.drop(to_drop, axis=1)
    
    rand_features = np.random.choice(list(X_train.columns), replace=False, size=int(0.5*len(X_train.columns)))
    X_train = X_train[rand_features]
    X_test = X_test[rand_features]
    
    train_index = X_train.index
    test_index = X_test.index
    
#     train_index = X_train.index
#     test_index = X_test.index
    
#     hasher = FeatureHasher()
#     X_train = hasher.fit_transform(X_train.to_dict(orient='records'))
#     X_test = hasher.fit_transform(X_test.to_dict(orient='records'))
    
    clfs = [
#           ('knn_100', Pipeline(steps=[('scale', StandardScaler()), ('knn_100', KNeighborsRegressor(n_neighbors=100))])),
#           ('knn_10', Pipeline(steps=[('scale', StandardScaler()), ('knn_10', KNeighborsRegressor(n_neighbors=10))])),
#           ('knn_50_3', Pipeline(steps=[('scale', StandardScaler()), ('knn_50', KNeighborsRegressor(n_neighbors=50))])),
#           ('knn_250', Pipeline(steps=[('scale', StandardScaler()), ('knn_250', KNeighborsRegressor(n_neighbors=250))])),
#           ('lr', Pipeline(steps=[('scale', StandardScaler()), ('lr', Lasso(max_iter=10000))])),
#           ('knn_pca', Pipeline(steps=[('scale', StandardScaler()), ('pca', PCA(n_components=5)), ('knn', KNeighborsRegressor(n_neighbors=100))])),
#           ('mlp',  Pipeline(steps=[('scale', StandardScaler()), ('mlp', MLPRegressor(max_iter=1000))])),
#           ('rf_25', RandomForestRegressor(n_estimators=25)),
#           ('rf_100', RandomForestRegressor(n_estimators=100)),
#           ('rf_250', RandomForestRegressor(n_estimators=250)),
          ('et_50_4', ExtraTreesRegressor(n_estimators=50)),
#           ('et_100', ExtraTreesRegressor(n_estimators=100)),
#           ('et_250', ExtraTreesRegressor(n_estimators=250)),
#           ('logreg_l1', Pipeline(steps=[('scale', StandardScaler()), ('lr', LogisticRegression(penalty='l1'))])),
#           ('logreg_l2', Pipeline(steps=[('scale', StandardScaler()), ('lr', LogisticRegression(penalty='l2'))])),
#         ('ada_50', AdaBoostRegressor(n_estimators=50)),
#         ('rt_embedding', Pipeline(steps=[('embed', RandomTreesEmbedding(max_depth=3, n_estimators=100)), ('et',  ExtraTreesRegressor(n_estimators=25))])),
#         ('pca_et', Pipeline(steps=[('scale', StandardScaler()), ('pca', PCA(n_components=25)), ('et',  ExtraTreesRegressor(n_estimators=25))]))
#         ('ada_250', AdaBoostRegressor(n_estimators=250)),
          #('et_10_hash', ExtraTreesRegressor(n_estimators=10, max_depth=5, max_features='log2')),
#           ('et_100_depth_3', ExtraTreesRegressor(n_estimators=100, max_depth=3, max_features='sqrt')),
#           ('et_50', ExtraTreesRegressor(n_estimators=50, min_samples_leaf=10)),
#           ('svr_5', Pipeline(steps=[('scale', StandardScaler()), ('svr', SVR())])),
#           ('linear_svr', Pipeline(steps=[('scale', StandardScaler()), ('svr', LinearSVR())])),
#           ('bay_lr', Pipeline(steps=[('scale', StandardScaler()), ('lr', BayesianRidge())])),
#           ('knn_25_rbf', Pipeline(steps=[('scale', StandardScaler()), ('rbf', RBFSampler()), ('knn', KNeighborsRegressor(n_neighbors=25, weights='distance'))])),
#           ('svr_C_100', Pipeline(steps=[('scale', StandardScaler()), ('svr', SVR(C=100))])),
#           #('gp', Pipeline(steps=[('scale', StandardScaler()), ('gp', GaussianProcessRegressor())]))
#           ('svm_clf', Pipeline(steps=[('scale', StandardScaler()), ('svr', SVC())])),
#           ('et_50_clf', ExtraTreesClassifier(n_estimators=50)),
#           ('rf_50_clf', RandomForestClassifier(n_estimators=50)),
#           ('et_100_clf', ExtraTreesClassifier(n_estimators=100)),
#           ('rf_100_clf', RandomForestClassifier(n_estimators=100)),
#           ('et_250_clf', ExtraTreesClassifier(n_estimators=100)),
          #('ord_ridge', Pipeline(steps=[('scale', StandardScaler()), ('ord', OrdinalRidge())]))
        
        #TODO:
#           ('et_25_mae', ExtraTreesRegressor(n_estimators=25, criterion='mae')),
      ]

    for name, clf in clfs:
        print(name)
        train_pred_df, test_pred_df = fit_stack(clf, name, X_train.values, y_train.values, X_test.values, train_index, test_index, n_splits=10)
        train_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/train_predictions_stack_{}_{}_{}.csv'.format(name, recipe, process_combination))
        test_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/test_predictions_stack_{}_{}_{}.csv'.format(name, recipe, process_combination))
# Out:
# 279 ["real_('flow_diff', '<lambda>')", 'target_value__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.5', "real_('tank_level_caustic', 'count')", "flow_('target_value', 'mean')", 'target_value__symmetry_looking__r_0.9', 'supply_flow__symmetry_looking__r_0.45', 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'flow_diff__symmetry_looking__r_0.6000000000000001', 'supply_flow__symmetry_looking__r_0.7000000000000001', "real_('tank_concentration_acid', 'count')", 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.45', "last_real_('tank_temperature_pre_rinse', 'count_zeros')", 'target_value__maximum', "last_flow_('return_flow', 'sum')", 'supply_flow__large_standard_deviation__r_0.75', "real_('return_conductivity', 'count')", "last_real_('tank_temperature_pre_rinse', '<lambda>')", "real_('tank_temperature_pre_rinse', 'count_zeros')", 'return_turbidity__symmetry_looking__r_0.4', 'target_value__symmetry_looking__r_0.9500000000000001', "last_real_('return_flow', 'max')", "real_('tank_level_pre_rinse', 'count_zeros')", 'target_value__autocorrelation__lag_1', 'target_value__large_standard_deviation__r_0.5', 'return_turbidity__large_standard_deviation__r_0.6000000000000001', 'supply_flow__symmetry_looking__r_0.65', "last_flow_('supply_flow', 'sum')", 'return_turbidity__large_standard_deviation__r_0.55', 'return_flow__symmetry_looking__r_0.45', 'return_turbidity__symmetry_looking__r_0.8', "last_bin_('tank_lsh_pre_rinse', 'std')", 'flow_diff__number_crossing_m__m_0', "real_('target_value', 'count')", "last_real_('tank_level_caustic', '<lambda>')", "last_real_('supply_flow', 'count')", 'supply_flow__large_standard_deviation__r_0.5', 'flow_diff__large_standard_deviation__r_0.55', 'return_flow__symmetry_looking__r_0.65', "last_real_('return_turbidity', '<lambda>')", 'target_value__large_standard_deviation__r_0.6000000000000001', "bin_('return_caustic', '<lambda>')", "real_('tank_temperature_acid', '<lambda>')", "last_real_('tank_level_acid', 'count')", 'flow_diff__large_standard_deviation__r_0.8500000000000001', 'flow_diff__large_standard_deviation__r_0.8', "last_real_('tank_temperature_acid', 'count')", 'flow_diff__symmetry_looking__r_0.30000000000000004', "real_('tank_level_acid', '<lambda>')", 'return_flow__symmetry_looking__r_0.9', "real_('tank_temperature_caustic', 'count')", "last_real_('tank_temperature_caustic', 'count')", "bin_('supply_pre_rinse', '<lambda>')", 'flow_diff__maximum', 'return_turbidity__symmetry_looking__r_0.9500000000000001', 'return_turbidity__number_crossing_m__m_-1', 'target_value__large_standard_deviation__r_0.9', "real_('tank_concentration_caustic', 'count')", "last_real_('supply_flow', 'max')", "bin_('tank_lsh_clean_water', '<lambda>')", 'flow_diff__large_standard_deviation__r_0.9', 'return_flow__symmetry_looking__r_0.0', 'return_flow__symmetry_looking__r_0.35000000000000003', 'target_value__large_standard_deviation__r_0.8', 'return_flow__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.6000000000000001', 'return_turbidity__symmetry_looking__r_0.65', 'target_value__large_standard_deviation__r_0.8500000000000001', "real_('return_conductivity', '<lambda>')", "real_('return_flow', '<lambda>')", 'flow_diff__symmetry_looking__r_0.7000000000000001', "real_('target_value', '<lambda>')", "last_real_('target_value', 'count')", "flow_('target_value', 'sum')", 'return_flow__large_standard_deviation__r_0.55', 'return_turbidity__large_standard_deviation__r_0.65', 'target_value__symmetry_looking__r_0.6000000000000001', "last_bin_('supply_caustic', 'mean')", 'return_flow__large_standard_deviation__r_0.65', "last_real_('flow_diff', 'count')", "real_('return_turbidity', 'count')", "bin_('tank_lsh_acid', 'mean')", "bin_('supply_pump', '<lambda>')", 'return_flow__symmetry_looking__r_0.8', "last_real_('supply_flow', '<lambda>')", 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__partial_autocorrelation__lag_0', 'target ...
# et_50_4
# [et_50_4] Fold #1 MAPE=0.8498583550372394
# [et_50_4] Fold #2 MAPE=0.7598964682962062
# [et_50_4] Fold #3 MAPE=0.6824959073046213
# [et_50_4] Fold #4 MAPE=0.3109583713643912
# [et_50_4] Fold #5 MAPE=0.4907141395080604
# [et_50_4] Fold #6 MAPE=0.8772832693395755
# [et_50_4] Fold #7 MAPE=0.4183960523020228
# [et_50_4] Fold #8 MAPE=1.0207424087868973
# [et_50_4] Fold #9 MAPE=0.6841468122394102
# [et_50_4] Fold #10 MAPE=0.7179128701287623

# %%
train_pred_df, test_pred_df = fit_stack(RRForestRegressor(), name, X_train.values, y_train.values, X_test.values, n_splits=10)
# Out:
# [rot_et_50] Fold #1 MAPE=1.2176318312591492
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-38fb42dc8d70> in <module>()
# ----> 1 train_pred_df, test_pred_df = fit_stack(RRForestRegressor(), name, X_train.values, y_train.values, X_test.values, n_splits=10)
#
# <ipython-input-7-558fc72218c4> in fit_stack(clf, name, X_train, y_train, X_test, n_splits)
#      13
#      14     clf_clone = clone(clf)
# ---> 15     clf_clone.fit(X_cv_train, y_cv_train)
#      16
#      17     print('[{}] Fold #{} MAPE={}'.format(name, fold_ix + 1, custom_mape(np.exp(y_cv_test), np.exp(clf_clone.predict(X_cv_test)))))
#
# <ipython-input-26-3a18b45cf243> in fit(self, X, y, sample_weight)
#     287         if self.scaling:
#     288             self._fit_scale(X)
# --> 289             super(RRForestRegressor, self).fit(self._scale(X), y, sample_weight)
#     290         else:
#     291             super(RRForestRegressor, self).fit(X, y, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     331                     t, self, X, y, sample_weight, i, len(trees),
#     332                     verbose=self.verbose, class_weight=self.class_weight)
# --> 333                 for i, t in enumerate(trees))
#     334
#     335             # Collect newly grown trees
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     117             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     118
# --> 119         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     120     else:
#     121         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# <ipython-input-26-3a18b45cf243> in fit(self, X, y, sample_weight, check_input)
#     195         self._fit_rotation_matrix(X)
#     196         super(RRTreeRegressor, self).fit(self.rotate(X), y,
# --> 197                                                 sample_weight, check_input)
#     198
#     199     def predict_proba(self, X, check_input=True):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1140             sample_weight=sample_weight,
#    1141             check_input=check_input,
# -> 1142             X_idx_sorted=X_idx_sorted)
#    1143         return self
#    1144
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     364                                            min_impurity_split)
#     365
# --> 366         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     367
#     368         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
# X_train[[0, 5, 10]]
# Out:
# <3x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2734 stored elements in Compressed Sparse Row format>

# %%
# combinations_per_recipe = {
#     3: [3, 1, 2], 
#     9: [8],
#     15: [1, 2, 3, 6, 7, 14, 15]
# }

# prediction_df = None
# import warnings; warnings.filterwarnings('ignore')
# for recipe in [3, 9, 15]:
#   for process_combination in combinations_per_recipe[recipe]:
#     train_features = pd.read_csv('/content/drive/My Drive/Rinse Over Run/train_features_{}_{}.csv'.format(recipe, process_combination), index_col=0)
#     test_features = pd.read_csv('/content/drive/My Drive/Rinse Over Run/test_features_{}_{}.csv'.format(recipe, process_combination), index_col=0)
#     labels = pd.read_csv('/content/drive/My Drive/Rinse Over Run/final_phase_labels_{}_{}.csv'.format(recipe, process_combination), index_col=0)
    
#     X_train = train_features.drop('target', axis=1)
#     y_train = np.log(labels.loc[X_train.index]['return_flow_sum'])
    
#     X_test = test_features
    
#     to_drop = remove_features(X_train, y_train)
#     print(len(to_drop), to_drop)

#     X_train = X_train.drop(to_drop, axis=1)
#     X_test = X_test.drop(to_drop, axis=1)
    
#     clfs = [
#           ('rf_25_return_flow_sum', RandomForestRegressor(n_estimators=25)),
#           ('et_25_return_flow_sum', ExtraTreesRegressor(n_estimators=25)),
#       ]

#     for name, clf in clfs:
#         train_pred_df, test_pred_df = fit_stack(clf, name, X_train, y_train, X_test, n_splits=10)
#         train_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/train_predictions_stack_flow_{}_{}_{}.csv'.format(name, recipe, process_combination))
#         test_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/test_predictions_stack_flow_{}_{}_{}.csv'.format(name, recipe, process_combination))
# Out:
# 1104 correlated feature pairs left...
# 1062 correlated feature pairs left...
# 1022 correlated feature pairs left...
# 984 correlated feature pairs left...
# 942 correlated feature pairs left...
# 902 correlated feature pairs left...
# 864 correlated feature pairs left...
# 862 correlated feature pairs left...
# 826 correlated feature pairs left...
# 824 correlated feature pairs left...
# 788 correlated feature pairs left...
# 754 correlated feature pairs left...
# 720 correlated feature pairs left...
# 688 correlated feature pairs left...
# 658 correlated feature pairs left...
# 630 correlated feature pairs left...
# 628 correlated feature pairs left...
# 602 correlated feature pairs left...
# 578 correlated feature pairs left...
# 556 correlated feature pairs left...
# 554 correlated feature pairs left...
# 552 correlated feature pairs left...
# 550 correlated feature pairs left...
# 518 correlated feature pairs left...
# 498 correlated feature pairs left...
# 468 correlated feature pairs left...
# 440 correlated feature pairs left...
# 438 correlated feature pairs left...
# 420 correlated feature pairs left...
# 394 correlated feature pairs left...
# 390 correlated feature pairs left...
# 366 correlated feature pairs left...
# 356 correlated feature pairs left...
# 340 correlated feature pairs left...
# 326 correlated feature pairs left...
# 304 correlated feature pairs left...
# 292 correlated feature pairs left...
# 272 correlated feature pairs left...
# 262 correlated feature pairs left...
# 254 correlated feature pairs left...
# 252 correlated feature pairs left...
# 250 correlated feature pairs left...
# 248 correlated feature pairs left...
# 242 correlated feature pairs left...
# 234 correlated feature pairs left...
# 216 correlated feature pairs left...
# 214 correlated feature pairs left...
# 210 correlated feature pairs left...
# 208 correlated feature pairs left...
# 206 correlated feature pairs left...
# 204 correlated feature pairs left...
# 198 correlated feature pairs left...
# 196 correlated feature pairs left...
# 194 correlated feature pairs left...
# 192 correlated feature pairs left...
# 188 correlated feature pairs left...
# 186 correlated feature pairs left...
# 184 correlated feature pairs left...
# 168 correlated feature pairs left...
# 162 correlated feature pairs left...
# 160 correlated feature pairs left...
# 156 correlated feature pairs left...
# 154 correlated feature pairs left...
# 152 correlated feature pairs left...
# 150 correlated feature pairs left...
# 148 correlated feature pairs left...
# 146 correlated feature pairs left...
# 132 correlated feature pairs left...
# 120 correlated feature pairs left...
# 118 correlated feature pairs left...
# 116 correlated feature pairs left...
# 114 correlated feature pairs left...
# 112 correlated feature pairs left...
# 110 correlated feature pairs left...
# 100 correlated feature pairs left...
# 98 correlated feature pairs left...
# 90 correlated feature pairs left...
# 88 correlated feature pairs left...
# 82 correlated feature pairs left...
# 80 correlated feature pairs left...
# 78 correlated feature pairs left...
# 74 correlated feature pairs left...
# 72 correlated feature pairs left...
# 70 correlated feature pairs left...
# 68 correlated feature pairs left...
# 66 correlated feature pairs left...
# 64 correlated feature pairs left...
# 60 correlated feature pairs left...
# 58 correlated feature pairs left...
# 56 correlated feature pairs left...
# 54 correlated feature pairs left...
# 52 correlated feature pairs left...
# 50 correlated feature pairs left...
# 48 correlated feature pairs left...
# 46 correlated feature pairs left...
# 44 correlated feature pairs left...
# 42 correlated feature pairs left...
# 40 correlated feature pairs left...
# 38 correlated feature pairs left...
# 34 correlated feature pairs left...
# 32 correlated feature pairs left...
# 30 correlated feature pairs left...
# 28 correlated feature pairs left...
# 26 correlated feature pairs left...
# 24 correlated feature pairs left...
# 22 correlated feature pairs left...
# 20 correlated feature pairs left...
# 18 correlated feature pairs left...
# 16 correlated feature pairs left...
# 14 correlated feature pairs left...
# 12 correlated feature pairs left...
# 10 correlated feature pairs left...
# 8 correlated feature pairs left...
# 6 correlated feature pairs left...
# 4 correlated feature pairs left...
# 2 correlated feature pairs left...
# 300 ['flow_diff__symmetry_looking__r_0.0', 'return_flow__large_standard_deviation__r_0.5', 'target_value__large_standard_deviation__r_0.6000000000000001', 'target_value__symmetry_looking__r_0.0', 'target_value__symmetry_looking__r_0.65', 'return_flow__symmetry_looking__r_0.0', "last_bin_('return_acid', 'mean')", "last_real_('tank_temperature_pre_rinse', 'count')", "real_('supply_flow', 'count_zeros')", "bin_('supply_pre_rinse', '<lambda>')", 'return_flow__number_crossing_m__m_-1', "last_real_('tank_level_caustic', 'count')", "real_('supply_pressure', 'count')", 'return_turbidity__large_standard_deviation__r_0.05', "bin_('return_recovery_water', '<lambda>')", "last_real_('tank_level_clean_water', 'count')", 'flow_diff__large_standard_deviation__r_0.35000000000000003', "last_bin_('supply_pump', '<lambda>')", 'return_flow__large_standard_deviation__r_0.9', 'target_value__large_standard_deviation__r_0.9500000000000001', 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.5', "real_('flow_diff', 'count')", 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'target_value__large_standard_deviation__r_0.8500000000000001', 'target_value__large_standard_deviation__r_0.5', "real_('return_temperature', 'count_zeros')", 'return_flow__symmetry_looking__r_0.6000000000000001', "real_('return_conductivity', 'count')", 'return_flow__number_crossing_m__m_0', "real_('tank_temperature_pre_rinse', '<lambda>')", "real_('tank_level_clean_water', '<lambda>')", 'return_flow__symmetry_looking__r_0.7000000000000001', "bin_('supply_acid', '<lambda>')", 'return_flow__partial_autocorrelation__lag_0', "last_flow_('supply_flow', 'mean')", 'return_flow__large_standard_deviation__r_0.9500000000000001', 'return_flow__large_standard_deviation__r_0.45', 'return_turbidity__symmetry_looking__r_0.7000000000000001', "last_real_('tank_concentration_acid', 'count')", "last_real_('tank_level_clean_water', 'count_zeros')", "last_bin_('supply_acid', 'mean')", 'object_id_95', 'return_turbidity__large_standard_deviation__r_0.8500000000000001', "bin_('tank_lsh_caustic', '<lambda>')", "last_real_('tank_concentration_acid', '<lambda>')", "last_real_('tank_concentration_caustic', 'count')", "last_bin_('tank_lsh_acid', 'count_zeros')", 'return_flow__symmetry_looking__r_0.65', "last_real_('tank_concentration_caustic', 'count_zeros')", 'flow_diff__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.35000000000000003', 'target_value__symmetry_looking__r_0.55', 'supply_flow__maximum', 'return_flow__symmetry_looking__r_0.45', "real_('tank_temperature_acid', 'count_zeros')", "last_bin_('tank_lsh_acid', 'mean')", 'return_turbidity__maximum', "last_real_('return_conductivity', '<lambda>')", "real_('tank_level_caustic', '<lambda>')", "last_bin_('return_recovery_water', '<lambda>')", 'flow_diff__symmetry_looking__r_0.35000000000000003', 'return_flow__symmetry_looking__r_0.8', 'supply_flow__large_standard_deviation__r_0.8500000000000001', "last_real_('tank_temperature_acid', 'count_zeros')", 'target_value__symmetry_looking__r_0.75', "last_bin_('supply_acid', 'count_zeros')", "last_real_('tank_temperature_caustic', 'count')", "real_('tank_temperature_caustic', 'count_zeros')", 'supply_flow__large_standard_deviation__r_0.6000000000000001', 'target_value__large_standard_deviation__r_0.8', "bin_('supply_acid', 'std')", 'return_flow__symmetry_looking__r_0.9500000000000001', "last_bin_('supply_acid', '<lambda>')", "last_bin_('tank_lsh_acid', '<lambda>')", "last_real_('supply_flow', 'count')", "last_real_('return_flow', '<lambda>')", 'object_id_30', "real_('target_value', 'min')", 'return_turbidity__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__number_crossing_m__m_-1', "last_bin_('supply_acid', 'std')", 'return_flow__symmetry_looking__r_0.30000000000000004', 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.9500000000000001', "last_bin_(' ...
# [rf_25_return_flow_sum] Fold #1 MAPE=0.07733776849208691
# [rf_25_return_flow_sum] Fold #2 MAPE=0.19006528396881137
# [rf_25_return_flow_sum] Fold #3 MAPE=0.07734864631395018
# [rf_25_return_flow_sum] Fold #4 MAPE=0.08069352654568196
# [rf_25_return_flow_sum] Fold #5 MAPE=0.08351052565953068
# [rf_25_return_flow_sum] Fold #6 MAPE=0.07669228403059714
# [rf_25_return_flow_sum] Fold #7 MAPE=0.07100016286505041
# [rf_25_return_flow_sum] Fold #8 MAPE=0.05672830365581423
# [rf_25_return_flow_sum] Fold #9 MAPE=0.08567321911261257
# [rf_25_return_flow_sum] Fold #10 MAPE=0.09591770083269392
# [et_25_return_flow_sum] Fold #1 MAPE=0.06532265643488946
# [et_25_return_flow_sum] Fold #2 MAPE=0.0670974992732161
# [et_25_return_flow_sum] Fold #3 MAPE=0.06463704402967645
# [et_25_return_flow_sum] Fold #4 MAPE=0.07162178654768005
# [et_25_return_flow_sum] Fold #5 MAPE=0.07595885951945947
# [et_25_return_flow_sum] Fold #6 MAPE=0.05790295757738848
# [et_25_return_flow_sum] Fold #7 MAPE=0.10635657939129699
# [et_25_return_flow_sum] Fold #8 MAPE=0.160930451167041
# [et_25_return_flow_sum] Fold #9 MAPE=0.1127388312737948
# [et_25_return_flow_sum] Fold #10 MAPE=0.04884268034359754
# 668 correlated feature pairs left...
# 666 correlated feature pairs left...
# 618 correlated feature pairs left...
# 572 correlated feature pairs left...
# 528 correlated feature pairs left...
# 486 correlated feature pairs left...
# 446 correlated feature pairs left...
# 408 correlated feature pairs left...
# 372 correlated feature pairs left...
# 338 correlated feature pairs left...
# 306 correlated feature pairs left...
# 276 correlated feature pairs left...
# 248 correlated feature pairs left...
# 222 correlated feature pairs left...
# 218 correlated feature pairs left...
# 194 correlated feature pairs left...
# 172 correlated feature pairs left...
# 152 correlated feature pairs left...
# 134 correlated feature pairs left...
# 118 correlated feature pairs left...
# 116 correlated feature pairs left...
# 102 correlated feature pairs left...
# 90 correlated feature pairs left...
# 88 correlated feature pairs left...
# 86 correlated feature pairs left...
# 84 correlated feature pairs left...
# 82 correlated feature pairs left...
# 80 correlated feature pairs left...
# 76 correlated feature pairs left...
# 74 correlated feature pairs left...
# 72 correlated feature pairs left...
# 70 correlated feature pairs left...
# 68 correlated feature pairs left...
# 66 correlated feature pairs left...
# 64 correlated feature pairs left...
# 62 correlated feature pairs left...
# 60 correlated feature pairs left...
# 50 correlated feature pairs left...
# 42 correlated feature pairs left...
# 40 correlated feature pairs left...
# 38 correlated feature pairs left...
# 36 correlated feature pairs left...
# 34 correlated feature pairs left...
# 32 correlated feature pairs left...
# 26 correlated feature pairs left...
# 22 correlated feature pairs left...
# 20 correlated feature pairs left...
# 18 correlated feature pairs left...
# 16 correlated feature pairs left...
# 12 correlated feature pairs left...
# 10 correlated feature pairs left...
# 8 correlated feature pairs left...
# 6 correlated feature pairs left...
# 4 correlated feature pairs left...
# 2 correlated feature pairs left...
# 239 ['flow_diff__symmetry_looking__r_0.0', 'return_flow__large_standard_deviation__r_0.5', 'target_value__large_standard_deviation__r_0.6000000000000001', "bin_('tank_lsh_clean_water', 'mean')", 'target_value__symmetry_looking__r_0.0', 'return_flow__symmetry_looking__r_0.0', 'target_value__symmetry_looking__r_0.65', 'return_flow__number_crossing_m__m_-1', "real_('supply_pressure', 'count')", 'return_turbidity__large_standard_deviation__r_0.05', "bin_('return_recovery_water', '<lambda>')", 'target_value__large_standard_deviation__r_0.05', 'return_flow__large_standard_deviation__r_0.9', 'target_value__large_standard_deviation__r_0.9500000000000001', 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.5', "real_('flow_diff', 'count')", "bin_('return_caustic', 'mean')", 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'target_value__large_standard_deviation__r_0.8500000000000001', "real_('return_temperature', 'count_zeros')", 'target_value__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.6000000000000001', "real_('return_conductivity', 'count')", 'return_flow__symmetry_looking__r_0.7000000000000001', "bin_('supply_acid', '<lambda>')", 'return_flow__partial_autocorrelation__lag_0', 'return_flow__large_standard_deviation__r_0.9500000000000001', 'return_flow__large_standard_deviation__r_0.45', 'return_turbidity__symmetry_looking__r_0.7000000000000001', 'return_turbidity__large_standard_deviation__r_0.8500000000000001', 'return_flow__range_count__max_1__min_-1', 'return_flow__symmetry_looking__r_0.65', 'flow_diff__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.35000000000000003', 'target_value__symmetry_looking__r_0.55', 'target_value__partial_autocorrelation__lag_1', 'return_flow__symmetry_looking__r_0.45', "real_('tank_temperature_acid', 'count_zeros')", 'supply_flow__range_count__max_1__min_-1', 'flow_diff__symmetry_looking__r_0.35000000000000003', 'return_flow__symmetry_looking__r_0.8', 'supply_flow__large_standard_deviation__r_0.8500000000000001', 'target_value__symmetry_looking__r_0.75', 'flow_diff__large_standard_deviation__r_0.1', "real_('tank_temperature_caustic', 'count_zeros')", 'supply_flow__large_standard_deviation__r_0.6000000000000001', 'target_value__large_standard_deviation__r_0.8', "bin_('supply_acid', 'std')", 'return_flow__symmetry_looking__r_0.9500000000000001', 'pipeline_L10', 'object_id_30', "real_('target_value', 'min')", 'return_turbidity__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__number_crossing_m__m_-1', 'supply_flow__large_standard_deviation__r_0.45', "bin_('return_acid', 'count_zeros')", "bin_('supply_clean_water', '<lambda>')", 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.9500000000000001', "real_('tank_level_clean_water', 'count')", 'return_turbidity__large_standard_deviation__r_0.65', "real_('tank_level_caustic', 'count_zeros')", "real_('return_turbidity', 'max')", 'flow_diff__large_standard_deviation__r_0.05', "real_('tank_level_pre_rinse', 'count')", 'target_value__large_standard_deviation__r_0.55', 'supply_flow__number_crossing_m__m_0', 'flow_diff__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.9', 'return_flow__maximum', 'supply_flow__symmetry_looking__r_0.0', "bin_('tank_lsh_acid', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.9', "bin_('tank_lsh_acid', '<lambda>')", 'return_turbidity__symmetry_looking__r_0.30000000000000004', 'flow_diff__large_standard_deviation__r_0.75', 'return_turbidity__symmetry_looking__r_0.35000000000000003', 'supply_flow__minimum', 'flow_diff__symmetry_looking__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.65', 'supply_flow__ratio_beyond_r_sigma__r_10', "real_('tank_temperature_pre_rinse', 'count_zeros')", "real_('return_temperature', 'count')", 'return_flow__large_standard_deviation__r_0.05', 'flow_diff__minimum', 'return_flow__symmet ...
# [rf_25_return_flow_sum] Fold #1 MAPE=0.12944335959595332
# [rf_25_return_flow_sum] Fold #2 MAPE=0.10925894156301992
# [rf_25_return_flow_sum] Fold #3 MAPE=0.13089835181328746
# [rf_25_return_flow_sum] Fold #4 MAPE=0.19706052783965175
# [rf_25_return_flow_sum] Fold #5 MAPE=0.12636777733797938
# [rf_25_return_flow_sum] Fold #6 MAPE=0.14321908543226017
# [rf_25_return_flow_sum] Fold #7 MAPE=0.11464118417036095
# [rf_25_return_flow_sum] Fold #8 MAPE=0.11353339498649044
# [rf_25_return_flow_sum] Fold #9 MAPE=0.1259898653805851
# [rf_25_return_flow_sum] Fold #10 MAPE=0.11673258676968007
# [et_25_return_flow_sum] Fold #1 MAPE=0.10100483866452475
# [et_25_return_flow_sum] Fold #2 MAPE=0.10628986380260903
# [et_25_return_flow_sum] Fold #3 MAPE=0.07120326639771654
# [et_25_return_flow_sum] Fold #4 MAPE=0.08853538236588049
# [et_25_return_flow_sum] Fold #5 MAPE=0.11295620018596346
# [et_25_return_flow_sum] Fold #6 MAPE=0.19112630120190988
# [et_25_return_flow_sum] Fold #7 MAPE=0.089801253574186
# [et_25_return_flow_sum] Fold #8 MAPE=0.11035545789084236
# [et_25_return_flow_sum] Fold #9 MAPE=0.07939560466961407
# [et_25_return_flow_sum] Fold #10 MAPE=0.08039380571471282
# 536 correlated feature pairs left...
# 534 correlated feature pairs left...
# 492 correlated feature pairs left...
# 452 correlated feature pairs left...
# 414 correlated feature pairs left...
# 410 correlated feature pairs left...
# 374 correlated feature pairs left...
# 340 correlated feature pairs left...
# 338 correlated feature pairs left...
# 306 correlated feature pairs left...
# 276 correlated feature pairs left...
# 248 correlated feature pairs left...
# 222 correlated feature pairs left...
# 198 correlated feature pairs left...
# 176 correlated feature pairs left...
# 156 correlated feature pairs left...
# 138 correlated feature pairs left...
# 136 correlated feature pairs left...
# 134 correlated feature pairs left...
# 118 correlated feature pairs left...
# 104 correlated feature pairs left...
# 100 correlated feature pairs left...
# 98 correlated feature pairs left...
# 96 correlated feature pairs left...
# 94 correlated feature pairs left...
# 90 correlated feature pairs left...
# 88 correlated feature pairs left...
# 86 correlated feature pairs left...
# 84 correlated feature pairs left...
# 82 correlated feature pairs left...
# 70 correlated feature pairs left...
# 60 correlated feature pairs left...
# 58 correlated feature pairs left...
# 56 correlated feature pairs left...
# 54 correlated feature pairs left...
# 52 correlated feature pairs left...
# 50 correlated feature pairs left...
# 42 correlated feature pairs left...
# 38 correlated feature pairs left...
# 36 correlated feature pairs left...
# 34 correlated feature pairs left...
# 32 correlated feature pairs left...
# 30 correlated feature pairs left...
# 24 correlated feature pairs left...
# 22 correlated feature pairs left...
# 20 correlated feature pairs left...
# 18 correlated feature pairs left...
# 16 correlated feature pairs left...
# 12 correlated feature pairs left...
# 10 correlated feature pairs left...
# 8 correlated feature pairs left...
# 6 correlated feature pairs left...
# 4 correlated feature pairs left...
# 2 correlated feature pairs left...
# 218 ['flow_diff__symmetry_looking__r_0.0', 'return_flow__large_standard_deviation__r_0.5', 'target_value__large_standard_deviation__r_0.6000000000000001', 'target_value__symmetry_looking__r_0.0', 'target_value__symmetry_looking__r_0.65', 'return_flow__symmetry_looking__r_0.0', "real_('supply_flow', 'count_zeros')", "bin_('supply_pre_rinse', '<lambda>')", 'return_flow__number_crossing_m__m_-1', "real_('supply_pressure', 'count')", "bin_('return_recovery_water', '<lambda>')", 'target_value__large_standard_deviation__r_0.05', 'flow_diff__large_standard_deviation__r_0.35000000000000003', 'return_flow__large_standard_deviation__r_0.9', 'target_value__large_standard_deviation__r_0.9500000000000001', 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.5', "real_('flow_diff', 'count')", 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'target_value__large_standard_deviation__r_0.8500000000000001', 'target_value__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.6000000000000001', "real_('return_conductivity', 'count')", "real_('target_value', 'mean')", 'return_flow__symmetry_looking__r_0.7000000000000001', "bin_('supply_acid', '<lambda>')", 'return_flow__partial_autocorrelation__lag_0', 'return_flow__large_standard_deviation__r_0.9500000000000001', 'return_flow__large_standard_deviation__r_0.45', 'return_turbidity__symmetry_looking__r_0.7000000000000001', "real_('flow_diff', 'min')", 'return_turbidity__large_standard_deviation__r_0.8500000000000001', 'return_flow__symmetry_looking__r_0.65', 'flow_diff__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.35000000000000003', 'target_value__symmetry_looking__r_0.55', 'return_flow__symmetry_looking__r_0.45', "real_('tank_temperature_acid', 'count_zeros')", 'target_value__minimum', 'flow_diff__symmetry_looking__r_0.35000000000000003', 'return_flow__symmetry_looking__r_0.8', 'supply_flow__large_standard_deviation__r_0.8500000000000001', 'target_value__symmetry_looking__r_0.75', 'supply_flow__large_standard_deviation__r_0.6000000000000001', 'target_value__large_standard_deviation__r_0.8', "bin_('supply_acid', 'std')", 'return_flow__symmetry_looking__r_0.9500000000000001', 'pipeline_L10', 'object_id_30', "flow_('return_flow', 'max')", 'return_turbidity__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__number_crossing_m__m_-1', "bin_('return_acid', 'count_zeros')", 'return_flow__symmetry_looking__r_0.30000000000000004', 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.9500000000000001', "real_('tank_level_clean_water', 'count')", 'return_turbidity__large_standard_deviation__r_0.65', "real_('tank_level_caustic', 'count_zeros')", "real_('return_turbidity', 'max')", "real_('tank_level_pre_rinse', 'count')", 'target_value__large_standard_deviation__r_0.55', 'supply_flow__number_crossing_m__m_0', 'flow_diff__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.9', 'return_flow__maximum', 'supply_flow__symmetry_looking__r_0.0', "bin_('tank_lsh_acid', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.9', "bin_('tank_lsh_acid', '<lambda>')", "real_('return_flow', 'count_zeros')", 'return_turbidity__symmetry_looking__r_0.30000000000000004', 'flow_diff__large_standard_deviation__r_0.75', 'return_turbidity__symmetry_looking__r_0.35000000000000003', 'flow_diff__symmetry_looking__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.65', "real_('tank_temperature_pre_rinse', 'count_zeros')", "real_('return_temperature', 'count')", 'return_flow__large_standard_deviation__r_0.05', 'flow_diff__symmetry_looking__r_0.25', 'return_flow__symmetry_looking__r_0.8500000000000001', 'return_flow__large_standard_deviation__r_0.75', 'return_turbidity__partial_autocorrelation__lag_0', 'flow_diff__large_standard_deviation__r_0.65', 'return_turbidity__large_standard_deviation__r_0.6000000000000001', 'flow_diff__large_sta ...
# [rf_25_return_flow_sum] Fold #1 MAPE=0.05884430555923421
# [rf_25_return_flow_sum] Fold #2 MAPE=0.08235979490627536
# [rf_25_return_flow_sum] Fold #3 MAPE=0.06469657914079664
# [rf_25_return_flow_sum] Fold #4 MAPE=0.08833234985149105
# [rf_25_return_flow_sum] Fold #5 MAPE=0.05958418734411194
# [rf_25_return_flow_sum] Fold #6 MAPE=0.0908509717528545
# [rf_25_return_flow_sum] Fold #7 MAPE=0.09586703787869542
# [rf_25_return_flow_sum] Fold #8 MAPE=0.1548506726811026
# [rf_25_return_flow_sum] Fold #9 MAPE=0.06203845310256185
# [rf_25_return_flow_sum] Fold #10 MAPE=0.09653702709287013
# [et_25_return_flow_sum] Fold #1 MAPE=0.16864630121928714
# [et_25_return_flow_sum] Fold #2 MAPE=0.07264457882388661
# [et_25_return_flow_sum] Fold #3 MAPE=0.056432510410909555
# [et_25_return_flow_sum] Fold #4 MAPE=0.07669828788357848
# [et_25_return_flow_sum] Fold #5 MAPE=0.07370737602874214
# [et_25_return_flow_sum] Fold #6 MAPE=0.06513273365554476
# [et_25_return_flow_sum] Fold #7 MAPE=0.051290143578527986
# [et_25_return_flow_sum] Fold #8 MAPE=0.09030712267862206
# [et_25_return_flow_sum] Fold #9 MAPE=0.06620892324988513
# [et_25_return_flow_sum] Fold #10 MAPE=0.06711252611925435
# 542 correlated feature pairs left...
# 500 correlated feature pairs left...
# 460 correlated feature pairs left...
# 422 correlated feature pairs left...
# 418 correlated feature pairs left...
# 416 correlated feature pairs left...
# 380 correlated feature pairs left...
# 346 correlated feature pairs left...
# 314 correlated feature pairs left...
# 284 correlated feature pairs left...
# 256 correlated feature pairs left...
# 230 correlated feature pairs left...
# 206 correlated feature pairs left...
# 184 correlated feature pairs left...
# 164 correlated feature pairs left...
# 146 correlated feature pairs left...
# 144 correlated feature pairs left...
# 142 correlated feature pairs left...
# 140 correlated feature pairs left...
# 124 correlated feature pairs left...
# 110 correlated feature pairs left...
# 106 correlated feature pairs left...
# 104 correlated feature pairs left...
# 102 correlated feature pairs left...
# 90 correlated feature pairs left...
# 86 correlated feature pairs left...
# 84 correlated feature pairs left...
# 82 correlated feature pairs left...
# 80 correlated feature pairs left...
# 70 correlated feature pairs left...
# 62 correlated feature pairs left...
# 56 correlated feature pairs left...
# 54 correlated feature pairs left...
# 52 correlated feature pairs left...
# 48 correlated feature pairs left...
# 46 correlated feature pairs left...
# 44 correlated feature pairs left...
# 42 correlated feature pairs left...
# 40 correlated feature pairs left...
# 38 correlated feature pairs left...
# 36 correlated feature pairs left...
# 34 correlated feature pairs left...
# 32 correlated feature pairs left...
# 30 correlated feature pairs left...
# 28 correlated feature pairs left...
# 24 correlated feature pairs left...
# 22 correlated feature pairs left...
# 20 correlated feature pairs left...
# 18 correlated feature pairs left...
# 16 correlated feature pairs left...
# 14 correlated feature pairs left...
# 12 correlated feature pairs left...
# 10 correlated feature pairs left...
# 8 correlated feature pairs left...
# 6 correlated feature pairs left...
# 4 correlated feature pairs left...
# 2 correlated feature pairs left...
# 211 ['flow_diff__symmetry_looking__r_0.0', 'return_flow__large_standard_deviation__r_0.5', 'target_value__large_standard_deviation__r_0.6000000000000001', "bin_('tank_lsh_clean_water', 'mean')", 'target_value__symmetry_looking__r_0.0', 'return_flow__symmetry_looking__r_0.0', 'target_value__symmetry_looking__r_0.65', "real_('supply_flow', 'count_zeros')", "bin_('supply_pre_rinse', '<lambda>')", 'return_flow__number_crossing_m__m_-1', "real_('supply_pressure', 'count')", "bin_('return_recovery_water', '<lambda>')", "flow_('supply_flow', 'sum')", 'return_flow__large_standard_deviation__r_0.9', 'target_value__large_standard_deviation__r_0.9500000000000001', 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.5', "real_('flow_diff', 'count')", 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'target_value__large_standard_deviation__r_0.8500000000000001', 'target_value__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.6000000000000001', "real_('return_conductivity', 'count')", 'return_flow__number_crossing_m__m_0', "real_('target_value', 'mean')", 'return_flow__symmetry_looking__r_0.7000000000000001', "flow_('return_flow', 'sum')", 'return_flow__partial_autocorrelation__lag_0', 'return_flow__large_standard_deviation__r_0.9500000000000001', 'return_turbidity__symmetry_looking__r_0.7000000000000001', "real_('flow_diff', 'min')", 'object_id_95', 'return_turbidity__large_standard_deviation__r_0.8500000000000001', 'return_flow__range_count__max_1__min_-1', 'return_flow__symmetry_looking__r_0.65', 'flow_diff__large_standard_deviation__r_0.5', 'target_value__symmetry_looking__r_0.55', 'supply_flow__maximum', 'return_flow__symmetry_looking__r_0.45', 'return_flow__partial_autocorrelation__lag_1', "real_('tank_temperature_acid', 'count_zeros')", 'target_value__minimum', 'pipeline_L9', 'flow_diff__symmetry_looking__r_0.35000000000000003', 'return_flow__symmetry_looking__r_0.8', 'supply_flow__large_standard_deviation__r_0.8500000000000001', 'target_value__symmetry_looking__r_0.75', "real_('target_value', 'sum')", "real_('tank_temperature_caustic', 'count_zeros')", 'supply_flow__large_standard_deviation__r_0.6000000000000001', 'target_value__large_standard_deviation__r_0.8', 'return_flow__symmetry_looking__r_0.9500000000000001', "flow_('return_flow', 'max')", "bin_('supply_pre_rinse', 'std')", 'return_turbidity__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__number_crossing_m__m_-1', 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.9500000000000001', "real_('tank_level_clean_water', 'count')", 'return_turbidity__large_standard_deviation__r_0.65', "real_('tank_level_caustic', 'count_zeros')", "real_('return_turbidity', 'max')", "real_('tank_level_pre_rinse', 'count')", 'target_value__large_standard_deviation__r_0.55', 'supply_flow__number_crossing_m__m_0', 'flow_diff__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.9', 'supply_flow__symmetry_looking__r_0.0', "bin_('tank_lsh_acid', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.9', 'supply_flow__autocorrelation__lag_1', "bin_('tank_lsh_acid', '<lambda>')", 'flow_diff__large_standard_deviation__r_0.75', 'flow_diff__symmetry_looking__r_0.7000000000000001', "bin_('supply_caustic', '<lambda>')", 'flow_diff__symmetry_looking__r_0.65', "real_('tank_temperature_pre_rinse', 'count_zeros')", "real_('return_temperature', 'count')", 'flow_diff__symmetry_looking__r_0.25', 'return_flow__symmetry_looking__r_0.8500000000000001', 'return_flow__large_standard_deviation__r_0.75', 'return_turbidity__partial_autocorrelation__lag_0', 'flow_diff__large_standard_deviation__r_0.65', 'return_turbidity__large_standard_deviation__r_0.6000000000000001', 'flow_diff__large_standard_deviation__r_0.8', "bin_('tank_lsh_acid', 'mean')", 'return_flow__large_standard_deviation__r_0.7000000000000001', 'supply_flow__large_standard_deviation_ ...
# [rf_25_return_flow_sum] Fold #1 MAPE=0.11487846657237082
# [rf_25_return_flow_sum] Fold #2 MAPE=0.09317745579794702
# [rf_25_return_flow_sum] Fold #3 MAPE=0.09088493970080312
# [rf_25_return_flow_sum] Fold #4 MAPE=0.10294071641698069
# [rf_25_return_flow_sum] Fold #5 MAPE=0.08668829189578033
# [rf_25_return_flow_sum] Fold #6 MAPE=0.10322198442600504
# [rf_25_return_flow_sum] Fold #7 MAPE=0.09192390882722726
# [rf_25_return_flow_sum] Fold #8 MAPE=0.13576707700023916
# [rf_25_return_flow_sum] Fold #9 MAPE=0.0939715256936808
# [rf_25_return_flow_sum] Fold #10 MAPE=0.09127932458012647
# [et_25_return_flow_sum] Fold #1 MAPE=0.1195139985148328
# [et_25_return_flow_sum] Fold #2 MAPE=0.08673685087917425
# [et_25_return_flow_sum] Fold #3 MAPE=0.0842912357225899
# [et_25_return_flow_sum] Fold #4 MAPE=0.08267280623113543
# [et_25_return_flow_sum] Fold #5 MAPE=0.10504947782776589
# [et_25_return_flow_sum] Fold #6 MAPE=0.0819928184691782
# [et_25_return_flow_sum] Fold #7 MAPE=0.09393275248597402
# [et_25_return_flow_sum] Fold #8 MAPE=0.08844723518601925
# [et_25_return_flow_sum] Fold #9 MAPE=0.10740879072054603
# [et_25_return_flow_sum] Fold #10 MAPE=0.0783936566603161
# 1190 correlated feature pairs left...
# 1148 correlated feature pairs left...
# 1108 correlated feature pairs left...
# 1070 correlated feature pairs left...
# 1028 correlated feature pairs left...
# 988 correlated feature pairs left...
# 950 correlated feature pairs left...
# 914 correlated feature pairs left...
# 880 correlated feature pairs left...
# 854 correlated feature pairs left...
# 830 correlated feature pairs left...
# 808 correlated feature pairs left...
# 788 correlated feature pairs left...
# 770 correlated feature pairs left...
# 754 correlated feature pairs left...
# 718 correlated feature pairs left...
# 684 correlated feature pairs left...
# 652 correlated feature pairs left...
# 622 correlated feature pairs left...
# 594 correlated feature pairs left...
# 568 correlated feature pairs left...
# 544 correlated feature pairs left...
# 522 correlated feature pairs left...
# 490 correlated feature pairs left...
# 476 correlated feature pairs left...
# 464 correlated feature pairs left...
# 454 correlated feature pairs left...
# 424 correlated feature pairs left...
# 396 correlated feature pairs left...
# 376 correlated feature pairs left...
# 350 correlated feature pairs left...
# 348 correlated feature pairs left...
# 346 correlated feature pairs left...
# 344 correlated feature pairs left...
# 342 correlated feature pairs left...
# 318 correlated feature pairs left...
# 316 correlated feature pairs left...
# 312 correlated feature pairs left...
# 310 correlated feature pairs left...
# 288 correlated feature pairs left...
# 268 correlated feature pairs left...
# 260 correlated feature pairs left...
# 254 correlated feature pairs left...
# 250 correlated feature pairs left...
# 232 correlated feature pairs left...
# 216 correlated feature pairs left...
# 202 correlated feature pairs left...
# 184 correlated feature pairs left...
# 168 correlated feature pairs left...
# 154 correlated feature pairs left...
# 142 correlated feature pairs left...
# 130 correlated feature pairs left...
# 128 correlated feature pairs left...
# 126 correlated feature pairs left...
# 116 correlated feature pairs left...
# 106 correlated feature pairs left...
# 102 correlated feature pairs left...
# 100 correlated feature pairs left...
# 92 correlated feature pairs left...
# 90 correlated feature pairs left...
# 82 correlated feature pairs left...
# 80 correlated feature pairs left...
# 74 correlated feature pairs left...
# 72 correlated feature pairs left...
# 68 correlated feature pairs left...
# 66 correlated feature pairs left...
# 64 correlated feature pairs left...
# 62 correlated feature pairs left...
# 60 correlated feature pairs left...
# 56 correlated feature pairs left...
# 50 correlated feature pairs left...
# 46 correlated feature pairs left...
# 44 correlated feature pairs left...
# 42 correlated feature pairs left...
# 40 correlated feature pairs left...
# 38 correlated feature pairs left...
# 36 correlated feature pairs left...
# 34 correlated feature pairs left...
# 32 correlated feature pairs left...
# 30 correlated feature pairs left...
# 28 correlated feature pairs left...
# 26 correlated feature pairs left...
# 24 correlated feature pairs left...
# 22 correlated feature pairs left...
# 20 correlated feature pairs left...
# 18 correlated feature pairs left...
# 16 correlated feature pairs left...
# 14 correlated feature pairs left...
# 12 correlated feature pairs left...
# 10 correlated feature pairs left...
# 8 correlated feature pairs left...
# 6 correlated feature pairs left...
# 4 correlated feature pairs left...
# 2 correlated feature pairs left...
# 209 ['flow_diff__symmetry_looking__r_0.0', 'return_flow__large_standard_deviation__r_0.5', 'target_value__large_standard_deviation__r_0.6000000000000001', "bin_('tank_lsh_clean_water', 'mean')", 'target_value__symmetry_looking__r_0.0', 'return_flow__symmetry_looking__r_0.0', 'target_value__symmetry_looking__r_0.65', 'return_flow__number_crossing_m__m_-1', "real_('flow_diff', 'max')", "real_('supply_pressure', 'count')", 'return_turbidity__large_standard_deviation__r_0.05', "flow_('supply_flow', 'sum')", "flow_('target_value', 'max')", 'return_flow__large_standard_deviation__r_0.9', 'target_value__large_standard_deviation__r_0.9500000000000001', 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.5', "real_('flow_diff', 'count')", 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'target_value__large_standard_deviation__r_0.8500000000000001', 'target_value__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.6000000000000001', "real_('return_conductivity', 'count')", 'return_flow__number_crossing_m__m_0', "real_('target_value', 'mean')", "real_('return_flow', 'sum')", "bin_('supply_acid', '<lambda>')", 'return_flow__partial_autocorrelation__lag_0', 'return_flow__large_standard_deviation__r_0.9500000000000001', 'return_turbidity__symmetry_looking__r_0.7000000000000001', "real_('flow_diff', 'min')", 'object_id_95', 'return_turbidity__large_standard_deviation__r_0.8500000000000001', 'return_flow__symmetry_looking__r_0.65', 'flow_diff__large_standard_deviation__r_0.5', 'target_value__symmetry_looking__r_0.55', 'supply_flow__maximum', 'return_flow__symmetry_looking__r_0.45', "real_('tank_temperature_acid', 'count_zeros')", 'supply_flow__range_count__max_1__min_-1', 'target_value__minimum', 'pipeline_L9', 'flow_diff__symmetry_looking__r_0.35000000000000003', 'supply_flow__large_standard_deviation__r_0.8500000000000001', 'return_flow__symmetry_looking__r_0.8', 'target_value__symmetry_looking__r_0.75', 'supply_flow__large_standard_deviation__r_0.6000000000000001', 'target_value__large_standard_deviation__r_0.8', "bin_('supply_acid', 'std')", 'return_flow__symmetry_looking__r_0.9500000000000001', "flow_('return_flow', 'max')", 'return_turbidity__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__number_crossing_m__m_-1', 'supply_flow__large_standard_deviation__r_0.45', "bin_('return_acid', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.9500000000000001', "bin_('supply_clean_water', '<lambda>')", "real_('tank_level_clean_water', 'count')", 'return_turbidity__large_standard_deviation__r_0.65', "real_('tank_level_caustic', 'count_zeros')", "real_('return_turbidity', 'max')", "real_('tank_level_pre_rinse', 'count')", 'target_value__large_standard_deviation__r_0.55', 'flow_diff__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.9', 'supply_flow__symmetry_looking__r_0.0', "bin_('tank_lsh_acid', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.9', "bin_('tank_lsh_acid', '<lambda>')", "real_('return_flow', 'count_zeros')", 'flow_diff__large_standard_deviation__r_0.75', 'return_turbidity__symmetry_looking__r_0.35000000000000003', 'supply_flow__minimum', 'flow_diff__symmetry_looking__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.65', 'supply_flow__ratio_beyond_r_sigma__r_10', "real_('tank_temperature_pre_rinse', 'count_zeros')", "real_('return_temperature', 'count')", 'return_flow__symmetry_looking__r_0.8500000000000001', 'return_flow__large_standard_deviation__r_0.75', 'return_turbidity__partial_autocorrelation__lag_0', 'flow_diff__large_standard_deviation__r_0.65', 'return_turbidity__large_standard_deviation__r_0.6000000000000001', 'flow_diff__large_standard_deviation__r_0.8', "bin_('tank_lsh_acid', 'mean')", 'return_flow__large_standard_deviation__r_0.7000000000000001', 'supply_flow__large_standard_deviation__r_0.5', 'supply_flow__s ...
# [rf_25_return_flow_sum] Fold #1 MAPE=0.11272132589079385
# [rf_25_return_flow_sum] Fold #2 MAPE=0.09863767516445791
# [rf_25_return_flow_sum] Fold #3 MAPE=0.11330872618573384
# [rf_25_return_flow_sum] Fold #4 MAPE=0.13818583734281187
# [rf_25_return_flow_sum] Fold #5 MAPE=0.11754908268023445
# [rf_25_return_flow_sum] Fold #6 MAPE=0.12153852633281131
# [rf_25_return_flow_sum] Fold #7 MAPE=0.11880503505673912
# [rf_25_return_flow_sum] Fold #8 MAPE=0.11768438727920903
# [rf_25_return_flow_sum] Fold #9 MAPE=0.08503031127656663
# [rf_25_return_flow_sum] Fold #10 MAPE=0.1325656912414328
# [et_25_return_flow_sum] Fold #1 MAPE=0.12551904050676152
# [et_25_return_flow_sum] Fold #2 MAPE=0.10347759581111023
# [et_25_return_flow_sum] Fold #3 MAPE=0.13423668607940098
# [et_25_return_flow_sum] Fold #4 MAPE=0.09477681392703188
# [et_25_return_flow_sum] Fold #5 MAPE=0.11664389530163818
# [et_25_return_flow_sum] Fold #6 MAPE=0.1128054552576203
# [et_25_return_flow_sum] Fold #7 MAPE=0.11221749752235974
# [et_25_return_flow_sum] Fold #8 MAPE=0.09193654664293144
# [et_25_return_flow_sum] Fold #9 MAPE=0.10651720435073112
# [et_25_return_flow_sum] Fold #10 MAPE=0.08395032189832873
# 534 correlated feature pairs left...
# 492 correlated feature pairs left...
# 452 correlated feature pairs left...
# 414 correlated feature pairs left...
# 378 correlated feature pairs left...
# 374 correlated feature pairs left...
# 340 correlated feature pairs left...
# 308 correlated feature pairs left...
# 278 correlated feature pairs left...
# 250 correlated feature pairs left...
# 224 correlated feature pairs left...
# 200 correlated feature pairs left...
# 198 correlated feature pairs left...
# 176 correlated feature pairs left...
# 156 correlated feature pairs left...
# 138 correlated feature pairs left...
# 136 correlated feature pairs left...
# 132 correlated feature pairs left...
# 130 correlated feature pairs left...
# 114 correlated feature pairs left...
# 112 correlated feature pairs left...
# 98 correlated feature pairs left...
# 96 correlated feature pairs left...
# 92 correlated feature pairs left...
# 80 correlated feature pairs left...
# 70 correlated feature pairs left...
# 62 correlated feature pairs left...
# 60 correlated feature pairs left...
# 54 correlated feature pairs left...
# 52 correlated feature pairs left...
# 48 correlated feature pairs left...
# 46 correlated feature pairs left...
# 44 correlated feature pairs left...
# 42 correlated feature pairs left...
# 40 correlated feature pairs left...
# 38 correlated feature pairs left...
# 36 correlated feature pairs left...
# 34 correlated feature pairs left...
# 32 correlated feature pairs left...
# 30 correlated feature pairs left...
# 28 correlated feature pairs left...
# 26 correlated feature pairs left...
# 24 correlated feature pairs left...
# 22 correlated feature pairs left...
# 20 correlated feature pairs left...
# 18 correlated feature pairs left...
# 16 correlated feature pairs left...
# 14 correlated feature pairs left...
# 12 correlated feature pairs left...
# 10 correlated feature pairs left...
# 8 correlated feature pairs left...
# 6 correlated feature pairs left...
# 4 correlated feature pairs left...
# 2 correlated feature pairs left...
# 215 ['flow_diff__symmetry_looking__r_0.0', 'return_flow__large_standard_deviation__r_0.5', 'target_value__large_standard_deviation__r_0.6000000000000001', "bin_('tank_lsh_clean_water', 'mean')", 'target_value__symmetry_looking__r_0.0', 'return_flow__symmetry_looking__r_0.0', 'target_value__symmetry_looking__r_0.65', "real_('supply_flow', 'count_zeros')", "bin_('supply_pre_rinse', '<lambda>')", 'return_flow__number_crossing_m__m_-1', "real_('supply_pressure', 'count')", "bin_('return_recovery_water', '<lambda>')", 'return_flow__large_standard_deviation__r_0.9', 'target_value__large_standard_deviation__r_0.9500000000000001', 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.5', "real_('flow_diff', 'count')", 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'target_value__large_standard_deviation__r_0.8500000000000001', 'target_value__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.6000000000000001', "real_('return_conductivity', 'count')", 'return_flow__number_crossing_m__m_0', "real_('target_value', 'mean')", 'return_flow__symmetry_looking__r_0.7000000000000001', "flow_('return_flow', 'sum')", "bin_('supply_acid', '<lambda>')", 'return_flow__partial_autocorrelation__lag_0', 'target_value__symmetry_looking__r_0.25', 'return_flow__large_standard_deviation__r_0.9500000000000001', 'return_flow__large_standard_deviation__r_0.45', 'return_turbidity__symmetry_looking__r_0.7000000000000001', "real_('flow_diff', 'min')", 'object_id_95', 'return_turbidity__large_standard_deviation__r_0.8500000000000001', 'return_flow__range_count__max_1__min_-1', 'return_flow__symmetry_looking__r_0.65', 'flow_diff__large_standard_deviation__r_0.5', 'target_value__symmetry_looking__r_0.55', 'supply_flow__maximum', 'return_flow__symmetry_looking__r_0.45', "real_('tank_temperature_acid', 'count_zeros')", 'target_value__minimum', 'pipeline_L9', 'flow_diff__symmetry_looking__r_0.35000000000000003', 'return_flow__symmetry_looking__r_0.8', 'supply_flow__large_standard_deviation__r_0.8500000000000001', "real_('supply_flow', 'sum')", 'target_value__symmetry_looking__r_0.75', "real_('tank_temperature_caustic', 'count_zeros')", 'supply_flow__large_standard_deviation__r_0.6000000000000001', 'target_value__large_standard_deviation__r_0.8', "bin_('supply_acid', 'std')", 'return_flow__symmetry_looking__r_0.9500000000000001', 'object_id_30', "flow_('return_flow', 'max')", 'return_turbidity__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__number_crossing_m__m_-1', 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.9500000000000001', "real_('tank_level_clean_water', 'count')", 'return_turbidity__large_standard_deviation__r_0.65', "real_('tank_level_caustic', 'count_zeros')", "real_('return_turbidity', 'max')", "real_('tank_level_pre_rinse', 'count')", 'target_value__large_standard_deviation__r_0.55', 'supply_flow__number_crossing_m__m_0', 'flow_diff__large_standard_deviation__r_0.9', 'return_turbidity__symmetry_looking__r_0.9', 'return_flow__maximum', 'supply_flow__symmetry_looking__r_0.0', "bin_('tank_lsh_acid', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.9', 'supply_flow__autocorrelation__lag_1', "bin_('tank_lsh_acid', '<lambda>')", 'flow_diff__large_standard_deviation__r_0.75', 'return_turbidity__symmetry_looking__r_0.35000000000000003', 'supply_flow__minimum', 'flow_diff__symmetry_looking__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.65', "real_('tank_temperature_pre_rinse', 'count_zeros')", 'flow_diff__symmetry_looking__r_0.25', 'return_flow__symmetry_looking__r_0.8500000000000001', 'return_flow__large_standard_deviation__r_0.75', 'return_turbidity__partial_autocorrelation__lag_0', 'flow_diff__large_standard_deviation__r_0.65', 'return_turbidity__large_standard_deviation__r_0.6000000000000001', 'flow_diff__large_standard_deviation__r_0.8', "bin_('tank_lsh_acid', 'mean')", 'return_flow_ ...
# [rf_25_return_flow_sum] Fold #1 MAPE=0.09993837888566644
# [rf_25_return_flow_sum] Fold #2 MAPE=0.10215086895511795
# [rf_25_return_flow_sum] Fold #3 MAPE=0.0966288329680259
# [rf_25_return_flow_sum] Fold #4 MAPE=0.09873968436771757
# [rf_25_return_flow_sum] Fold #5 MAPE=0.11769942597770082
# [rf_25_return_flow_sum] Fold #6 MAPE=0.09110848594730656
# [rf_25_return_flow_sum] Fold #7 MAPE=0.10784549176710496
# [rf_25_return_flow_sum] Fold #8 MAPE=0.09578367204604595
# [rf_25_return_flow_sum] Fold #9 MAPE=0.1358326132575144
# [rf_25_return_flow_sum] Fold #10 MAPE=0.1120260138118701
# [et_25_return_flow_sum] Fold #1 MAPE=0.09482864378968477
# [et_25_return_flow_sum] Fold #2 MAPE=0.10252365039210581
# [et_25_return_flow_sum] Fold #3 MAPE=0.09390049173459324
# [et_25_return_flow_sum] Fold #4 MAPE=0.11997479456328446
# [et_25_return_flow_sum] Fold #5 MAPE=0.09782854318610945
# [et_25_return_flow_sum] Fold #6 MAPE=0.08980409282083472
# [et_25_return_flow_sum] Fold #7 MAPE=0.0914798846926728
# [et_25_return_flow_sum] Fold #8 MAPE=0.09286877566666914
# [et_25_return_flow_sum] Fold #9 MAPE=0.11898382468962021
# [et_25_return_flow_sum] Fold #10 MAPE=0.1065872891702541
# 1072 correlated feature pairs left...
# 1070 correlated feature pairs left...
# 1028 correlated feature pairs left...
# 1026 correlated feature pairs left...
# 984 correlated feature pairs left...
# 944 correlated feature pairs left...
# 942 correlated feature pairs left...
# 940 correlated feature pairs left...
# 900 correlated feature pairs left...
# 862 correlated feature pairs left...
# 826 correlated feature pairs left...
# 788 correlated feature pairs left...
# 754 correlated feature pairs left...
# 718 correlated feature pairs left...
# 686 correlated feature pairs left...
# 656 correlated feature pairs left...
# 628 correlated feature pairs left...
# 594 correlated feature pairs left...
# 590 correlated feature pairs left...
# 558 correlated feature pairs left...
# 528 correlated feature pairs left...
# 500 correlated feature pairs left...
# 474 correlated feature pairs left...
# 450 correlated feature pairs left...
# 428 correlated feature pairs left...
# 408 correlated feature pairs left...
# 382 correlated feature pairs left...
# 358 correlated feature pairs left...
# 336 correlated feature pairs left...
# 316 correlated feature pairs left...
# 298 correlated feature pairs left...
# 280 correlated feature pairs left...
# 278 correlated feature pairs left...
# 262 correlated feature pairs left...
# 248 correlated feature pairs left...
# 246 correlated feature pairs left...
# 242 correlated feature pairs left...
# 226 correlated feature pairs left...
# 224 correlated feature pairs left...
# 222 correlated feature pairs left...
# 220 correlated feature pairs left...
# 218 correlated feature pairs left...
# 204 correlated feature pairs left...
# 192 correlated feature pairs left...
# 188 correlated feature pairs left...
# 186 correlated feature pairs left...
# 174 correlated feature pairs left...
# 172 correlated feature pairs left...
# 170 correlated feature pairs left...
# 168 correlated feature pairs left...
# 166 correlated feature pairs left...
# 164 correlated feature pairs left...
# 162 correlated feature pairs left...
# 160 correlated feature pairs left...
# 158 correlated feature pairs left...
# 156 correlated feature pairs left...
# 154 correlated feature pairs left...
# 144 correlated feature pairs left...
# 134 correlated feature pairs left...
# 126 correlated feature pairs left...
# 124 correlated feature pairs left...
# 122 correlated feature pairs left...
# 120 correlated feature pairs left...
# 118 correlated feature pairs left...
# 116 correlated feature pairs left...
# 110 correlated feature pairs left...
# 108 correlated feature pairs left...
# 106 correlated feature pairs left...
# 102 correlated feature pairs left...
# 100 correlated feature pairs left...
# 98 correlated feature pairs left...
# 96 correlated feature pairs left...
# 94 correlated feature pairs left...
# 92 correlated feature pairs left...
# 90 correlated feature pairs left...
# 88 correlated feature pairs left...
# 86 correlated feature pairs left...
# 84 correlated feature pairs left...
# 82 correlated feature pairs left...
# 74 correlated feature pairs left...
# 72 correlated feature pairs left...
# 70 correlated feature pairs left...
# 68 correlated feature pairs left...
# 66 correlated feature pairs left...
# 60 correlated feature pairs left...
# 58 correlated feature pairs left...
# 56 correlated feature pairs left...
# 54 correlated feature pairs left...
# 52 correlated feature pairs left...
# 50 correlated feature pairs left...
# 48 correlated feature pairs left...
# 46 correlated feature pairs left...
# 44 correlated feature pairs left...
# 42 correlated feature pairs left...
# 40 correlated feature pairs left...
# 38 correlated feature pairs left...
# 36 correlated feature pairs left...
# 34 correlated feature pairs left...
# 32 correlated feature pairs left...
# 28 correlated feature pairs left...
# 26 correlated feature pairs left...
# 24 correlated feature pairs left...
# 22 correlated feature pairs left...
# 20 correlated feature pairs left...
# 18 correlated feature pairs left...
# 16 correlated feature pairs left...
# 14 correlated feature pairs left...
# 12 correlated feature pairs left...
# 10 correlated feature pairs left...
# 8 correlated feature pairs left...
# 6 correlated feature pairs left...
# 4 correlated feature pairs left...
# 2 correlated feature pairs left...
# 298 ['flow_diff__symmetry_looking__r_0.0', 'return_flow__large_standard_deviation__r_0.5', 'target_value__large_standard_deviation__r_0.6000000000000001', "bin_('tank_lsh_clean_water', 'mean')", 'target_value__symmetry_looking__r_0.0', 'return_flow__symmetry_looking__r_0.0', 'target_value__symmetry_looking__r_0.65', "last_real_('tank_temperature_pre_rinse', 'count')", "last_bin_('tank_lsh_clean_water', 'mean')", "bin_('supply_pre_rinse', '<lambda>')", 'return_flow__number_crossing_m__m_-1', "last_real_('tank_level_caustic', 'count')", "real_('flow_diff', 'max')", "real_('supply_pressure', 'count')", "bin_('return_recovery_water', '<lambda>')", "real_('supply_pressure', '<lambda>')", "last_bin_('supply_caustic', '<lambda>')", "last_real_('tank_level_clean_water', 'count')", 'flow_diff__large_standard_deviation__r_0.35000000000000003', "flow_('target_value', 'max')", "last_bin_('supply_pump', '<lambda>')", 'return_flow__large_standard_deviation__r_0.9', 'target_value__large_standard_deviation__r_0.9500000000000001', 'flow_diff__large_standard_deviation__r_0.7000000000000001', 'flow_diff__symmetry_looking__r_0.5', "real_('flow_diff', 'count')", 'flow_diff__large_standard_deviation__r_0.9500000000000001', 'target_value__large_standard_deviation__r_0.8500000000000001', 'target_value__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.6000000000000001', "real_('return_conductivity', 'count')", "real_('tank_temperature_pre_rinse', '<lambda>')", 'return_flow__symmetry_looking__r_0.7000000000000001', "flow_('return_flow', 'sum')", "bin_('supply_acid', '<lambda>')", 'return_flow__partial_autocorrelation__lag_0', "last_flow_('supply_flow', 'mean')", 'return_flow__large_standard_deviation__r_0.9500000000000001', 'return_flow__large_standard_deviation__r_0.45', 'return_turbidity__symmetry_looking__r_0.7000000000000001', "last_real_('tank_concentration_acid', 'count')", "last_real_('tank_level_clean_water', 'count_zeros')", "last_bin_('supply_acid', 'mean')", 'object_id_95', 'return_turbidity__large_standard_deviation__r_0.8500000000000001', "bin_('tank_lsh_caustic', '<lambda>')", "last_real_('tank_concentration_acid', '<lambda>')", 'return_flow__range_count__max_1__min_-1', "last_real_('tank_concentration_caustic', 'count')", "last_bin_('tank_lsh_acid', 'count_zeros')", 'return_flow__symmetry_looking__r_0.65', "last_real_('tank_concentration_caustic', 'count_zeros')", 'flow_diff__large_standard_deviation__r_0.5', 'return_flow__symmetry_looking__r_0.35000000000000003', 'target_value__symmetry_looking__r_0.55', 'return_flow__symmetry_looking__r_0.45', "real_('tank_temperature_acid', 'count_zeros')", "last_bin_('tank_lsh_acid', 'mean')", 'supply_flow__range_count__max_1__min_-1', "last_real_('return_conductivity', '<lambda>')", "real_('tank_level_caustic', '<lambda>')", 'target_value__minimum', "last_bin_('return_recovery_water', '<lambda>')", 'flow_diff__symmetry_looking__r_0.35000000000000003', 'return_flow__symmetry_looking__r_0.8', 'supply_flow__large_standard_deviation__r_0.8500000000000001', "last_real_('tank_temperature_acid', 'count_zeros')", 'target_value__symmetry_looking__r_0.75', "real_('supply_flow', 'sum')", "last_real_('tank_temperature_caustic', 'count')", "last_real_('return_flow', 'sum')", 'supply_flow__large_standard_deviation__r_0.6000000000000001', 'target_value__large_standard_deviation__r_0.8', "bin_('supply_acid', 'std')", 'return_flow__symmetry_looking__r_0.9500000000000001', "last_bin_('supply_acid', '<lambda>')", "last_bin_('tank_lsh_acid', '<lambda>')", "last_real_('supply_flow', 'count')", "last_real_('return_flow', '<lambda>')", 'object_id_30', "flow_('return_flow', 'max')", 'return_turbidity__symmetry_looking__r_0.45', 'return_turbidity__large_standard_deviation__r_0.7000000000000001', 'return_turbidity__number_crossing_m__m_-1', "last_bin_('supply_acid', 'std')", "last_bin_('return_acid', '<lambda>')", 'flow_diff__symmetry_looking__r_0.4', 'flow_diff__symmetry_looking__r_0.9500000000000001',  ...
# [rf_25_return_flow_sum] Fold #1 MAPE=0.10547031287384798
# [rf_25_return_flow_sum] Fold #2 MAPE=0.12171353892701478
# [rf_25_return_flow_sum] Fold #3 MAPE=0.1255745496709132
# [rf_25_return_flow_sum] Fold #4 MAPE=0.10842802052890874
# [rf_25_return_flow_sum] Fold #5 MAPE=0.09212594116054179
# [rf_25_return_flow_sum] Fold #6 MAPE=0.09592827943786103
# [rf_25_return_flow_sum] Fold #7 MAPE=0.07721681215991409
# [rf_25_return_flow_sum] Fold #8 MAPE=0.09478295964444629
# [rf_25_return_flow_sum] Fold #9 MAPE=0.08983971483041826
# [rf_25_return_flow_sum] Fold #10 MAPE=0.09735280374219779
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7ea9a1900bf6> in <module>()
#      30
#      31     for name, clf in clfs:
# ---> 32         train_pred_df, test_pred_df = fit_stack(clf, name, X_train, y_train, X_test, n_splits=10)
#      33         train_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/train_predictions_stack_flow_{}_{}_{}.csv'.format(name, recipe, process_combination))
#      34         test_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/test_predictions_stack_flow_{}_{}_{}.csv'.format(name, recipe, process_combination))
#
# <ipython-input-4-d1cc60fd9394> in fit_stack(clf, name, X_train, y_train, X_test, n_splits)
#      13
#      14     clf_clone = clone(clf)
# ---> 15     clf_clone.fit(X_cv_train, y_cv_train)
#      16
#      17     print('[{}] Fold #{} MAPE={}'.format(name, fold_ix + 1, custom_mape(np.exp(y_cv_test), np.exp(clf_clone.predict(X_cv_test)))))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     331                     t, self, X, y, sample_weight, i, len(trees),
#     332                     verbose=self.verbose, class_weight=self.class_weight)
# --> 333                 for i, t in enumerate(trees))
#     334
#     335             # Collect newly grown trees
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     120     else:
# --> 121         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#     122
#     123     return tree
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1140             sample_weight=sample_weight,
#    1141             check_input=check_input,
# -> 1142             X_idx_sorted=X_idx_sorted)
#    1143         return self
#    1144
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     364                                            min_impurity_split)
#     365
# --> 366         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     367
#     368         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
# combinations_per_recipe = {
#     3: [1, 2, 3], 
#     9: [8],
#     15: [1, 2, 3, 6, 7, 14, 15]
# }

# prediction_df = None
# import warnings; warnings.filterwarnings('ignore')
# for recipe in [9, 15, 3]:
#   for process_combination in combinations_per_recipe[recipe]:
#     train_features = pd.read_csv('/content/drive/My Drive/Rinse Over Run/train_features_{}_{}.csv'.format(recipe, process_combination), index_col=0)
#     test_features = pd.read_csv('/content/drive/My Drive/Rinse Over Run/test_features_{}_{}.csv'.format(recipe, process_combination), index_col=0)
#       labels = pd.read_csv('/content/drive/My Drive/Rinse Over Run/final_phase_labels_{}_{}.csv'.format(recipe, process_combination), index_col=0)
    
#     X_train = train_features.drop('target', axis=1)
#     y_train = np.log(np.maximum(0, labels.loc[X_train.index]['return_turbidity_sum']) + 1)
    
#     X_test = test_features
    
#     to_drop = remove_features(X_train, y_train)
#     print(len(to_drop), to_drop)

#     X_train = X_train.drop(to_drop, axis=1)
#     X_test = X_test.drop(to_drop, axis=1)
    
    
#     clfs = [
#           ('rf_25_return_turbidity_sum', RandomForestRegressor(n_estimators=25)),
#           ('et_25_return_turbidity_sum', ExtraTreesRegressor(n_estimators=25)),
#       ]

#     for name, clf in clfs:
#         train_pred_df, test_pred_df = fit_stack(clf, name, X_train, y_train, X_test, n_splits=10)
#         train_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/train_predictions_stack_turbidity_{}_{}_{}.csv'.format(name, recipe, process_combination))
#         test_pred_df.to_csv('/content/drive/My Drive/Rinse Over Run/test_predictions_stack_turbidity_{}_{}_{}.csv'.format(name, recipe, process_combination))
